# %%
import os
os.listdir(r"C:\Users\arthu\APS360\Project_New\balanced_small_dataset")
# Out:
# ['images', 'labels']

# %%
# Path to the list_ingredients.txt file
ingredient_list_path = r'C:\Users\arthu\APS360\Project_New\list_ingredients.txt'
# Path to the list_ingredients.txt file
#ingredient_list_path = r'C:\Users\arthu\APS360\Project_New\ML_code\list_ingredients.txt'
# Initialize ingredient lists
ingredients = []
ingredient_frequencies = []

# Read the file and parse ingredients with frequencies
with open(ingredient_list_path, 'r') as f:
    for line in f:
        # Stop reading if we encounter the 'Top 10 Most Common Ingredients' line
        if line.startswith('Top'):
            break

        # Skip lines that are not ingredients or are headers
        if ':' in line or line.strip() == '':
            continue

        # Extract the ingredient name and its frequency
        ingredient = line.split('(')[0].strip()  # Extract ingredient name
        frequency = int(line.split('(')[1].replace(')', '').strip())  # Extract frequency
        ingredients.append(ingredient)
        ingredient_frequencies.append(frequency)

# Check how many ingredients were read and print a few for verification
print(f"Total ingredients: {len(ingredients)}")
print(f"First 10 ingredients: {ingredients[:10]}")  # Display the first 10 ingredients for verification
print(f"First 10 frequencies: {ingredient_frequencies[:10]}")  # Display the first 10 frequencies for verification

# Create a dictionary mapping each ingredient to a unique index (for one-hot encoding)
ingredient_dict = {ingredient: i for i, ingredient in enumerate(ingredients)}

# Create a dictionary mapping each ingredient to its frequency
ingredient_freq_dict = {ingredient: freq for ingredient, freq in zip(ingredients, ingredient_frequencies)}

# Print some examples for verification
print(f"Total unique ingredients mapped: {len(ingredient_dict)}")
print("Example ingredient mapping (index):", list(ingredient_dict.items())[:10])
print("Example ingredient mapping (frequency):", list(ingredient_freq_dict.items())[:10])
# Out:
# Total ingredients: 53
# First 10 ingredients: ['agent1', 'agent2', 'allium', 'berries', 'butter1', 'butter2', 'butter3', 'butter4', 'cheese', 'chocolate']
# First 10 frequencies: [4337, 4337, 5320, 4501, 3601, 3601, 3601, 3600, 5127, 4310]
# Total unique ingredients mapped: 53
# Example ingredient mapping (index): [('agent1', 0), ('agent2', 1), ('allium', 2), ('berries', 3), ('butter1', 4), ('butter2', 5), ('butter3', 6), ('butter4', 7), ('cheese', 8), ('chocolate', 9)]
# Example ingredient mapping (frequency): [('agent1', 4337), ('agent2', 4337), ('allium', 5320), ('berries', 4501), ('butter1', 3601), ('butter2', 3601), ('butter3', 3601), ('butter4', 3600), ('cheese', 5127), ('chocolate', 4310)]

# %%
import os
import random
import torch
import glob
from torch.utils.data import Dataset
from PIL import Image

class IngredientDataset(Dataset):
    def __init__(self, image_folder, label_folder, ingredient_dict, transform=None, folder_percentage=1.0, image_percentage=1.0):
        self.image_folder = image_folder
        self.label_folder = label_folder
        self.transform = transform
        self.ingredient_dict = {k.strip().lower(): v for k, v in ingredient_dict.items()}  # Normalize keys
        self.data = []

        # Collect all key names (subfolders in image_folder)
        all_folders = [key_name for key_name in os.listdir(label_folder) if key_name.endswith('.txt')]

        # Sample a subset of folders based on the folder_percentage
        folder_count = int(len(all_folders) * folder_percentage)
        random.seed(42)
        selected_folders = random.sample(all_folders, folder_count)

        for key_name in selected_folders:
            key_name_no_ext = key_name.replace('.txt', '')
            image_dir = os.path.join(image_folder, key_name_no_ext)
            label_file = os.path.join(label_folder, key_name)

            # Check if the image folder and label file both exist
            if not os.path.exists(image_dir):
                print(f"Missing image folder for key: {key_name_no_ext}")
                continue

            if not os.path.exists(label_file):
                print(f"Missing label file for key: {key_name_no_ext}")
                continue

            # Collect all images in the folder
            images = glob.glob(os.path.join(image_dir, "*.jpg"))

            # Debug: Check image count in folder
            print(f"Key: {key_name_no_ext}, Total Images: {len(images)}")

            # Sample a subset of images within the folder based on image_percentage
            image_count = int(len(images) * image_percentage)
            selected_images = random.sample(images, image_count) if image_count < len(images) else images

            # Add each image as a separate entry in the dataset
            for img_path in selected_images:
                self.data.append((key_name_no_ext, img_path, label_file))

        # Debug: Final dataset size
        print(f"Total Dataset Size: {len(self.data)}")

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        key_name, img_path, label_path = self.data[idx]

        # Load and transform the image
        image = Image.open(img_path).convert('RGB')
        if self.transform:
            image = self.transform(image)

        # Load and encode the label
        with open(label_path, 'r') as f:
            ingredients = f.read().strip().split('\n')

        # Debug: Check label file contents
        #print(f"Label File ({label_path}) Contents: {ingredients}")

        label_tensor = torch.tensor(self._encode_ingredients(ingredients), dtype=torch.float)

        # Debug: Check label tensor
        #print(f"Encoded Label Tensor for {key_name}: {label_tensor.nonzero(as_tuple=True)}")

        return key_name, image, label_tensor

    def _encode_ingredients(self, ingredients):
        """Convert list of ingredients to a one-hot vector."""
        ingredient_vector = [0] * len(self.ingredient_dict)
        for ingredient in ingredients:
            normalized_ingredient = ingredient.strip().lower()
            if normalized_ingredient in self.ingredient_dict:
                ingredient_vector[self.ingredient_dict[normalized_ingredient]] = 1
            else:
                # Debug: Log unmapped ingredient
                print(f"Unmapped Ingredient: {ingredient}")
        return ingredient_vector

# %%
from torch.utils.data import DataLoader
from torchvision import transforms

# Define image transformations (resize, convert to tensor, normalize)
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Dataset paths "C:\Users\arthu\APS360\Project_New\balanced_small_dataset\images\train\05123e5f1b"
#"F:\full_dataset\images"
train_image_folder = r'F:\full_dataset\images\train'
train_label_folder = r'F:\full_dataset\labels\train'
val_image_folder = r'F:\full_dataset\images\val'
val_label_folder = r'F:\full_dataset\labels\val'
test_image_folder = r'F:\full_dataset\images\test'
test_label_folder = r'F:\full_dataset\labels\test'



# Initialize datasets and DataLoaders
train_dataset = IngredientDataset(
    train_image_folder, train_label_folder, ingredient_dict, transform=transform, folder_percentage=1.0, image_percentage=1.0
)
val_dataset = IngredientDataset(
    val_image_folder, val_label_folder, ingredient_dict, transform=transform, folder_percentage=1.0, image_percentage=1.0
)
test_dataset = IngredientDataset(
    test_image_folder, test_label_folder, ingredient_dict, transform=transform, folder_percentage=1.0, image_percentage=1.0
)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Verify DataLoader
print("Verifying Train Loader...")
for batch_idx, (key_name, image, label) in enumerate(val_loader):
    print(f"Batch {batch_idx + 1}")
    print(f"Key Name: {key_name}")
    print(f"Image Tensor Shape: {image.shape}")
    print(f"Label Tensor Shape: {label.shape}")
    print(f"Non-zero Labels: {label.nonzero(as_tuple=True)}")  # Check for non-zero labels
    break  # Break after the first batch for verification
# Out:
# Key: 3472dad85a, Total Images: 3
# Key: 0ba05d0c30, Total Images: 5
# Key: 81ebb544e5, Total Images: 28
# Key: 741a7c33d4, Total Images: 16
# Key: 69d6ab2dcf, Total Images: 26
# Key: 41ae05d61a, Total Images: 5
# Key: 304376d284, Total Images: 4
# Key: 28a08f0371, Total Images: 11
# Key: c78add3d31, Total Images: 14
# Key: 0edcde1dbf, Total Images: 10
# Key: 0dec99d687, Total Images: 11
# Key: 2bfa0ff316, Total Images: 12
# Key: 67dc0da467, Total Images: 13
# Key: 6e76147f1c, Total Images: 7
# Key: eeb01ef33d, Total Images: 7
# Key: 0c4b2ee781, Total Images: 18
# Key: 5dfaadecd6, Total Images: 9
# Key: c66dd404bb, Total Images: 5
# Key: 6897fe604e, Total Images: 38
# Key: d49ce267c0, Total Images: 19
# Key: 835a983edc, Total Images: 24
# Key: 02f2cf1394, Total Images: 21
# Key: 4b93315549, Total Images: 7
# Key: c7cfa6559f, Total Images: 12
# Key: a049f5bb72, Total Images: 9
# Key: 83430d1971, Total Images: 16
# Key: 498d8e8a46, Total Images: 54
# Key: 663f46975f, Total Images: 10
# Key: 9ea30671bb, Total Images: 14
# Key: 30238981e0, Total Images: 29
# Key: 2b7090317a, Total Images: 10
# Key: b37328ccdd, Total Images: 7
# Key: 2d9348305e, Total Images: 9
# Key: a9638cecc1, Total Images: 19
# Key: a1fb2e5829, Total Images: 21
# Key: 7d30dd78c7, Total Images: 30
# Key: 143fbcf23e, Total Images: 10
# Key: d9207bdf85, Total Images: 16
# Key: fcfbc754b6, Total Images: 10
# Key: 3ac674a041, Total Images: 9
# Key: b2bfc13d9f, Total Images: 3
# Key: 24d403717f, Total Images: 17
# Key: 8a91803d43, Total Images: 14
# Key: aa9272d2a3, Total Images: 18
# Key: 5ac8164f7d, Total Images: 11
# Key: 201b349e1e, Total Images: 15
# Key: 156511d955, Total Images: 30
# Key: 6c32f3ba23, Total Images: 15
# Key: 88cb957abb, Total Images: 20
# Key: 25486e218b, Total Images: 20
# Key: 6e8c0f4754, Total Images: 10
# Key: 2fa6f3cf74, Total Images: 17
# Key: b38f3983bb, Total Images: 41
# Key: 834a12c1ef, Total Images: 13
# Key: d68ac1ff1e, Total Images: 4
# Key: ac051cb67e, Total Images: 12
# Key: 4cfd8b0b65, Total Images: 13
# Key: aea59d9062, Total Images: 20
# Key: a7599132c1, Total Images: 11
# Key: 63658b6506, Total Images: 45
# Key: 7e606ebe9c, Total Images: 2
# Key: 211c7b683e, Total Images: 2
# Key: 510b4f55c5, Total Images: 14
# Key: fc05292b4b, Total Images: 39
# Key: 741231bf55, Total Images: 14
# Key: 4d575261fc, Total Images: 7
# Key: da3c1f891c, Total Images: 10
# Key: b337e9d7d7, Total Images: 29
# Key: 7fa8c7403c, Total Images: 7
# Key: 683f548db1, Total Images: 16
# Key: 989beded76, Total Images: 8
# Key: 198e47a6da, Total Images: 7
# Key: 6cc2910415, Total Images: 22
# Key: 0f02207ad9, Total Images: 7
# Key: 9494949007, Total Images: 14
# Key: bdba1a8471, Total Images: 18
# Key: 7eb9f5bb22, Total Images: 7
# Key: 1e76b8835a, Total Images: 11
# Key: 6429f59185, Total Images: 17
# Key: 942ff4186c, Total Images: 17
# Key: 64f4a981e1, Total Images: 22
# Key: ebf0104246, Total Images: 9
# Key: bb343a2421, Total Images: 14
# Key: d8ddbd2280, Total Images: 9
# Key: 4352922400, Total Images: 10
# Key: 7d636838e1, Total Images: 12
# Key: 41c0d79431, Total Images: 27
# Key: 74f44a2f10, Total Images: 11
# Key: fe59bb1f1f, Total Images: 17
# Key: 7c69f7b44c, Total Images: 14
# Key: ca9742e9f3, Total Images: 16
# Key: bcce5f4e0c, Total Images: 14
# Key: aace5d6e7a, Total Images: 14
# Key: 6823ccacf9, Total Images: 10
# Key: 41195f5804, Total Images: 19
# Key: f0cb60dd8b, Total Images: 7
# Key: e95bbcd6bd, Total Images: 11
# Key: 2a946b2ff1, Total Images: 20
# Key: 15e21e87a5, Total Images: 22
# Key: 33ae2fea52, Total Images: 21
# Key: 4829cf5917, Total Images: 23
# Key: 4bb6d0fde7, Total Images: 15
# Key: c79b4eed11, Total Images: 23
# Key: 1d27e91599, Total Images: 14
# Key: b5d3450cb6, Total Images: 14
# Key: b457103433, Total Images: 4
# Key: dcec3d05a8, Total Images: 4
# Key: f9c08ce5d4, Total Images: 10
# Key: 7765d0a754, Total Images: 16
# Key: 051cded3f3, Total Images: 9
# Key: 3609121b73, Total Images: 23
# Key: fd5a145f58, Total Images: 28
# Key: 7e4a754a51, Total Images: 18
# Key: a04237fc65, Total Images: 12
# Key: 348d10ff25, Total Images: 15
# Key: 8ab343eba0, Total Images: 6
# Key: cd956dbbd2, Total Images: 35
# Key: 4add31c4d9, Total Images: 29
# Key: d6a6fbdeb7, Total Images: 11
# Key: 01761331f9, Total Images: 17
# Key: 7cae37e64a, Total Images: 8
# Key: ec91dae006, Total Images: 15
# Key: 54721c62f4, Total Images: 12
# Key: efdc7d3655, Total Images: 9
# Key: 32445df081, Total Images: 4
# Key: 8cccff331c, Total Images: 1
# Key: efd60a2319, Total Images: 27
# Key: 5e0981272c, Total Images: 22
# Key: ff399fa343, Total Images: 17
# Key: b04f5ae0a1, Total Images: 19
# Key: 4c6b20248d, Total Images: 6
# Key: fe8a6a8074, Total Images: 14
# Key: fa4cd9118e, Total Images: 41
# Key: 003d7452e3, Total Images: 13
# Key: 988f8827d6, Total Images: 7
# Key: e6eaa5bbc9, Total Images: 5
# Key: 08e283af9b, Total Images: 36
# Key: 34b4c0b90f, Total Images: 33
# Key: ab2d6eaa62, Total Images: 8
# Key: 91106644bf, Total Images: 1
# Key: 71c54cb33b, Total Images: 9
# Key: 1a6fab9592, Total Images: 13
# Key: 7251cc61e0, Total Images: 6
# Key: 24d06bc076, Total Images: 16
# Key: 280f52fc32, Total Images: 19
# Key: e5a9ae4018, Total Images: 4
# Key: 1fe16c8fdc, Total Images: 11
# Key: fb40d96104, Total Images: 12
# Key: 3b2e32b22d, Total Images: 41
# Key: 3c3df80331, Total Images: 2
# Key: e06f8f0dc8, Total Images: 2
# Key: 4e3015fd7d, Total Images: 12
# Key: 7d77d7db9a, Total Images: 4
# Key: f8fa40e0c9, Total Images: 11
# Key: c8017ee8fc, Total Images: 11
# Key: 649050f9f3, Total Images: 15
# Key: fe7e7d9413, Total Images: 21
# Key: 5f00b1368c, Total Images: 28
# Key: 9304a96dbc, Total Images: 30
# Key: bc966e4708, Total Images: 5
# Key: b016cabbfb, Total Images: 18
# Key: cf23526d67, Total Images: 25
# Key: f42c7ba915, Total Images: 11
# Key: d583c822e9, Total Images: 3
# Key: 38fb156ae5, Total Images: 16
# Key: 758bdc4c98, Total Images: 19
# Key: 6a8272b89c, Total Images: 6
# Key: 1d5d2300e1, Total Images: 11
# Key: 9f62af1bc9, Total Images: 4
# Key: 09a268b276, Total Images: 9
# Key: 6d439a8166, Total Images: 36
# Key: 687a1d0886, Total Images: 8
# Key: 033d6f467d, Total Images: 24
# Key: 20dcc693d6, Total Images: 23
# Key: 1aec0f339b, Total Images: 16
# Key: 6cb87f8226, Total Images: 4
# Key: 1f0ca3c686, Total Images: 28
# Key: 0eaad5dc14, Total Images: 11
# Key: 9ba602b683, Total Images: 10
# Key: 20d204f8b1, Total Images: 9
# Key: f2bd15e45d, Total Images: 15
# Key: 712dc4b44e, Total Images: 16
# Key: 837424adc8, Total Images: 3
# Key: e562aba309, Total Images: 6
# Key: 65a0156c13, Total Images: 8
# Key: fe74ee6a97, Total Images: 1
# Key: 3e287b52c0, Total Images: 9
# Key: df0f14fb6c, Total Images: 24
# Key: 734637eac1, Total Images: 37
# Key: df353b9f3b, Total Images: 13
# Key: c08f6e7c85, Total Images: 20
# Key: 59f5997a36, Total Images: 3
# Key: 2c53c92fa9, Total Images: 4
# Key: 2da8cadd2a, Total Images: 26
# Key: cbc80d92e2, Total Images: 8
# Key: a6ecd4c4ff, Total Images: 11
# Key: c839cf6d50, Total Images: 24
# Key: c2684d9732, Total Images: 5
# Key: dc7a57a3c6, Total Images: 6
# Key: 18e1084e61, Total Images: 11
# Key: 2e5587ddbd, Total Images: 16
# Key: 1bcb19ae4d, Total Images: 8
# Key: be5e66c813, Total Images: 6
# Key: 9fe45c897e, Total Images: 4
# Key: 338e366ea2, Total Images: 12
# Key: 7602fb98a0, Total Images: 10
# Key: 5a7ce76111, Total Images: 12
# Key: 59d674d3da, Total Images: 1
# Key: fd0469da23, Total Images: 7
# Key: d444abcd8e, Total Images: 8
# Key: 42085b30fe, Total Images: 19
# Key: c786ea1c1e, Total Images: 3
# Key: 56b7b2da55, Total Images: 12
# Key: 837c857393, Total Images: 15
# Key: da6b367f3e, Total Images: 1
# Key: 769bc7589b, Total Images: 4
# Key: 2333d7e903, Total Images: 45
# Key: d190d5373a, Total Images: 3
# Key: 2e26caeb01, Total Images: 6
# Key: 1776b02d2d, Total Images: 1
# Key: 06c757c31e, Total Images: 39
# Key: 2bce2cccf3, Total Images: 3
# Key: 7069ca49e8, Total Images: 15
# Key: 4ed471832d, Total Images: 16
# Key: c0365ac13e, Total Images: 5
# Key: e5809fe675, Total Images: 8
# Key: e36da4b809, Total Images: 5
# Key: 656d1fb62f, Total Images: 6
# Key: bda6081c66, Total Images: 34
# Key: 1aca4fde33, Total Images: 12
# Key: 4defa9aba2, Total Images: 19
# Key: b2fd074e63, Total Images: 9
# Key: 00e6e359e3, Total Images: 16
# Key: b8b40b16a2, Total Images: 14
# Key: 7d8e0502f1, Total Images: 18
# Key: d73c35d7fe, Total Images: 3
# Key: 86e5e0cfbe, Total Images: 5
# Key: c7fcc61bc7, Total Images: 11
# Key: e60513bdc6, Total Images: 40
# Key: 4921e0ec7a, Total Images: 10
# Key: 59a87a135e, Total Images: 28
# Key: 8c1e485745, Total Images: 16
# Key: 67742b37db, Total Images: 33
# Key: 1ab9bb2c74, Total Images: 1
# Key: 1be91fd765, Total Images: 13
# Key: 93cfdfe589, Total Images: 16
# Key: 1a1badafbf, Total Images: 3
# Key: 174d7d5a8e, Total Images: 24
# Key: e12e90fb96, Total Images: 4
# Key: eda373a7aa, Total Images: 8
# Key: fa932eddff, Total Images: 7
# Key: 4a7fa4e5c4, Total Images: 3
# Key: 1a00140bff, Total Images: 24
# Key: efee7f0cea, Total Images: 27
# Key: 256c123e72, Total Images: 20
# Key: 57b9e08206, Total Images: 4
# Key: 1f8c412e1f, Total Images: 18
# Key: 1f4f33e2ec, Total Images: 7
# Key: 6fb89e5fd8, Total Images: 18
# Key: bedfba9a93, Total Images: 10
# Key: 3885be0b5e, Total Images: 1
# Key: 74b9d3181a, Total Images: 8
# Key: 127fefe401, Total Images: 14
# Key: 265797763b, Total Images: 29
# Key: c657057005, Total Images: 29
# Key: f6b091e460, Total Images: 12
# Key: 94fdc2f488, Total Images: 22
# Key: 7b7f69280b, Total Images: 1
# Key: 609fde43bd, Total Images: 11
# Key: 9407ecaba5, Total Images: 18
# Key: 71776ec4ef, Total Images: 3
# Key: 7db4e9ee47, Total Images: 9
# Key: bb4528f998, Total Images: 15
# Key: 3d84337cc6, Total Images: 23
# Key: 8d6a6a1657, Total Images: 2
# Key: d826a9f4b3, Total Images: 23
# Key: 94e5749606, Total Images: 10
# Key: 21ac439a20, Total Images: 25
# Key: 0415bf7afa, Total Images: 1
# Key: d8910fc649, Total Images: 16
# Key: 2f2b5cf711, Total Images: 8
# Key: 21ffe50123, Total Images: 9
# Key: fdbaaf200f, Total Images: 12
# Key: 6529fa7f49, Total Images: 2
# Key: eef0017c6e, Total Images: 30
# Key: fe3a2caf45, Total Images: 16
# Key: 3e377c3466, Total Images: 24
# Key: a43a73004f, Total Images: 5
# Key: 1fac0bc059, Total Images: 11
# Key: 73dd2c57b8, Total Images: 33
# Key: ae5c642bc3, Total Images: 35
# Key: 86cac2e49d, Total Images: 15
# Key: 4aaf9d865d, Total Images: 22
# Key: cf2bf2c4ba, Total Images: 17
# Key: 8e86077310, Total Images: 7
# Key: f9aa4769f3, Total Images: 4
# Key: 0383ac8517, Total Images: 3
# Key: 8d2acb05cd, Total Images: 18
# Key: 30df442925, Total Images: 17
# Key: 3f14bbf319, Total Images: 13
# Key: 7d2f1bb671, Total Images: 5
# Key: 366c1db530, Total Images: 23
# Key: 328a98720b, Total Images: 10
# Key: 498c23a415, Total Images: 3
# Key: 80cbf44735, Total Images: 11
# Key: 85201bbac1, Total Images: 36
# Key: 63f9b023e6, Total Images: 16
# Key: a18d680ae1, Total Images: 20
# Key: 6037fb9489, Total Images: 19
# Key: 7cf61f429c, Total Images: 19
# Key: eeb411683f, Total Images: 24
# Key: e6da6c43f8, Total Images: 18
# Key: 773a2cbaf6, Total Images: 14
# Key: 1789bdd3a0, Total Images: 11
# Key: 2b366461e8, Total Images: 11
# Key: fe76e4d7dc, Total Images: 10
# Key: 82ba89c1a9, Total Images: 3
# Key: 149297d9e2, Total Images: 13
# Key: 0195e75131, Total Images: 18
# Key: 9d492fad93, Total Images: 6
# Key: 3d7f09e24e, Total Images: 20
# Key: 7c0e27bb02, Total Images: 21
# Key: 4c6d76a21c, Total Images: 3
# Key: d0eda228a2, Total Images: 6
# Key: ca1eee620d, Total Images: 9
# Key: 0449c87f7c, Total Images: 13
# Key: feedbf9a51, Total Images: 8
# Key: 232abae6bc, Total Images: 18
# Key: 463f1b3ade, Total Images: 9
# Key: 10d4bdebf8, Total Images: 3
# Key: ae29c62d3f, Total Images: 3
# Key: 45c3ec7ac2, Total Images: 5
# Key: cb284c2845, Total Images: 22
# Key: 3be6d4888e, Total Images: 15
# Key: 1383724dc2, Total Images: 22
# Key: 91640f5a96, Total Images: 2
# Key: abfa040b19, Total Images: 17
# Key: 12990443df, Total Images: 4
# Key: a8adcdb383, Total Images: 15
# Key: 63a0ec9aa5, Total Images: 26
# Key: 7671d0bd83, Total Images: 5
# Key: 3068dcc5f5, Total Images: 2
# Key: a699afec3c, Total Images: 8
# Key: c030f3cb80, Total Images: 10
# Key: 4906a7d6a1, Total Images: 25
# Key: 7095a7a034, Total Images: 4
# Key: 4ceaa00dcc, Total Images: 3
# Key: 53b161da5d, Total Images: 11
# Key: c2f3987b44, Total Images: 12
# Key: 0b836268f3, Total Images: 15
# Key: 54bd98c486, Total Images: 16
# Key: 9c9d68dbc3, Total Images: 6
# Key: c2b53d5b75, Total Images: 1
# Key: 75b7dd0fb1, Total Images: 39
# Key: 7e485a21e8, Total Images: 10
# Key: 4b56a58327, Total Images: 4
# Key: 32fe1e3532, Total Images: 11
# Key: b4ba3405d1, Total Images: 2
# Key: 11f69aae73, Total Images: 21
# Key: de2aafcaf4, Total Images: 20
# Key: 6985fa5d45, Total Images: 18
# Key: 5e58592b65, Total Images: 28
# Key: d97f5ef5c3, Total Images: 17
# Key: a498d4503a, Total Images: 2
# Key: 8fc298c429, Total Images: 6
# Key: 6bf622e301, Total Images: 42
# Key: 69b8e0aa1c, Total Images: 12
# Key: 0af7f609f3, Total Images: 2
# Key: 5b29d3a369, Total Images: 16
# Key: bc5bed4eb9, Total Images: 15
# Key: 9a8e7ee1b1, Total Images: 16
# Key: 8388a4cce9, Total Images: 11
# Key: 2003808245, Total Images: 22
# Key: 83cc6f22e1, Total Images: 25
# Key: a5508afbb8, Total Images: 9
# Key: f0ba76b9f0, Total Images: 24
# Key: bce9bf169e, Total Images: 20
# Key: fcfa713ded, Total Images: 1
# Key: 9c07aa6489, Total Images: 23
# Key: 0cd4fbd93f, Total Images: 14
# Key: 365acb7288, Total Images: 6
# Key: 7bb342c33f, Total Images: 20
# Key: 54614d9ca1, Total Images: 11
# Key: 7da598ae66, Total Images: 15
# Key: 11ca251516, Total Images: 22
# Key: 3330964b6a, Total Images: 8
# Key: cd78af911e, Total Images: 13
# Key: a2a793866c, Total Images: 2
# Key: 93dc6241d7, Total Images: 21
# Key: ce584408cc, Total Images: 12
# Key: f19fe97b1e, Total Images: 26
# Key: 368e628712, Total Images: 21
# Key: b60955f642, Total Images: 24
# Key: 59c9a7529c, Total Images: 1
# Key: 78c4a25ba8, Total Images: 9
# Key: 14b5a3326c, Total Images: 29
# Key: ce365aa65b, Total Images: 12
# Key: 00b7e03aad, Total Images: 20
# Key: f54465a317, Total Images: 34
# Key: 5d1f89240e, Total Images: 21
# Key: abcafa8679, Total Images: 13
# Key: cbe082a220, Total Images: 26
# Key: 204bdb8902, Total Images: 11
# Key: 9b951ae183, Total Images: 19
# Key: 93f5c6ed5b, Total Images: 20
# Key: 3aace88a8a, Total Images: 22
# Key: 8d87f7dbaa, Total Images: 7
# Key: ef901477f8, Total Images: 20
# Key: 91dbaf90f5, Total Images: 20
# Key: c138ea878f, Total Images: 41
# Key: 9996365030, Total Images: 34
# Key: be43fb8690, Total Images: 6
# Key: 8ba845b855, Total Images: 8
# Key: 3bd23fbca6, Total Images: 23
# Key: 5a99a38288, Total Images: 36
# Key: c6d6e4353f, Total Images: 7
# Key: b314b3755a, Total Images: 9
# Key: 525bb5a33a, Total Images: 34
# Key: 8de03aaeae, Total Images: 39
# Key: c009acfc0a, Total Images: 13
# Key: 002dd801a4, Total Images: 6
# Key: 8f2839770a, Total Images: 31
# Key: 87ac8c1678, Total Images: 4
# Key: 63acd425b0, Total Images: 26
# Key: cb37df1984, Total Images: 3
# Key: 97c550b0d1, Total Images: 7
# Key: db779f7884, Total Images: 37
# Key: d0e994333d, Total Images: 10
# Key: d11a223bc2, Total Images: 46
# Key: 6566e1ee16, Total Images: 13
# Key: f190117323, Total Images: 5
# Key: df5c8e9974, Total Images: 19
# Key: 506ca52cf7, Total Images: 9
# Key: 2797f0f3d3, Total Images: 34
# Key: 863b442c8f, Total Images: 9
# Key: f340e5fc3c, Total Images: 7
# Key: 9df610f8da, Total Images: 10
# Key: 2bd7da64be, Total Images: 12
# Key: 6f882bd5f6, Total Images: 37
# Key: 9263ae203f, Total Images: 72
# Key: 6a7f4f3df4, Total Images: 6
# Key: 5e2d5c8309, Total Images: 2
# Key: 45785bc205, Total Images: 8
# Key: 0b5e8c4a42, Total Images: 13
# Key: 1591e11d2b, Total Images: 5
# Key: 741531a5b9, Total Images: 14
# Key: e06069c510, Total Images: 14
# Key: 21d2ef40dd, Total Images: 3
# Key: d77205ec1a, Total Images: 33
# Key: c401691844, Total Images: 27
# Key: 5bddcb59b7, Total Images: 15
# Key: b56f3eecc7, Total Images: 4
# Key: e9c433ab84, Total Images: 39
# Key: bce6c86579, Total Images: 11
# Key: 73bd5b8291, Total Images: 6
# Key: 45878ae772, Total Images: 19
# Key: 0295103d74, Total Images: 21
# Key: 325d163309, Total Images: 20
# Key: c8e4852634, Total Images: 9
# Key: 67f3d78683, Total Images: 11
# Key: 5334288942, Total Images: 16
# Key: f46329381b, Total Images: 17
# Key: db4416c043, Total Images: 8
# Key: 17535b77e9, Total Images: 17
# Key: 764aa04c12, Total Images: 4
# Key: 393c0bc915, Total Images: 18
# Key: d7dc57a7b5, Total Images: 20
# Key: 3e8bd8e3c9, Total Images: 21
# Key: db533faf9c, Total Images: 1
# Key: fa9433a818, Total Images: 12
# Key: 956d3c9662, Total Images: 8
# Key: d14b61a580, Total Images: 23
# Key: ee71a6c446, Total Images: 13
# Key: c9abcc8686, Total Images: 14
# Key: d2f8e36004, Total Images: 10
# Key: 4b54eda1f8, Total Images: 5
# Key: e019659679, Total Images: 3
# Key: d506fd14b8, Total Images: 1
# Key: 7ad7cf1c04, Total Images: 15
# Key: 753f3da453, Total Images: 27
# Key: 82f864caf4, Total Images: 4
# Key: f5ef605e0a, Total Images: 35
# Key: e4fe45053d, Total Images: 3
# Key: 71b9256621, Total Images: 1
# Key: 81b782e9d7, Total Images: 34
# Key: cff4db1251, Total Images: 18
# Key: 243e0d6c70, Total Images: 12
# Key: 8719b1aab9, Total Images: 3
# Key: 6f4c3a3316, Total Images: 3
# Key: 807de40a35, Total Images: 15
# Key: 9e48a3c73c, Total Images: 26
# Key: 968cb89624, Total Images: 1
# Key: 25af0ffcce, Total Images: 12
# Key: 411c4e27d2, Total Images: 6
# Key: 474bbf8371, Total Images: 3
# Key: 6dcb3ae5a4, Total Images: 11
# Key: b5061e97a6, Total Images: 33
# Key: 48222a1e21, Total Images: 15
# Key: 6582e883a6, Total Images: 26
# Key: 1d6bcbb67d, Total Images: 16
# Key: c42da55e69, Total Images: 2
# Key: c0d054fcf4, Total Images: 8
# Key: 9bdd9e7a36, Total Images: 40
# Key: dbf07aeb16, Total Images: 10
# Key: c485680b4b, Total Images: 15
# Key: 1c89389ae5, Total Images: 41
# Key: 62146b49be, Total Images: 34
# Key: c6b20d580f, Total Images: 9
# Key: b82eb3a859, Total Images: 1
# Key: 08ea152200, Total Images: 8
# Key: b3b8991d32, Total Images: 11
# Key: e14e1b0131, Total Images: 21
# Key: 02b71c46a3, Total Images: 13
# Key: a5a368c47b, Total Images: 2
# Key: 8ce1c898e8, Total Images: 23
# Key: b8728997dc, Total Images: 15
# Key: c641cf762d, Total Images: 10
# Key: 68a488e42e, Total Images: 9
# Key: e6ad2a11c0, Total Images: 7
# Key: 682c4add38, Total Images: 15
# Key: 810a77c1b0, Total Images: 12
# Key: ce1f63745e, Total Images: 18
# Key: e5842b1776, Total Images: 1
# Key: 0d93167333, Total Images: 6
# Key: b7e18d1e2e, Total Images: 15
# Key: 9e61331f1f, Total Images: 9
# Key: bf364641cc, Total Images: 13
# Key: 4e2b2e7c96, Total Images: 12
# Key: dca28aa2fa, Total Images: 3
# Key: 3bef5ca802, Total Images: 7
# Key: fc042d31bd, Total Images: 11
# Key: 0c87ef54d4, Total Images: 6
# Key: ba700d4ca6, Total Images: 10
# Key: 0c9b7631f3, Total Images: 10
# Key: 272a64d386, Total Images: 11
# Key: caa71001d7, Total Images: 1
# Key: 3fc480f77d, Total Images: 11
# Key: da00751b60, Total Images: 9
# Key: 55f099a0d0, Total Images: 13
# Key: 17581db3fd, Total Images: 15
# Key: 7b50c990ee, Total Images: 10
# Key: b30ea39cb7, Total Images: 21
# Key: 9a337cf4d7, Total Images: 4
# Key: 647c906663, Total Images: 9
# Key: d71c8ab12c, Total Images: 19
# Key: 99e5335de6, Total Images: 2
# Key: 9f06c12ebd, Total Images: 11
# Key: b3149bfc8f, Total Images: 15
# Key: 83605ccd14, Total Images: 18
# Key: c75c02b922, Total Images: 21
# Key: 77bc544342, Total Images: 20
# Key: 26482bdf53, Total Images: 6
# Key: de0a0f9c78, Total Images: 11
# Key: 08dc02ee1c, Total Images: 25
# Key: 18153ee567, Total Images: 19
# Key: a4be10d369, Total Images: 4
# Key: 6a526bb401, Total Images: 22
# Key: 1f95b749d5, Total Images: 10
# Key: 12c57a9f5a, Total Images: 17
# Key: 0e7b9716aa, Total Images: 11
# Key: 7541d19a2f, Total Images: 17
# Key: 5e4b69e380, Total Images: 13
# Key: 09588cad1e, Total Images: 20
# Key: 47ec7578ef, Total Images: 3
# Key: 7168dc49b2, Total Images: 5
# Key: 3b5cbdc792, Total Images: 12
# Key: df8e485ccc, Total Images: 9
# Key: 35e8eea03d, Total Images: 19
# Key: 679f20c58f, Total Images: 17
# Key: db7ca7a886, Total Images: 13
# Key: 797ffe3996, Total Images: 6
# Key: ae083899cd, Total Images: 13
# Key: 4f9b772fc4, Total Images: 23
# Key: 3605ef95bb, Total Images: 6
# Key: 4d81fe001f, Total Images: 9
# Key: 92ae15121a, Total Images: 1
# Key: fd476137a0, Total Images: 18
# Key: 0bee906a7b, Total Images: 20
# Key: 93216adcf6, Total Images: 4
# Key: b101b427db, Total Images: 18
# Key: bba5c16d5f, Total Images: 5
# Key: 5dc10f0d3e, Total Images: 2
# Key: 238f919718, Total Images: 18
# Key: 73374692f9, Total Images: 22
# Key: 30034eef09, Total Images: 22
# Key: 8e1bd25712, Total Images: 25
# Key: 3904f47b56, Total Images: 15
# Key: 13268b2298, Total Images: 7
# Key: a3691879ef, Total Images: 19
# Key: fb43fe1a3d, Total Images: 7
# Key: ca849b1228, Total Images: 7
# Key: aee0af1c00, Total Images: 18
# Key: 1fc509b8d3, Total Images: 13
# Key: eefaf93e4c, Total Images: 7
# Key: a0c10a8a8e, Total Images: 31
# Key: 05aaa57168, Total Images: 3
# Key: c6a4a727c3, Total Images: 12
# Key: e79fcabcf6, Total Images: 11
# Key: 31cdfca2cc, Total Images: 9
# Key: ccee670227, Total Images: 14
# Key: aae4924fde, Total Images: 21
# Key: d93c6c020d, Total Images: 23
# Key: 483e2fded7, Total Images: 8
# Key: cdefa8052c, Total Images: 10
# Key: 535372d9cf, Total Images: 16
# Key: f63c3b9378, Total Images: 5
# Key: 7fbcad28a1, Total Images: 31
# Key: e47b8dd130, Total Images: 4
# Key: db684d2874, Total Images: 27
# Key: cdfa16a5db, Total Images: 26
# Key: 7f06daddaa, Total Images: 10
# Key: 97cc606933, Total Images: 11
# Key: 746592ec93, Total Images: 10
# Key: 2886d5e04a, Total Images: 18
# Key: 83b774c3e5, Total Images: 29
# Key: d54f09c5d7, Total Images: 5
# Key: 73b224b29b, Total Images: 27
# Key: db5a5db9cb, Total Images: 24
# Key: b2ff0a6c08, Total Images: 3
# Key: 9e9143c6b9, Total Images: 12
# Key: 0d6d244a0a, Total Images: 7
# Key: e9be9c3c5f, Total Images: 7
# Key: 990688aece, Total Images: 4
# Key: 55f66bf5ca, Total Images: 15
# Key: e667dc7e6d, Total Images: 1
# Key: 64be618ab2, Total Images: 10
# Key: a71c8a2292, Total Images: 11
# Key: 7a8af53c02, Total Images: 17
# Key: a051a64882, Total Images: 24
# Key: 8413cb414c, Total Images: 37
# Key: 826ce9c7cf, Total Images: 5
# Key: 0484d2cd01, Total Images: 9
# Key: f3d2d96ae9, Total Images: 17
# Key: 5a41b3f602, Total Images: 17
# Key: 280b951d83, Total Images: 1
# Key: 728bccc796, Total Images: 2
# Key: c0369e0f9f, Total Images: 38
# Key: e6e46f46a3, Total Images: 13
# Key: 722a84140d, Total Images: 18
# Key: e0ddda9e39, Total Images: 14
# Key: e800c03940, Total Images: 2
# Key: d404ba1311, Total Images: 10
# Key: 07ee298742, Total Images: 10
# Key: 2ba5e62fb8, Total Images: 14
# Key: 8af19d41bc, Total Images: 10
# Key: 6911e68fe0, Total Images: 3
# Key: bf424d3460, Total Images: 18
# Key: 7363ba6cc8, Total Images: 16
# Key: 9062eb2e27, Total Images: 23
# Key: ae169a7173, Total Images: 26
# Key: df6830347e, Total Images: 15
# Key: fa8399350e, Total Images: 10
# Key: a1e7301c36, Total Images: 19
# Key: c91a1f5cfd, Total Images: 5
# Key: 9bd76e4695, Total Images: 13
# Key: a5a646f240, Total Images: 23
# Key: d6a81e39d7, Total Images: 2
# Key: 8028c9d30e, Total Images: 14
# Key: 9091d0da42, Total Images: 18
# Key: 7762f0ec70, Total Images: 11
# Key: 6d69167248, Total Images: 8
# Key: 38cf5bff37, Total Images: 12
# Key: 5ae2c5d8dc, Total Images: 8
# Key: 94a389e4e4, Total Images: 22
# Key: 3868967c48, Total Images: 16
# Key: 576f66bae4, Total Images: 16
# Key: 5a7a16ff86, Total Images: 6
# Key: 66c49de9ed, Total Images: 11
# Key: e4d6a41d18, Total Images: 8
# Key: 829ba3f7b2, Total Images: 5
# Key: f78d3f3bcc, Total Images: 21
# Key: 85cee812e3, Total Images: 13
# Key: 2f751c302c, Total Images: 4
# Key: 5bb8221e76, Total Images: 22
# Key: 8be9c320c7, Total Images: 4
# Key: 6be3fe8ac1, Total Images: 9
# Key: aa415eae1a, Total Images: 19
# Key: 54c63f7cb0, Total Images: 34
# Key: 8e6c5be28b, Total Images: 26
# Key: 0675c2cc07, Total Images: 27
# Key: 3b8890f2df, Total Images: 9
# Key: 819dec0e65, Total Images: 1
# Key: 1539e68417, Total Images: 6
# Key: 190ba67365, Total Images: 16
# Key: 8a112718d2, Total Images: 11
# Key: 3b62696f08, Total Images: 16
# Key: e809f41338, Total Images: 22
# Key: 3052732682, Total Images: 20
# Key: 057ee24fb1, Total Images: 3
# Key: 867d424741, Total Images: 8
# Key: dd885bef58, Total Images: 7
# Key: e21bbeb327, Total Images: 3
# Key: d03ecaf66e, Total Images: 10
# Key: a07de7d30b, Total Images: 24
# Key: 5710d73d42, Total Images: 5
# Key: 17d557ac2d, Total Images: 11
# Key: 77ccf51705, Total Images: 34
# Key: e1a50640af, Total Images: 11
# Key: 35ca3d0cef, Total Images: 28
# Key: 1dfeeb501c, Total Images: 16
# Key: bd70ba273e, Total Images: 35
# Key: e869d58a64, Total Images: 9
# Key: 22717ad62f, Total Images: 4
# Key: 18acca1b7b, Total Images: 15
# Key: 479c930231, Total Images: 12
# Key: 465bb13969, Total Images: 8
# Key: 8f25640e8d, Total Images: 11
# Key: 27d38d6762, Total Images: 32
# Key: 75baa0516f, Total Images: 10
# Key: 37e9c9a969, Total Images: 11
# Key: c4c1a98326, Total Images: 16
# Key: 6affedeed4, Total Images: 9
# Key: f69b39679f, Total Images: 4
# Key: fc1b7eecc3, Total Images: 25
# Key: d537dfa050, Total Images: 19
# Key: d15ef74ff7, Total Images: 20
# Key: 8c6d3c0e73, Total Images: 5
# Key: cac14721c7, Total Images: 5
# Key: 8fe4a662ee, Total Images: 2
# Key: 1b9f03d193, Total Images: 2
# Key: 2ed3cac538, Total Images: 6
# Key: 628df83cd2, Total Images: 36
# Key: 642d92f47f, Total Images: 11
# Key: 7d42a9f75f, Total Images: 12
# Key: 25e42f5bc8, Total Images: 1
# Key: 4a533af033, Total Images: 24
# Key: 71f1cc0280, Total Images: 18
# Key: 524297b99d, Total Images: 13
# Key: 231182ed33, Total Images: 6
# Key: 49fcd1d8a1, Total Images: 16
# Key: 0133043103, Total Images: 15
# Key: c142939be2, Total Images: 14
# Key: faad7d2f41, Total Images: 20
# Key: ddd37493db, Total Images: 11
# Key: 89ac85f75b, Total Images: 7
# Key: 0f3cfb6fa3, Total Images: 9
# Key: 6de68c770f, Total Images: 9
# Key: 8840eaed72, Total Images: 18
# Key: 85959f3dbf, Total Images: 7
# Key: d6c12aaf55, Total Images: 11
# Key: 20fa4bb816, Total Images: 3
# Key: 6eccbe634a, Total Images: 15
# Key: 7d32e5c739, Total Images: 11
# Key: 5d7ad6b32a, Total Images: 7
# Key: c8e34b45aa, Total Images: 1
# Key: 36234c8b24, Total Images: 12
# Key: 6a89ce99ea, Total Images: 18
# Key: 46331133e3, Total Images: 22
# Key: 7db7a351fa, Total Images: 9
# Key: 43014595aa, Total Images: 11
# Key: ff8a5c3527, Total Images: 2
# Key: 1b4cec975b, Total Images: 4
# Key: 4e98dabe3e, Total Images: 14
# Key: 911be6bdff, Total Images: 11
# Key: 887407d205, Total Images: 10
# Key: cf96dd54be, Total Images: 12
# Key: 3a8bec319b, Total Images: 18
# Key: dd359c50e1, Total Images: 4
# Key: 8f424aa7f1, Total Images: 10
# Key: be4d9f35eb, Total Images: 11
# Key: 80c2e115cf, Total Images: 9
# Key: ec7d098dd8, Total Images: 10
# Key: e9816b0748, Total Images: 6
# Key: cefca0d339, Total Images: 18
# Key: 25965174ba, Total Images: 26
# Key: 12941a3532, Total Images: 16
# Key: cc3ca8964d, Total Images: 2
# Key: 97cce17f4f, Total Images: 12
# Key: 76e1a98d5e, Total Images: 8
# Key: 0bffe614b5, Total Images: 20
# Key: 2ac64f45df, Total Images: 12
# Key: 6cb0eae521, Total Images: 1
# Key: 097d6b6950, Total Images: 7
# Key: 7f7dde3246, Total Images: 12
# Key: 12c3b62904, Total Images: 1
# Key: 52e5c4216b, Total Images: 21
# Key: de13b8b741, Total Images: 33
# Key: f4f36571b4, Total Images: 34
# Key: d123de7398, Total Images: 6
# Key: 83584a3175, Total Images: 11
# Key: 55d90268af, Total Images: 13
# Key: ce2c33e7c5, Total Images: 19
# Key: e86873d6e3, Total Images: 8
# Key: 2abab1457a, Total Images: 5
# Key: dddd33024f, Total Images: 14
# Key: a3b09ec88b, Total Images: 16
# Key: c131143140, Total Images: 18
# Key: 9d24c1c7e4, Total Images: 1
# Key: 97284b24c2, Total Images: 9
# Key: 3156a247e9, Total Images: 10
# Key: 4c12f20a5c, Total Images: 16
# Key: 9b61dcadcb, Total Images: 18
# Key: c2a696154b, Total Images: 22
# Key: ea3eaf4af3, Total Images: 5
# Key: 8849a8cee8, Total Images: 2
# Key: bd4408d249, Total Images: 18
# Key: 111cfbb25c, Total Images: 11
# Key: d72ad74bfa, Total Images: 32
# Key: 2920b79bc7, Total Images: 7
# Key: 942772287f, Total Images: 6
# Key: 77ca27216c, Total Images: 15
# Key: 9829693a87, Total Images: 20
# Key: 36aa157fab, Total Images: 4
# Key: bf2092c87c, Total Images: 14
# Key: f2ecacac31, Total Images: 4
# Key: 007271d002, Total Images: 14
# Key: da235583f1, Total Images: 2
# Key: c364e6c7a4, Total Images: 18
# Key: 18e42bf26c, Total Images: 32
# Key: 58ad65e341, Total Images: 7
# Key: f4a2b5e061, Total Images: 12
# Key: aaac3da718, Total Images: 4
# Key: eb972e3c4d, Total Images: 4
# Key: d10694ed5f, Total Images: 6
# Key: 17f0434616, Total Images: 2
# Key: 60371314a3, Total Images: 25
# Key: 7e688b587e, Total Images: 1
# Key: 3d8cef3218, Total Images: 6
# Key: 883ab6a492, Total Images: 18
# Key: cf239c8a8b, Total Images: 10
# Key: e507341a41, Total Images: 20
# Key: 394411dba7, Total Images: 14
# Key: 0d7f9e2aa9, Total Images: 4
# Key: 71bbeec682, Total Images: 7
# Key: 4af7563114, Total Images: 36
# Key: 9288840cd6, Total Images: 9
# Key: 06354fc0d3, Total Images: 7
# Key: c0f9da3ada, Total Images: 4
# Key: 2bc47d33ce, Total Images: 19
# Key: feb6bd8b12, Total Images: 11
# Key: 356c55996a, Total Images: 11
# Key: d9e9af998e, Total Images: 23
# Key: 377e085f3a, Total Images: 4
# Key: 48bd6fc1b0, Total Images: 18
# Key: eb88261391, Total Images: 6
# Key: 89e29372fa, Total Images: 25
# Key: f06b27a737, Total Images: 13
# Key: 814fdd9722, Total Images: 9
# Key: c469ac6bdb, Total Images: 11
# Key: e3f6062fa7, Total Images: 26
# Key: deda179429, Total Images: 4
# Key: 73a90b87ab, Total Images: 18
# Key: d801237705, Total Images: 13
# Key: 442e259323, Total Images: 47
# Key: b53b65b0e9, Total Images: 25
# Key: 5a110ada1d, Total Images: 24
# Key: f01878cb90, Total Images: 18
# Key: 401ce8def6, Total Images: 8
# Key: 20370a5102, Total Images: 1
# Key: 826ba5a8b4, Total Images: 20
# Key: c434f899de, Total Images: 26
# Key: a023fe62f6, Total Images: 5
# Key: efe1eab047, Total Images: 22
# Key: 7e81d9303a, Total Images: 1
# Key: 012a483f0f, Total Images: 5
# Key: 85ac5e6bed, Total Images: 13
# Key: 8cdcf50aad, Total Images: 36
# Key: e75b60784e, Total Images: 17
# Key: 460a0e6d2a, Total Images: 16
# Key: d352f13241, Total Images: 6
# Key: e4e292f63a, Total Images: 3
# Key: a2772d89ba, Total Images: 7
# Key: 9cb852251e, Total Images: 1
# Key: b2165d5829, Total Images: 1
# Key: d76cd55ed5, Total Images: 18
# Key: 978899251a, Total Images: 22
# Key: 59134e671a, Total Images: 3
# Key: 718b0e44f0, Total Images: 13
# Key: b4fe5853dc, Total Images: 4
# Key: 6ed98315ec, Total Images: 22
# Key: c22b2cea95, Total Images: 6
# Key: 1464613f60, Total Images: 7
# Key: 95e342fd78, Total Images: 3
# Key: fe8a51ef88, Total Images: 5
# Key: b433a7ec2b, Total Images: 5
# Key: b67d8f3405, Total Images: 16
# Key: 47d34dd661, Total Images: 26
# Key: ea2b3949eb, Total Images: 10
# Key: 1149036e55, Total Images: 23
# Key: 3b5d2b3ffe, Total Images: 13
# Key: ed58609390, Total Images: 11
# Key: 9c7cf94eab, Total Images: 1
# Key: 2f69a19339, Total Images: 20
# Key: d02a440515, Total Images: 18
# Key: 2f059d3aa6, Total Images: 12
# Key: f81c5f14ce, Total Images: 2
# Key: d808089142, Total Images: 11
# Key: 0717ef84a1, Total Images: 12
# Key: 43df64fb6c, Total Images: 5
# Key: c1e9259d01, Total Images: 10
# Key: 48f8aa063c, Total Images: 35
# Key: 22ed8b6a50, Total Images: 8
# Key: dd934e924e, Total Images: 4
# Key: 7d744022fb, Total Images: 15
# Key: 9f8d3baf32, Total Images: 35
# Key: bbfa6c6935, Total Images: 7
# Key: 2589ca5ccc, Total Images: 3
# Key: 9abff06e1f, Total Images: 7
# Key: b3784f13ee, Total Images: 7
# Key: 951b86eb0a, Total Images: 28
# Key: e6873900b7, Total Images: 32
# Key: 10c93983f4, Total Images: 6
# Key: 1f84fb67e1, Total Images: 11
# Key: 6f7e7011be, Total Images: 11
# Key: 87f2d051ab, Total Images: 14
# Key: faef34e002, Total Images: 26
# Key: 2a52dadf27, Total Images: 9
# Key: cd25e02de7, Total Images: 17
# Key: 2e594b6a04, Total Images: 32
# Key: 2f717467c1, Total Images: 13
# Key: d1be2bfde8, Total Images: 5
# Key: 4edc0f4164, Total Images: 15
# Key: 8d328f2186, Total Images: 23
# Key: 0d8903498d, Total Images: 11
# Key: 15764cae26, Total Images: 9
# Key: 98ae7a4b67, Total Images: 24
# Key: 199fcd8f39, Total Images: 15
# Key: 8aa84c6332, Total Images: 2
# Key: a91d4dd17a, Total Images: 6
# Key: b0c486e6da, Total Images: 14
# Key: cb902c79df, Total Images: 4
# Key: 44b649bb7e, Total Images: 12
# Key: 73d53250b9, Total Images: 15
# Key: c2d6860e49, Total Images: 7
# Key: 552e9e0231, Total Images: 32
# Key: 508da68ae0, Total Images: 18
# Key: 52d68c46e6, Total Images: 9
# Key: 24f98fdde5, Total Images: 10
# Key: fd466ba406, Total Images: 15
# Key: 7250267e9b, Total Images: 6
# Key: eb3d95401d, Total Images: 14
# Key: 437807bde1, Total Images: 14
# Key: 6e28918d93, Total Images: 2
# Key: d9d07436bd, Total Images: 17
# Key: 7878d6b8ce, Total Images: 10
# Key: d92ab5e160, Total Images: 7
# Key: 7913c94b8c, Total Images: 20
# Key: 042067a38f, Total Images: 5
# Key: db9c59476d, Total Images: 14
# Key: 8815cd22cd, Total Images: 39
# Key: 4ad1240340, Total Images: 10
# Key: 22558cea8e, Total Images: 7
# Key: d0e53e8240, Total Images: 35
# Key: a297168a92, Total Images: 32
# Key: 8d1eb417a4, Total Images: 18
# Key: c883450fbb, Total Images: 9
# Key: 76bf1250a9, Total Images: 12
# Key: d80331e672, Total Images: 27
# Key: 8e4d057ab5, Total Images: 13
# Key: 5e3786a0a8, Total Images: 8
# Key: b5ce9d9668, Total Images: 3
# Key: e45c4924a7, Total Images: 12
# Key: 32657a9359, Total Images: 17
# Key: 70d4ba6baf, Total Images: 2
# Key: b43c08efd4, Total Images: 13
# Key: a95bc3dd18, Total Images: 15
# Key: 8bc89c89be, Total Images: 32
# Key: 8b6b138a4a, Total Images: 18
# Key: 0a31acdb1d, Total Images: 19
# Key: bb46877688, Total Images: 20
# Key: 81ae5c92ec, Total Images: 13
# Key: 03a3cdf1c0, Total Images: 1
# Key: 16e24036b0, Total Images: 10
# Key: ead201c5ec, Total Images: 10
# Key: 8762939dba, Total Images: 7
# Key: 6d45265fa2, Total Images: 6
# Key: a5f3ed7b24, Total Images: 14
# Key: 68005697c7, Total Images: 15
# Key: 59cf41adae, Total Images: 4
# Key: 76fc18bc3d, Total Images: 6
# Key: 40392b74ab, Total Images: 11
# Key: 2dc454754d, Total Images: 12
# Key: 1255330ef7, Total Images: 13
# Key: 91b13217d3, Total Images: 25
# Key: d0609a8982, Total Images: 6
# Key: 0f8e5f319d, Total Images: 16
# Key: ac07948b62, Total Images: 26
# Key: 3dc13a0342, Total Images: 16
# Key: 2a3319f8b0, Total Images: 29
# Key: 8b5cb81104, Total Images: 8
# Key: 99dc1dbdbf, Total Images: 30
# Key: c46ab88ca8, Total Images: 10
# Key: 53237ab061, Total Images: 22
# Key: 5ed0fb8973, Total Images: 2
# Key: 3e164477c5, Total Images: 26
# Key: ac87a39acc, Total Images: 6
# Key: ed26ad29c6, Total Images: 12
# Key: 80e947f3b2, Total Images: 7
# Key: 4dea3b0e38, Total Images: 8
# Key: 79d94e3f51, Total Images: 9
# Key: e3aec690e8, Total Images: 4
# Key: 8b5e5ba72d, Total Images: 8
# Key: 9fa272a667, Total Images: 17
# Key: 364d4483ef, Total Images: 36
# Key: dd15e3de0b, Total Images: 3
# Key: 232de61c7a, Total Images: 11
# Key: 425872d39b, Total Images: 2
# Key: 6af1ffbf07, Total Images: 6
# Key: bbf466068d, Total Images: 6
# Key: ac82a8d0c2, Total Images: 9
# Key: 2a4cfba39a, Total Images: 6
# Key: baab3d55b9, Total Images: 18
# Key: 0659764392, Total Images: 1
# Key: 7d2b61913e, Total Images: 28
# Key: 3a3ddaccef, Total Images: 3
# Key: d723380b69, Total Images: 53
# Key: adde014755, Total Images: 3
# Key: 7c27be4784, Total Images: 25
# Key: b409d7a499, Total Images: 9
# Key: af3ee19445, Total Images: 18
# Key: 332949d216, Total Images: 6
# Key: 6ef3639e5a, Total Images: 32
# Key: de8dad9797, Total Images: 27
# Key: 0ba18240d2, Total Images: 13
# Key: 9a7bb1a496, Total Images: 6
# Key: 68f97160d2, Total Images: 8
# Key: 1d0872eb6b, Total Images: 4
# Key: db1ee82757, Total Images: 9
# Key: 8e5b2c7d5a, Total Images: 16
# Key: c12da7de71, Total Images: 14
# Key: 371c99b0bd, Total Images: 40
# Key: 41d813db4e, Total Images: 34
# Key: 1522a8eade, Total Images: 19
# Key: 11658c649c, Total Images: 9
# Key: 8f5dbb05da, Total Images: 17
# Key: e8f86ce5d1, Total Images: 7
# Key: 36c542bc0e, Total Images: 18
# Key: 2dc73eca9b, Total Images: 9
# Key: 6f7fbe8502, Total Images: 31
# Key: 3fc1fd4c19, Total Images: 2
# Key: b7ccfca205, Total Images: 23
# Key: d6a1a96fa3, Total Images: 26
# Key: af0e05eeaa, Total Images: 8
# Key: c64aaf0497, Total Images: 37
# Key: 4904b68d3c, Total Images: 10
# Key: c42e74d1fd, Total Images: 4
# Key: 2eb8622033, Total Images: 27
# Key: e74444b503, Total Images: 8
# Key: c112c71e41, Total Images: 17
# Key: 841c9c0b39, Total Images: 25
# Key: 0f455bd3a2, Total Images: 34
# Key: aeda9ec5fb, Total Images: 16
# Key: 672ff0c8cb, Total Images: 3
# Key: d1a7c748fb, Total Images: 14
# Key: d251ca78d4, Total Images: 11
# Key: 7045501662, Total Images: 8
# Key: ab08749fc5, Total Images: 6
# Key: 2edf21d71f, Total Images: 31
# Key: ad45923b51, Total Images: 3
# Key: a93b193472, Total Images: 3
# Key: 1bc493cd3c, Total Images: 21
# Key: bc3f37a2fb, Total Images: 2
# Key: 823e0199ab, Total Images: 27
# Key: 599a8ad21e, Total Images: 18
# Key: 399b0e9065, Total Images: 9
# Key: d71df5f853, Total Images: 19
# Key: 2aed0fad06, Total Images: 8
# Key: 64bdb595db, Total Images: 18
# Key: 09cd4f055e, Total Images: 23
# Key: 177693feb4, Total Images: 10
# Key: 9d46ad1d2c, Total Images: 8
# Key: 7396077736, Total Images: 10
# Key: 3b3bc29cc5, Total Images: 16
# Key: 6129187125, Total Images: 25
# Key: fbd0b56665, Total Images: 19
# Key: 62410c8f4d, Total Images: 7
# Key: 66881305bf, Total Images: 17
# Key: 6ea33b7813, Total Images: 19
# Key: f983688cfa, Total Images: 16
# Key: 4585e75ded, Total Images: 16
# Key: 0147029b04, Total Images: 4
# Key: 82f5d1265a, Total Images: 17
# Key: 44304a49ae, Total Images: 7
# Key: 3d199d52dc, Total Images: 22
# Key: 76fd6b61de, Total Images: 12
# Key: 52963f76a6, Total Images: 12
# Key: 33d1f8a5ae, Total Images: 16
# Key: 0bf8d0c2ff, Total Images: 1
# Key: 3ded5749d2, Total Images: 19
# Key: 06d390ff74, Total Images: 2
# Key: a8ea66486f, Total Images: 15
# Key: 712413829e, Total Images: 6
# Key: 984eafcbf6, Total Images: 11
# Key: 0752df932c, Total Images: 1
# Key: 527668d4ba, Total Images: 2
# Key: 7d9990b7b1, Total Images: 8
# Key: 18399298ff, Total Images: 10
# Key: 3b9c060fbc, Total Images: 11
# Key: c71d3c0855, Total Images: 10
# Key: 358459f266, Total Images: 30
# Key: 1d29c70fad, Total Images: 27
# Key: e0f442ec7c, Total Images: 22
# Key: d410ecfc2d, Total Images: 11
# Key: aacf5b1b28, Total Images: 20
# Key: f25edc1864, Total Images: 7
# Key: 3377e4612a, Total Images: 4
# Key: d5d2f137c1, Total Images: 16
# Key: ee0c0b9409, Total Images: 7
# Key: 690c86a2ea, Total Images: 1
# Key: 143bbd006a, Total Images: 18
# Key: f6161cfafd, Total Images: 24
# Key: 8e1dd4c30d, Total Images: 20
# Key: d8796a79e8, Total Images: 18
# Key: 0e859bd9f7, Total Images: 18
# Key: 1be002efca, Total Images: 14
# Key: e235d8b1c4, Total Images: 5
# Key: bdf520a826, Total Images: 24
# Key: c96658da0c, Total Images: 13
# Key: 32f0873c5a, Total Images: 6
# Key: e7a73836c9, Total Images: 27
# Key: d1b9c844fb, Total Images: 30
# Key: 221fe71a8a, Total Images: 17
# Key: 25bee72aa5, Total Images: 22
# Key: 97b31d382b, Total Images: 3
# Key: 45dc66abea, Total Images: 30
# Key: 1e2323e335, Total Images: 12
# Key: 3b570c99ad, Total Images: 6
# Key: 81e82df58a, Total Images: 4
# Key: 9922c5f7fe, Total Images: 25
# Key: b3f8045ab0, Total Images: 15
# Key: 8b3d34327f, Total Images: 27
# Key: d6a6463e65, Total Images: 10
# Key: eec0713c9a, Total Images: 47
# Key: cb5de1d1da, Total Images: 20
# Key: 2ecf13aed0, Total Images: 18
# Key: 35ef07c8f0, Total Images: 18
# Key: 6624c34ea8, Total Images: 2
# Key: cb4ae406ed, Total Images: 3
# Key: d58c2e5458, Total Images: 3
# Key: 6c7259e4b8, Total Images: 32
# Key: c3b47ca26e, Total Images: 16
# Key: 9fb851d8a6, Total Images: 5
# Key: d695314a71, Total Images: 17
# Key: bc76857dcb, Total Images: 11
# Key: c4a0e25b16, Total Images: 13
# Key: 2cc7738e5e, Total Images: 27
# Key: 9360ff4ced, Total Images: 7
# Key: c9aca21d90, Total Images: 12
# Key: 935f11f4dd, Total Images: 14
# Key: 78db0e81da, Total Images: 15
# Key: b07c192bd0, Total Images: 35
# Key: 480563868c, Total Images: 24
# Key: dfedd6a556, Total Images: 25
# Key: 1eea6fe2f0, Total Images: 9
# Key: 2ab805a89e, Total Images: 13
# Key: 27e69f28f5, Total Images: 12
# Key: 2bc821422b, Total Images: 28
# Key: cc23bc0d9c, Total Images: 11
# Key: 2d7e22e529, Total Images: 13
# Key: afc8cce60e, Total Images: 8
# Key: 3d237fb2a2, Total Images: 9
# Key: 1b7eae36a8, Total Images: 4
# Key: 9b44f68ca2, Total Images: 18
# Key: 39a6267265, Total Images: 10
# Key: c22d54cbf1, Total Images: 2
# Key: a693c0a560, Total Images: 10
# Key: c7f4d0696c, Total Images: 41
# Key: 17e5929e43, Total Images: 4
# Key: f925b1d40c, Total Images: 15
# Key: 9358d02dd3, Total Images: 11
# Key: a59c8364d1, Total Images: 24
# Key: 30dfbb02be, Total Images: 10
# Key: efb5774a9f, Total Images: 19
# Key: 65039ff83a, Total Images: 29
# Key: 4915eef31b, Total Images: 14
# Key: e3d37481ed, Total Images: 18
# Key: 6a53e1f212, Total Images: 3
# Key: 3316b112c6, Total Images: 23
# Key: a4d4654cf6, Total Images: 7
# Key: ad5ded8b99, Total Images: 9
# Key: 3637a98336, Total Images: 21
# Key: 837fab7393, Total Images: 34
# Key: 6b3f3abb21, Total Images: 24
# Key: cae9c61036, Total Images: 13
# Key: 0c2653425d, Total Images: 13
# Key: 7e9a175f54, Total Images: 5
# Key: f9672f0525, Total Images: 29
# Key: 55569828c2, Total Images: 17
# Key: 8138503a1f, Total Images: 16
# Key: 91b3350349, Total Images: 4
# Key: a01db4cfe0, Total Images: 14
# Key: a53e66e7ac, Total Images: 14
# Key: 02c5143edb, Total Images: 3
# Key: 55d0f522f7, Total Images: 18
# Key: 43853eb399, Total Images: 14
# Key: bd74dca72c, Total Images: 7
# Key: 202100696f, Total Images: 8
# Key: 42dade79d8, Total Images: 23
# Key: 0e4dec0c77, Total Images: 7
# Key: 2af396bbdf, Total Images: 12
# Key: 662c65d140, Total Images: 32
# Key: b16c0fcf27, Total Images: 7
# Key: c695f31563, Total Images: 1
# Key: d6a2766a47, Total Images: 6
# Key: a094d5e1b8, Total Images: 56
# Key: 4a7bf38b48, Total Images: 21
# Key: ae964872ae, Total Images: 2
# Key: 93001be095, Total Images: 26
# Key: f962e72ed3, Total Images: 22
# Key: 27b6efdf8b, Total Images: 11
# Key: 184c8e48a0, Total Images: 14
# Key: 4994a56c2b, Total Images: 3
# Key: 4a7d8db05d, Total Images: 23
# Key: 172ff02a0c, Total Images: 7
# Key: 261c54bf5d, Total Images: 11
# Key: 80ad53a277, Total Images: 6
# Key: d18c8a3d3c, Total Images: 24
# Key: c86bbceeab, Total Images: 16
# Key: e586cbd81c, Total Images: 5
# Key: fa1594bb81, Total Images: 36
# Key: c3da9f0db3, Total Images: 15
# Key: 8127fd6e45, Total Images: 23
# Key: 66594becdd, Total Images: 22
# Key: f2075735f4, Total Images: 13
# Key: 35a1cfad9c, Total Images: 29
# Key: a27981b19a, Total Images: 14
# Key: cb39976de7, Total Images: 14
# Key: 342e577691, Total Images: 30
# Key: 85eaa7e8ae, Total Images: 9
# Key: e604a140c1, Total Images: 11
# Key: 9175fb5dd3, Total Images: 20
# Key: 1527c43c11, Total Images: 4
# Key: 689df7bf94, Total Images: 8
# Key: bafe5cbc02, Total Images: 1
# Key: 1925120187, Total Images: 14
# Key: 0369c913de, Total Images: 19
# Key: 60b175bc69, Total Images: 3
# Key: 8e0d259250, Total Images: 8
# Key: 6448ffa709, Total Images: 8
# Key: 4077dccf48, Total Images: 12
# Key: 79305b418a, Total Images: 14
# Key: 88cf7251fb, Total Images: 14
# Key: 9a83f26976, Total Images: 9
# Key: 388ac59fa2, Total Images: 11
# Key: 0371e47713, Total Images: 16
# Key: eb2b5f6887, Total Images: 13
# Key: cb8c9bd496, Total Images: 19
# Key: 532767e457, Total Images: 19
# Key: 3ca1b97add, Total Images: 29
# Key: b39e20e338, Total Images: 4
# Key: feb1f0c407, Total Images: 21
# Key: ec623657b3, Total Images: 35
# Key: a6e2f2bb87, Total Images: 12
# Key: 217006d7da, Total Images: 14
# Key: bbd4f6c5fa, Total Images: 22
# Key: 13b90cf2a7, Total Images: 5
# Key: ce45b10507, Total Images: 13
# Key: 089fda1133, Total Images: 8
# Key: d93db28c6e, Total Images: 1
# Key: 246999e97b, Total Images: 2
# Key: 93a25e64dc, Total Images: 41
# Key: caf8267b40, Total Images: 1
# Key: bf44d2cee9, Total Images: 35
# Key: c593095198, Total Images: 11
# Key: 88dadabdd5, Total Images: 26
# Key: 364fd83687, Total Images: 17
# Key: bf7f6d1733, Total Images: 32
# Key: 098987d6a8, Total Images: 12
# Key: 98d850bf92, Total Images: 42
# Key: 51507dab21, Total Images: 16
# Key: d965e39673, Total Images: 13
# Key: aab9dd06db, Total Images: 5
# Key: 292406cf23, Total Images: 12
# Key: ce830decc2, Total Images: 9
# Key: 31f078a797, Total Images: 9
# Key: fb21dc9d71, Total Images: 17
# Key: ce07d21651, Total Images: 10
# Key: bd41ad6996, Total Images: 20
# Key: 24c032b46c, Total Images: 8
# Key: bb430e5dc4, Total Images: 22
# Key: 925137a197, Total Images: 18
# Key: 9ffa4d6214, Total Images: 8
# Key: 690cc86512, Total Images: 5
# Key: 9d07ec3ca6, Total Images: 13
# Key: 4fc55cc810, Total Images: 11
# Key: 23b62f12e7, Total Images: 17
# Key: f1368f6ced, Total Images: 11
# Key: 35c3891ddf, Total Images: 9
# Key: f0fd37c297, Total Images: 4
# Key: 5b8d42f6fa, Total Images: 2
# Key: a4740d14a5, Total Images: 12
# Key: a54a3402f1, Total Images: 5
# Key: 459b10cf50, Total Images: 4
# Key: 70606cd27c, Total Images: 4
# Key: 306b0d3cfe, Total Images: 23
# Key: 4504cb20bb, Total Images: 32
# Key: 796d48ec75, Total Images: 23
# Key: 5d3e99e6de, Total Images: 38
# Key: 521e44adad, Total Images: 3
# Key: 482a3cc0cc, Total Images: 4
# Key: 2330bffd08, Total Images: 3
# Key: 53b8bdea01, Total Images: 12
# Key: e9a271069f, Total Images: 20
# Key: dafddd38c8, Total Images: 12
# Key: d46ab4cb37, Total Images: 18
# Key: 9823bef824, Total Images: 4
# Key: 94e12a6af2, Total Images: 26
# Key: 475dfd9000, Total Images: 7
# Key: cfdd46de5a, Total Images: 10
# Key: 1f716c56e6, Total Images: 12
# Key: dd58e98f2c, Total Images: 10
# Key: d1228bc608, Total Images: 15
# Key: 8ea4452252, Total Images: 1
# Key: 81c40c24ac, Total Images: 15
# Key: 19a8ffc81f, Total Images: 6
# Key: a5b7430b29, Total Images: 23
# Key: efac24690c, Total Images: 23
# Key: 2287c56ef0, Total Images: 2
# Key: 9263a8f90a, Total Images: 18
# Key: da06906505, Total Images: 7
# Key: d5cbd36ccd, Total Images: 2
# Key: 11962eedf2, Total Images: 6
# Key: 1a0021493b, Total Images: 23
# Key: adf5cdf4ab, Total Images: 6
# Key: 87c430612d, Total Images: 5
# Key: 23dd8732c2, Total Images: 9
# Key: 2a4a8f0aff, Total Images: 20
# Key: ef8d8be429, Total Images: 27
# Key: b5b7505bd9, Total Images: 23
# Key: da72964d97, Total Images: 20
# Key: 131f53b253, Total Images: 21
# Key: d4ddf7eb62, Total Images: 28
# Key: 58e62e1f6d, Total Images: 8
# Key: 9773e656d8, Total Images: 6
# Key: e08ca3b54f, Total Images: 31
# Key: ecec52ebfd, Total Images: 23
# Key: 474d8403a2, Total Images: 13
# Key: 1c5abad395, Total Images: 16
# Key: d53aec21d6, Total Images: 10
# Key: 30d26045d3, Total Images: 18
# Key: a1c5f9f44b, Total Images: 16
# Key: 27552d5a20, Total Images: 9
# Key: ee5b70817e, Total Images: 1
# Key: 51a187bbe0, Total Images: 10
# Key: 12349381a8, Total Images: 10
# Key: 7574e1023a, Total Images: 13
# Key: fa5ec0f759, Total Images: 26
# Key: cfb639fa0c, Total Images: 16
# Key: 4b273413cf, Total Images: 16
# Key: aba18bb27d, Total Images: 10
# Key: afd3f16396, Total Images: 2
# Key: 85b05adac0, Total Images: 1
# Key: b73cf365c2, Total Images: 19
# Key: c160755278, Total Images: 21
# Key: 9f7ff8cfe0, Total Images: 13
# Key: 183388a650, Total Images: 13
# Key: 9dc581b943, Total Images: 14
# Key: 1e37624878, Total Images: 4
# Key: 9b4f0ef434, Total Images: 32
# Key: 2c62210c61, Total Images: 16
# Key: b6ba6c3b7c, Total Images: 14
# Key: 866537d271, Total Images: 14
# Key: 77a892cc60, Total Images: 17
# Key: 470aaa615b, Total Images: 15
# Key: 9d2a9ba857, Total Images: 11
# Key: 260df3cd6e, Total Images: 9
# Key: 42aede7590, Total Images: 12
# Key: a4a8b5f753, Total Images: 22
# Key: 924ca92e11, Total Images: 17
# Key: b96c4d664b, Total Images: 4
# Key: 3c892584f4, Total Images: 11
# Key: 2785a9c05a, Total Images: 7
# Key: 91ffc47dae, Total Images: 6
# Key: b1c9cf1377, Total Images: 5
# Key: 9aafefb5e7, Total Images: 24
# Key: 3bfdfed733, Total Images: 3
# Key: 2bda239dd9, Total Images: 16
# Key: c8292c9df4, Total Images: 4
# Key: f033a0dda7, Total Images: 1
# Key: aab86698b9, Total Images: 29
# Key: 0859fc9d36, Total Images: 22
# Key: ab03e00424, Total Images: 16
# Key: 91aee14be9, Total Images: 17
# Key: 554ab58375, Total Images: 11
# Key: 659727d280, Total Images: 2
# Key: a104d169c1, Total Images: 5
# Key: e5d805732a, Total Images: 18
# Key: 5aa9d37f87, Total Images: 9
# Key: 6b722918d9, Total Images: 4
# Key: 40a8df8201, Total Images: 41
# Key: 493b2c8cf0, Total Images: 15
# Key: 241868c488, Total Images: 8
# Key: 8bbea379ac, Total Images: 22
# Key: 2fad8b67ec, Total Images: 5
# Key: ff0efd334d, Total Images: 15
# Key: 11a0fc0c9f, Total Images: 31
# Key: 9eb663709c, Total Images: 28
# Key: 3d9098c3c8, Total Images: 16
# Key: b1cedbeb15, Total Images: 7
# Key: 48dd98982c, Total Images: 8
# Key: 4cc0d5e780, Total Images: 14
# Key: 558642ca9d, Total Images: 13
# Key: 4e6bf645ac, Total Images: 3
# Key: ceea0b817a, Total Images: 4
# Key: 146f3842ec, Total Images: 11
# Key: c2458798fa, Total Images: 38
# Key: abce36fdcd, Total Images: 37
# Key: 70f6f23c9d, Total Images: 17
# Key: d1f565008b, Total Images: 11
# Key: 86c294afe7, Total Images: 12
# Key: d46e600833, Total Images: 28
# Key: 6f0929ec93, Total Images: 8
# Key: 71b1cde76e, Total Images: 18
# Key: 91f5caa281, Total Images: 10
# Key: dd650bf3e8, Total Images: 26
# Key: 5b9fab0115, Total Images: 27
# Key: ad87ed41ff, Total Images: 28
# Key: d05173a55d, Total Images: 36
# Key: d9ff034b70, Total Images: 4
# Key: 8521c3c8aa, Total Images: 28
# Key: b46a59df45, Total Images: 12
# Key: eda8c89644, Total Images: 26
# Key: c61e5495bd, Total Images: 4
# Key: 4c9b2a8c64, Total Images: 19
# Key: 5e5f2dbfb1, Total Images: 11
# Key: 4121d31381, Total Images: 37
# Key: 76b8fd058a, Total Images: 11
# Key: 181de1a77a, Total Images: 14
# Key: e3103c1b03, Total Images: 13
# Key: af2890bfa4, Total Images: 20
# Key: fad92017f0, Total Images: 14
# Key: f36bd0c1ae, Total Images: 25
# Key: 3ab595ea3d, Total Images: 23
# Key: 86ce912dfa, Total Images: 7
# Key: 271f413185, Total Images: 11
# Key: 4bda127ee9, Total Images: 21
# ...
# Key: a7dd367f7c, Total Images: 10
# Key: bffd4666b8, Total Images: 22
# Key: 7d34a3e848, Total Images: 16
# Key: a2b3deb38b, Total Images: 4
# Key: efbccaa2b3, Total Images: 18
# Key: 30655a4008, Total Images: 6
# Key: 9749464196, Total Images: 7
# Key: 7aff05246f, Total Images: 10
# Key: 17d1f0516f, Total Images: 19
# Key: 4b7c6a05c6, Total Images: 23
# Key: f8d0c1d29d, Total Images: 3
# Key: d5bef033da, Total Images: 3
# Key: 7e21d3fd4f, Total Images: 9
# Key: 754d9911e0, Total Images: 13
# Key: b80b8a9be3, Total Images: 11
# Key: 70337d9872, Total Images: 15
# Key: ff5dc6841a, Total Images: 13
# Key: cdad596bc5, Total Images: 1
# Key: 7401fc8f4c, Total Images: 5
# Key: c50c7cbaea, Total Images: 21
# Key: 42cffe37ec, Total Images: 7
# Key: 0a00538092, Total Images: 2
# Key: 03860881c7, Total Images: 18
# Key: 2cd67031ba, Total Images: 3
# Key: 034d98f3e0, Total Images: 23
# Key: 0301b7b081, Total Images: 6
# Key: 222e938be1, Total Images: 2
# Key: 46cecc040e, Total Images: 31
# Key: 089038d2cc, Total Images: 3
# Key: 7427532d05, Total Images: 3
# Key: 9deda97fad, Total Images: 6
# Key: 825f16528d, Total Images: 11
# Key: eb91e5a7d5, Total Images: 1
# Key: 01c170f4bf, Total Images: 24
# Key: e45c4b99a3, Total Images: 5
# Key: 9cf876a986, Total Images: 6
# Key: d24e7597c6, Total Images: 19
# Key: a3f9116c25, Total Images: 4
# Key: 9f63dbaa6b, Total Images: 9
# Key: 9753cdb3d6, Total Images: 8
# Key: a2a4696734, Total Images: 28
# Key: faacbe2380, Total Images: 15
# Key: 4fa00d9afe, Total Images: 35
# Key: 731e9ad531, Total Images: 46
# Key: 7f0afb45ed, Total Images: 7
# Key: e871710136, Total Images: 36
# Key: d9dbb35727, Total Images: 9
# Key: d2a1e4a611, Total Images: 17
# Key: 53bd3424be, Total Images: 11
# Key: d8d59de477, Total Images: 3
# Key: 656f0858dd, Total Images: 2
# Key: fc7b54d74e, Total Images: 5
# Key: d6e121ab60, Total Images: 2
# Key: 0916a7c0d7, Total Images: 6
# Key: 67af655228, Total Images: 14
# Key: 698f62cb82, Total Images: 11
# Key: 9fa8b4e6f6, Total Images: 19
# Key: 6082359f60, Total Images: 4
# Key: 22fe23efec, Total Images: 3
# Key: c97ca8abe0, Total Images: 5
# Key: d8d03456d0, Total Images: 13
# Key: 3533484bd5, Total Images: 8
# Key: f4b3a7719f, Total Images: 28
# Key: 46da999e11, Total Images: 21
# Key: 54fe41bee8, Total Images: 13
# Key: de3ef40ea1, Total Images: 24
# Key: 9042945a60, Total Images: 7
# Key: d1e83722a5, Total Images: 47
# Key: ea1ef179a1, Total Images: 13
# Key: c7237340c3, Total Images: 16
# Key: 4e4350c075, Total Images: 12
# Key: 199467e378, Total Images: 19
# Key: 38fb7a5374, Total Images: 11
# Key: 689de37b6b, Total Images: 15
# Key: 53bd7cdc63, Total Images: 12
# Key: 3b475c1765, Total Images: 18
# Key: d42f842cf5, Total Images: 12
# Key: 7bf7be3427, Total Images: 10
# Key: 070f569b86, Total Images: 7
# Key: 58f22b3162, Total Images: 2
# Key: d2c75cfdba, Total Images: 14
# Key: abad2c3135, Total Images: 24
# Key: d8f1b08955, Total Images: 17
# Key: b484c97bb1, Total Images: 9
# Key: 60506f7a7b, Total Images: 18
# Key: b2a8877217, Total Images: 11
# Key: c51fb448a6, Total Images: 24
# Key: 906e098438, Total Images: 7
# Key: e98e6c95d8, Total Images: 14
# Key: fe6ed057ec, Total Images: 2
# Key: ee37256404, Total Images: 6
# Key: 21c87052a5, Total Images: 15
# Key: 07457d60c7, Total Images: 6
# Key: 43e81521f6, Total Images: 9
# Key: 52bc1bd9a5, Total Images: 31
# Key: a50bb62754, Total Images: 10
# Key: 446aa729e2, Total Images: 36
# Key: b082024c8b, Total Images: 6
# Key: 6f66b6e068, Total Images: 26
# Key: 2944481024, Total Images: 7
# Key: 0e0838285b, Total Images: 24
# Key: f34b44e12d, Total Images: 1
# Key: 9a0cfcafa5, Total Images: 22
# Key: 0b0830456f, Total Images: 5
# Key: 164dc04cd5, Total Images: 11
# Key: 67bd31408b, Total Images: 30
# Key: 358fe31280, Total Images: 9
# Key: cc77798a89, Total Images: 1
# Key: fcb3dd54b8, Total Images: 3
# Key: 10e13eb1db, Total Images: 21
# Key: 2048e9abfd, Total Images: 16
# Key: e224845bd6, Total Images: 10
# Key: 9a9a82c29d, Total Images: 12
# Key: b9a3b9f7bb, Total Images: 31
# Key: 2b284e6441, Total Images: 16
# Key: e869fb8181, Total Images: 10
# Key: f5768fe71a, Total Images: 10
# Key: bb9438d263, Total Images: 3
# Key: 9fe0354972, Total Images: 11
# Key: 862d726354, Total Images: 22
# Key: c08e270cb3, Total Images: 25
# Key: 853e97eda3, Total Images: 14
# Key: f664e040a4, Total Images: 3
# Key: 44ce4723d1, Total Images: 6
# Key: 7de4d98dec, Total Images: 12
# Key: ee8e2ea848, Total Images: 2
# Key: 1490563981, Total Images: 24
# Key: 3b58deaaf0, Total Images: 37
# Key: c4b8110b96, Total Images: 22
# Key: 215aa791f8, Total Images: 11
# Key: 59b5bad0ed, Total Images: 25
# Key: 74708ee5f4, Total Images: 8
# Key: c4f7756df0, Total Images: 8
# Key: 2a8fe76ce6, Total Images: 1
# Key: 3afdd701a4, Total Images: 10
# Key: 79c3362ec9, Total Images: 2
# Key: 4d625aa253, Total Images: 32
# Key: 7f7d93b23b, Total Images: 15
# Key: 97167ee6eb, Total Images: 22
# Key: 1b94bc28cc, Total Images: 2
# Key: 7891b21b0b, Total Images: 9
# Key: 9f4f9a9806, Total Images: 7
# Key: fd74454535, Total Images: 36
# Key: 50606b623f, Total Images: 2
# Key: a501b84f4d, Total Images: 6
# Key: 08a78cb1d0, Total Images: 8
# Key: 2d72afd6c2, Total Images: 30
# Key: fcafa01660, Total Images: 25
# Key: 1cf0cfa72c, Total Images: 18
# Key: 3c550832ba, Total Images: 17
# Key: b9fd694085, Total Images: 8
# Key: f51f20e674, Total Images: 14
# Key: deb88f7ea2, Total Images: 11
# Key: a47c585aec, Total Images: 16
# Key: 5db53d2d2e, Total Images: 1
# Key: 5624376aff, Total Images: 11
# Key: d6c66f30f8, Total Images: 9
# Key: dd37d4928d, Total Images: 23
# Key: 00e2ceea40, Total Images: 5
# Key: b7847f979f, Total Images: 7
# Key: bd0b884fc3, Total Images: 19
# Key: 101165a49c, Total Images: 18
# Key: cce307ce7a, Total Images: 39
# Key: 9a96591a2a, Total Images: 22
# Key: fe4faee86e, Total Images: 13
# Key: 94bbf09849, Total Images: 22
# Key: 9c0bb177dd, Total Images: 4
# Key: 5265c8a54e, Total Images: 13
# Key: a39daddae6, Total Images: 22
# Key: 9154a14dad, Total Images: 33
# Key: a38feabaa3, Total Images: 4
# Key: 28523013e9, Total Images: 16
# Key: ae0e88f2f0, Total Images: 15
# Key: 03248cdb43, Total Images: 12
# Key: b29579cad1, Total Images: 4
# Key: 04beddff71, Total Images: 20
# Key: 0d3b6cc53d, Total Images: 6
# Key: a4229e0226, Total Images: 18
# Key: 5e9bdb1713, Total Images: 12
# Key: 4aa68d7ac5, Total Images: 15
# Key: 06eb83c16f, Total Images: 7
# Key: 08fb9c62f3, Total Images: 9
# Key: cc4448dde6, Total Images: 14
# Key: ea5292da3b, Total Images: 4
# Key: 855b6bc6f4, Total Images: 20
# Key: 0a561a7a2b, Total Images: 16
# Key: 2682044fcb, Total Images: 17
# Key: 8b720fbfb1, Total Images: 17
# Key: 7088fc462f, Total Images: 11
# Key: 408ccc551a, Total Images: 6
# Key: c528aa306f, Total Images: 5
# Key: 074949d3b3, Total Images: 4
# Key: e412fffbcb, Total Images: 12
# Key: 22aacfb115, Total Images: 1
# Key: 4feaeb892c, Total Images: 8
# Key: 99762c1880, Total Images: 12
# Key: 44cefa66dd, Total Images: 17
# Key: aa6a59d8f3, Total Images: 11
# Key: a02c2fcdb3, Total Images: 10
# Key: a8b7bc2c4e, Total Images: 8
# Key: 7ec09af194, Total Images: 35
# Key: 7ed0d012d2, Total Images: 22
# Key: c9b6b47fde, Total Images: 22
# Key: b0d2bd51d4, Total Images: 20
# Key: f9872510a0, Total Images: 3
# Key: 6476c09004, Total Images: 25
# Key: 47a6f92991, Total Images: 22
# Key: ba038b4a25, Total Images: 21
# Key: 3f2bc9b0ef, Total Images: 16
# Key: 857953009f, Total Images: 20
# Key: bfa2702047, Total Images: 12
# Key: 55195858dc, Total Images: 14
# Key: ad9ef076e4, Total Images: 12
# Key: f4db6323cf, Total Images: 17
# Key: 379462d545, Total Images: 22
# Key: 0d68210704, Total Images: 6
# Key: cb99f1bf6c, Total Images: 14
# Key: 1df7c555e2, Total Images: 8
# Key: 2501a93cf3, Total Images: 19
# Key: 22afcca39c, Total Images: 31
# Key: b09038605d, Total Images: 6
# Key: ff7bed3821, Total Images: 15
# Key: 780c86b7d7, Total Images: 11
# Key: a68fc5ef43, Total Images: 47
# Key: 0882a7246b, Total Images: 3
# Key: 4a9ec15fad, Total Images: 18
# Key: 372f7ecce0, Total Images: 21
# Key: d3674af7f1, Total Images: 2
# Key: 23aa8f3f79, Total Images: 16
# Key: 34fcd8dc21, Total Images: 10
# Key: dcdf67dad1, Total Images: 13
# Key: 8d8a691113, Total Images: 6
# Key: 4d8af1d995, Total Images: 3
# Key: 79f8c467a6, Total Images: 28
# Key: 6c76300732, Total Images: 4
# Key: 6dd51dc181, Total Images: 16
# Key: d2fcb3ecc3, Total Images: 7
# Key: 307d01c250, Total Images: 17
# Key: 90d4eb90b4, Total Images: 28
# Key: 78929bfba4, Total Images: 8
# Key: b2b9497647, Total Images: 4
# Key: 0cccccee3f, Total Images: 21
# Key: 81be3536fd, Total Images: 15
# Key: ca1daa8550, Total Images: 11
# Key: e619f7725d, Total Images: 26
# Key: 16e8961369, Total Images: 28
# Key: 88622c07d6, Total Images: 28
# Key: 1814c3106f, Total Images: 7
# Key: 3c77b6ecb9, Total Images: 13
# Key: 0575c65b88, Total Images: 11
# Key: 317e0dcc69, Total Images: 2
# Key: 91e058f26f, Total Images: 12
# Key: 77ee611e87, Total Images: 8
# Key: 339a3a1894, Total Images: 33
# Key: 3bab7ef285, Total Images: 7
# Key: 19bc7ab392, Total Images: 8
# Key: 3c425da1a5, Total Images: 22
# Key: 645a24b4fc, Total Images: 21
# Key: 038802cc08, Total Images: 21
# Key: 798be958dd, Total Images: 20
# Key: febd94d43c, Total Images: 2
# Key: 08edb729c4, Total Images: 37
# Key: 625e62d4eb, Total Images: 17
# Key: 7ecd394833, Total Images: 6
# Key: 15d71e2442, Total Images: 18
# Key: 4f12ecd669, Total Images: 11
# Key: 1922da67a6, Total Images: 2
# Key: 3a460a6e2b, Total Images: 18
# Key: 1a13070160, Total Images: 30
# Key: bb3b86baef, Total Images: 5
# Key: bd0079daa9, Total Images: 7
# Key: cd666e6130, Total Images: 4
# Key: 47f3657563, Total Images: 16
# Key: e9ebcf9f84, Total Images: 22
# Key: 95cb2cdc6f, Total Images: 9
# Key: 7f695eed61, Total Images: 10
# Key: ac0c7e23ca, Total Images: 7
# Key: d6c7aa2562, Total Images: 8
# Key: 3cdda54324, Total Images: 7
# Key: 1cae55326f, Total Images: 22
# Key: 09eb8039f9, Total Images: 6
# Key: f8be3adcf3, Total Images: 6
# Key: 3c37b8a263, Total Images: 15
# Key: 03e4cd8519, Total Images: 34
# Key: ccea212799, Total Images: 24
# Key: 59ee6f3474, Total Images: 8
# Key: 1c7e4b4018, Total Images: 15
# Key: 88e30b7185, Total Images: 38
# Key: 52bc9837ec, Total Images: 8
# Key: 577dd9f75a, Total Images: 15
# Key: 3c9138d0df, Total Images: 7
# Key: 34658b0794, Total Images: 7
# Key: 787e148d7c, Total Images: 6
# Key: 47c520d8f8, Total Images: 23
# Key: 8444736722, Total Images: 11
# Key: c017aed8b4, Total Images: 24
# Key: 2e1df4c845, Total Images: 22
# Key: 0f26302a2d, Total Images: 7
# Key: 57910c8209, Total Images: 12
# Key: d838923d0c, Total Images: 5
# Key: bab29fb080, Total Images: 2
# Key: 1fb3187ea7, Total Images: 3
# Key: a3e64138ce, Total Images: 12
# Key: 1ffe0d2581, Total Images: 54
# Key: c0a9bf432d, Total Images: 19
# Key: aff90a6dc1, Total Images: 1
# Key: f543566ea0, Total Images: 19
# Key: 770122cd4d, Total Images: 2
# Key: f90a641fff, Total Images: 4
# Key: 3d361025e0, Total Images: 10
# Key: 161cd71113, Total Images: 8
# Key: ce88d5c1b0, Total Images: 22
# Key: e3d0299ad1, Total Images: 27
# Key: c92550279b, Total Images: 37
# Key: 31fd7b0cea, Total Images: 2
# Key: ab1fd16678, Total Images: 29
# Key: fbeac4e9f8, Total Images: 16
# Key: 8dc0aa672b, Total Images: 6
# Key: d89f0a4dc4, Total Images: 29
# Key: 499916b551, Total Images: 18
# Key: 30b04d09a9, Total Images: 7
# Key: 2103c8416b, Total Images: 24
# Key: 09c9a4119c, Total Images: 20
# Key: 568be47c22, Total Images: 5
# Key: e1a23185ac, Total Images: 7
# Key: 208ce49823, Total Images: 2
# Key: 19d57aab05, Total Images: 7
# Key: 996bc60153, Total Images: 12
# Key: fcdbae10b7, Total Images: 6
# Key: 66e81b132c, Total Images: 1
# Key: f88102b015, Total Images: 13
# Key: a0dc34a840, Total Images: 8
# Key: 6d8fbb3359, Total Images: 21
# Key: aeafa32137, Total Images: 21
# Key: df4b9b6baa, Total Images: 6
# Key: 6bf583cad0, Total Images: 13
# Key: 2129cabdf6, Total Images: 22
# Key: 771568f876, Total Images: 14
# Key: 898ffcf589, Total Images: 9
# Key: 540fdbf3d5, Total Images: 15
# Key: 4842f7dc2a, Total Images: 11
# Key: 3f604cb7de, Total Images: 34
# Key: 828439b269, Total Images: 38
# Key: 709a64e61d, Total Images: 8
# Key: 5884624f69, Total Images: 6
# Key: 86bd727c99, Total Images: 8
# Key: 455b10e843, Total Images: 40
# Key: a6036d1abf, Total Images: 6
# Key: 02f48e4201, Total Images: 7
# Key: c21ebc825e, Total Images: 20
# Key: 6447ad4d67, Total Images: 26
# Key: 859037f61c, Total Images: 12
# Key: f21535b4c0, Total Images: 16
# Key: 7cfc893ce0, Total Images: 23
# Key: 7cab74caa4, Total Images: 17
# Key: 187aaa0ffc, Total Images: 9
# Key: 45d3c4b2bd, Total Images: 1
# Key: 12ac29f738, Total Images: 20
# Key: 56503bdebc, Total Images: 24
# Key: 7eabee3f45, Total Images: 31
# Key: 029ae7b95d, Total Images: 1
# Key: 392de4fe3e, Total Images: 4
# Key: 04dce840dc, Total Images: 6
# Key: 1dfeeb9666, Total Images: 16
# Key: eda8ce279b, Total Images: 19
# Key: d5f49da5e1, Total Images: 24
# Key: 4aa18ca949, Total Images: 9
# Key: 4caf78c1a0, Total Images: 17
# Key: 564b3444fd, Total Images: 1
# Key: e6c07cc2f7, Total Images: 12
# Key: f3c651f271, Total Images: 17
# Key: 200f71b520, Total Images: 8
# Key: c3ca25b338, Total Images: 21
# Key: 9df4b0cab6, Total Images: 13
# Key: b2d0c31d84, Total Images: 15
# Key: da2b5183f5, Total Images: 499
# Key: 6700fb5092, Total Images: 19
# Key: 2469fdbbbe, Total Images: 7
# Key: 3ff7f25231, Total Images: 7
# Key: ae3aadcff2, Total Images: 11
# Key: c1f7adafba, Total Images: 15
# Key: 2823329193, Total Images: 12
# Key: 56981fda12, Total Images: 15
# Key: 448a7e246e, Total Images: 2
# Key: bec4f967a9, Total Images: 25
# Key: 45c708a57a, Total Images: 12
# Key: ec9549e003, Total Images: 1
# Key: 0110d98841, Total Images: 14
# Key: f231544134, Total Images: 12
# Key: 90229732dd, Total Images: 19
# Key: 381b099202, Total Images: 21
# Key: 8153abe91b, Total Images: 18
# Key: 72f20abb9a, Total Images: 14
# Key: 9b1c6f137b, Total Images: 17
# Key: 19dbc8fc21, Total Images: 9
# Key: 3e3b02b9e8, Total Images: 19
# Key: 55933380f8, Total Images: 22
# Key: 7e63912e74, Total Images: 14
# Key: b226d2858e, Total Images: 25
# Key: 3557526750, Total Images: 11
# Key: 2d5189b984, Total Images: 12
# Key: 7abe1bb743, Total Images: 26
# Key: 2edadbdc58, Total Images: 6
# Key: e2cd11eb72, Total Images: 14
# Key: 72a573765e, Total Images: 20
# Key: aacb183437, Total Images: 9
# Key: 97460f92b1, Total Images: 29
# Key: 3754450a18, Total Images: 5
# Key: bca081959a, Total Images: 8
# Key: eb405c25d4, Total Images: 3
# Key: 6d64e49069, Total Images: 28
# Key: ab4504b173, Total Images: 19
# Key: f9e11a2527, Total Images: 10
# Key: 3fa57246a8, Total Images: 19
# Key: c8dce5212d, Total Images: 10
# Key: 8334b89c69, Total Images: 12
# Key: b2d87722c3, Total Images: 13
# Key: 8472a73581, Total Images: 3
# Key: 9e190f6a41, Total Images: 16
# Key: 3f51b5b288, Total Images: 7
# Key: 10ec3bee8d, Total Images: 16
# Key: a5498cf0ff, Total Images: 8
# Key: 2abe81e632, Total Images: 17
# Key: fad13d5437, Total Images: 16
# Key: 8678e4bcb9, Total Images: 19
# Key: 2e06056cde, Total Images: 13
# Total Dataset Size: 107752
# Verifying Train Loader...
# Batch 1
# Key Name: ('af12e593e3', 'af12e593e3', 'af12e593e3', 'af12e593e3', 'af12e593e3', 'af12e593e3', 'af12e593e3', 'af12e593e3', 'af12e593e3', 'af12e593e3', 'af12e593e3', 'af12e593e3', 'af12e593e3', 'af12e593e3', 'af12e593e3', '1f14a84d7d', '1f14a84d7d', '1f14a84d7d', '1f14a84d7d', '1f14a84d7d', '1f14a84d7d', '1f14a84d7d', '1f14a84d7d', '1f14a84d7d', '0784304a91', '0784304a91', '0784304a91', '0784304a91', '0784304a91', '0784304a91', '0784304a91', '0784304a91')
# Image Tensor Shape: torch.Size([32, 3, 224, 224])
# Label Tensor Shape: torch.Size([32, 53])
# Non-zero Labels: (tensor([ 0,  0,  0,  1,  1,  1,  2,  2,  2,  3,  3,  3,  4,  4,  4,  5,  5,  5,
#          6,  6,  6,  7,  7,  7,  8,  8,  8,  9,  9,  9, 10, 10, 10, 11, 11, 11,
#         12, 12, 12, 13, 13, 13, 14, 14, 14, 15, 15, 15, 15, 15, 16, 16, 16, 16,
#         16, 17, 17, 17, 17, 17, 18, 18, 18, 18, 18, 19, 19, 19, 19, 19, 20, 20,
#         20, 20, 20, 21, 21, 21, 21, 21, 22, 22, 22, 22, 22, 23, 23, 23, 23, 23,
#         24, 24, 24, 25, 25, 25, 26, 26, 26, 27, 27, 27, 28, 28, 28, 29, 29, 29,
#         30, 30, 30, 31, 31, 31]), tensor([11, 31, 48, 11, 31, 48, 11, 31, 48, 11, 31, 48, 11, 31, 48, 11, 31, 48,
#         11, 31, 48, 11, 31, 48, 11, 31, 48, 11, 31, 48, 11, 31, 48, 11, 31, 48,
#         11, 31, 48, 11, 31, 48, 11, 31, 48, 11, 33, 39, 46, 48, 11, 33, 39, 46,
#         48, 11, 33, 39, 46, 48, 11, 33, 39, 46, 48, 11, 33, 39, 46, 48, 11, 33,
#         39, 46, 48, 11, 33, 39, 46, 48, 11, 33, 39, 46, 48, 11, 33, 39, 46, 48,
#         14, 43, 49, 14, 43, 49, 14, 43, 49, 14, 43, 49, 14, 43, 49, 14, 43, 49,
#         14, 43, 49, 14, 43, 49]))

# %%
# Check if CUDA is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
import torch
import torch.nn as nn
from torchvision.models import vit_b_16

class VITIngredientDetector(nn.Module):
   def __init__(self, output_size=100):
       super().__init__()
       # Load pretrained ViT
       self.vit = vit_b_16(pretrained=True)
       
       # Replace classifier head with more sophisticated head
       self.head = nn.Sequential(
           nn.Linear(768, 1024),
           nn.LayerNorm(1024),
           nn.ReLU(),
           nn.Dropout(0.3),
           nn.Linear(1024, 512),
           nn.LayerNorm(512),
           nn.ReLU(),
           nn.Dropout(0.2),
           nn.Linear(512, output_size)
       )
       self.vit.heads = self.head
       
       # Initially freeze all parameters
       for param in self.vit.parameters():
           param.requires_grad = False
           
       # Unfreeze head parameters
       for param in self.head.parameters():
           param.requires_grad = True
           
       # Unfreeze last two transformer layers for fine-tuning
       for param in self.vit.encoder.layers[-2:].parameters():
           param.requires_grad = True
           
   def unfreeze_last_n_layers(self, n):
       """Unfreeze the last n transformer layers"""
       for param in self.vit.encoder.layers[-n:].parameters():
           param.requires_grad = True
           
   def forward(self, x):
       return self.vit(x)
# Out:
# '\nimport torch\nimport torch.nn as nn\nfrom torchvision.models import vit_l_16\n\nclass VITIngredientDetector(nn.Module):\n    def __init__(self, output_size=100):\n        super().__init__()\n        self.vit = vit_l_16(pretrained=True)\n        \n        # Simpler head with stronger regularization\n        self.head = nn.Sequential(\n            nn.Linear(1024, 512),\n            nn.LayerNorm(512),\n            nn.ReLU(),\n            nn.Dropout(0.6),  # Increased dropout\n            nn.Linear(512, output_size)\n        )\n        self.vit.heads = self.head\n        \n        # Freeze more layers\n        for param in self.vit.parameters():\n            param.requires_grad = False\n            \n        # Only unfreeze head\n        for param in self.head.parameters():\n            param.requires_grad = True\n\n    def forward(self, x):\n        return self.vit(x)\n'

# %%
import torch
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report
import matplotlib.pyplot as plt
from tqdm import tqdm
import numpy as np

def compute_accuracy(y_true, y_pred):
    """
    Compute accuracy as ratio of correctly predicted positive labels to total positive labels
    y_true: ground truth labels
    y_pred: predicted labels
    """
    total_samples = y_true.shape[0]
    accuracies = []
        
    for i in range(total_samples):
        true_positives = np.sum(np.logical_and(y_true[i] == 1, y_pred[i] == 1))
        total_positives = np.sum(y_true[i] == 1)
        if total_positives > 0:  # Avoid division by zero
            accuracies.append(true_positives / total_positives)
        
    return np.mean(accuracies) if accuracies else 0.0


def save_predictions(epoch, labels, predictions, key_names, save_dir="validation_results", samples_per_epoch=10):
    """
    Save validation predictions and labels to text files
    """
    # Create epoch directory
    epoch_dir = os.path.join(save_dir, f"epoch_{epoch+1}")
    os.makedirs(epoch_dir, exist_ok=True)
    
    # Save specified number of samples
    for i in range(min(samples_per_epoch, len(labels))):
        # Get current key and remove any invalid characters
        current_key = str(key_names[i]).replace('/', '_').replace('\\', '_')
        print(f"Sample {i+1} key: {current_key}")  # Debug print
        
        filename = os.path.join(epoch_dir, f"sample_{i+1}_{current_key}.txt")
        
        with open(filename, 'w') as f:
            f.write(f"Sample Key: {current_key}\n\n")  # Add key to file content
            f.write("Ground Truth Labels:\n")
            label_indices = np.where(labels[i] == 1)[0]
            f.write(", ".join([list(ingredient_dict.keys())[idx] for idx in label_indices]))
            f.write("\n\nPredicted Labels:\n")
            
            pred_indices = np.where(predictions[i] == 1)[0]
            f.write(", ".join([list(ingredient_dict.keys())[idx] for idx in pred_indices]))
            
            true_positives = np.sum(np.logical_and(labels[i] == 1, predictions[i] == 1))
            total_positives = np.sum(labels[i] == 1)
            accuracy = true_positives / total_positives if total_positives > 0 else 0
            f.write(f"\n\nSample Accuracy: {accuracy:.4f}")



def custom_multilabel_metrics(y_true, y_pred, class_names):
    """
    Custom metric calculation that consolidates predictions for all label groups
    (e.g., flour1-4, agent1-2, etc.) based on ground truth
    """
    print("Entering custom_multilabel_metrics")
    # Create copies to avoid modifying originals
    y_true_modified = y_true.copy()
    y_pred_modified = y_pred.copy()
    
    # Create a dictionary to group indices by base label
    base_label_groups = {}
    for i, name in enumerate(class_names):
        # Extract base label by removing trailing numbers
        base_label = ''.join(char for char in name if not char.isdigit())
        if base_label not in base_label_groups:
            base_label_groups[base_label] = []
        base_label_groups[base_label].append(i)
    print(base_label_groups)
    
    # For each sample
    for i in range(len(y_true)):
        # Handle each base label group
        for base_indices in base_label_groups.values():
            # Only process groups with multiple variants (len > 1)
            if len(base_indices) > 1:
                # Check if any variant exists in ground truth
                true_variant_indices = [idx for idx in base_indices if y_true[i, idx] == 1]
                if true_variant_indices:
                    true_variant_idx = true_variant_indices[0]  # Get the ground truth variant index
                    # If any variant was predicted, consolidate to the correct one
                    if any(y_pred[i, idx] == 1 for idx in base_indices):
                        # Zero out all variant predictions
                        for idx in base_indices:
                            y_pred_modified[i, idx] = 0
                        # Set the correct variant to 1
                        y_pred_modified[i, true_variant_idx] = 1
    
    # Calculate metrics using modified predictions
    precision = precision_score(y_true_modified, y_pred_modified, average="samples", zero_division=0)
    recall = recall_score(y_true_modified, y_pred_modified, average="samples", zero_division=0)
    f1 = f1_score(y_true_modified, y_pred_modified, average="samples", zero_division=0)
    #accuracy = compute_accuracy(y_true_modified, y_pred_modified)
    
    # Generate classification report
    '''
    class_report = classification_report(y_true_modified, y_pred_modified, 
                                      target_names=class_names, digits=8, 
                                      zero_division=0)
    '''
    return precision, recall, f1


def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs, device, class_names=list(ingredient_dict.keys())):
    # At the start of your training script, calculate thresholds
    #frequencies = torch.tensor(list(ingredient_freq_dict.values()), dtype=torch.float)
    #mean_freq = frequencies.mean()
    
    # Track losses and metrics
    train_losses = []
    val_losses = []
    precision_values = []
    recall_values = []
    f1_values = []
    accuracy_values = []  # Add at start with other metric lists

    # Learning rate scheduler
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=2, verbose=True)

    # Warmup settings
    warmup_epochs = 3
    initial_lr = optimizer.param_groups[0]['lr']

    # Move model to the specified device
    model.to(device)
    best_f1 = 0
    best_epoch = 0

    for epoch in range(num_epochs):
        # Warmup logic for learning rate
        if epoch < warmup_epochs:
            lr_scale = min(1.0, float(epoch + 1) / warmup_epochs)
            for pg in optimizer.param_groups:
                pg['lr'] = lr_scale * initial_lr

        # Training phase
        model.train()
        train_loss = 0.0

        print(f"\nEpoch [{epoch + 1}/{num_epochs}]")
        with tqdm(total=len(train_loader), desc="Training", unit="batch") as pbar:
            for batch_idx, (key_name, images, labels) in enumerate(train_loader):
                # Move data to device
                images, labels = images.to(device), labels.to(device)

                # Forward pass
                outputs = model(images)

                # Calculate false positive indices
                probabilities = torch.sigmoid(outputs)  # Convert logits to probabilities
                preds = (probabilities > 0.35).float()  # Binary predictions
                false_positive_indices = (preds == 1) & (labels == 0)

                # Adjust weights for loss
                weights = torch.ones_like(labels, device=device)  # Initialize weights
                weights[false_positive_indices] *= 2.0  # Penalize false positives more

                # Compute weighted loss
                loss = criterion(outputs, labels)* weights

                # Backward pass and optimization
                optimizer.zero_grad()
                loss.mean().backward()  # Reduce the loss for gradient calculation
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)  # Regularization: Gradient Clipping
                optimizer.step()

                train_loss += loss.mean().item()

                # Update progress bar
                pbar.set_postfix({"Loss": f"{loss.mean().item():.4f}"})
                pbar.update(1)

        train_losses.append(train_loss / len(train_loader))  # Average loss for the epoch

        # Validation phase
        model.eval()
        val_loss = 0.0
        all_labels = []
        all_preds = []
        val_key_names = []

        with torch.no_grad():
            with tqdm(total=len(val_loader), desc="Validation", unit="batch") as pbar:
                for batch_idx, (key_name, images, labels) in enumerate(val_loader):
                    val_key_names.extend(key_name)
                    
                    images, labels = images.to(device), labels.to(device)

                    # Forward pass
                    outputs = model(images)

                    # Compute loss
                    loss = criterion(outputs, labels)
                    val_loss += loss.item()

                    # Collect predictions and labels
                    probabilities = torch.sigmoid(outputs)
                    preds = (probabilities > 0.35).float()  # Binary predictions
                    
                    # In your validation loop, replace the prediction line with:
                    #probabilities = torch.sigmoid(outputs)
                    
                    all_labels.append(labels.cpu())
                    all_preds.append(preds.cpu())

                    # Update progress bar
                    pbar.set_postfix({"Val Loss": f"{loss.item():.4f}"})
                    pbar.update(1)

        val_losses.append(val_loss / len(val_loader))  # Average validation loss

        # Flatten label and prediction lists
        all_labels = torch.cat(all_labels, dim=0).numpy()
        all_preds = torch.cat(all_preds, dim=0).numpy()        

        # Compute metrics
        precision, recall, f1= custom_multilabel_metrics(
        all_labels, all_preds, class_names
        )
        
        #precision = precision_score(all_labels, all_preds, average="samples", zero_division=0)
        #recall = recall_score(all_labels, all_preds, average="samples", zero_division=0)
        #f1 = f1_score(all_labels, all_preds, average="samples", zero_division=0)
        #accuracy = compute_accuracy(all_labels, all_preds)

        precision_values.append(precision)
        recall_values.append(recall)
        f1_values.append(f1)
        #accuracy_values.append(accuracy)
        save_predictions(epoch, all_labels, all_preds, val_key_names, samples_per_epoch=10)
        
        if f1 > best_f1:
            best_f1 = f1
            best_epoch = epoch
            print(f"\nSaving best model with F1: {f1:.4f}")
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'scheduler_state_dict': scheduler.state_dict(),
                'f1_score': f1,
                'precision': precision,
                'recall': recall,
                'train_loss': train_losses[-1],
                'val_loss': val_losses[-1]
            }, 'best_model_checkpoint.pth')

        

        # Log epoch summary
        print(f"Epoch Summary - Train Loss: {train_losses[-1]:.4f}, Val Loss: {val_losses[-1]:.4f}")
        print(f"Precision: {precision:.4f}, Recall: {recall:.4f}, F1-Score: {f1:.4f}")

        # Class-wise performance
        if class_names is not None:
            class_report = classification_report(all_labels, all_preds, target_names=class_names, digits=8,zero_division=0)
            print("\nClass-wise Performance:")
            print(class_report)

        # Step the scheduler based on F1 score
        scheduler.step(f1)

    # Plot graphs
    plot_training_metrics(train_losses, val_losses, precision_values, recall_values, f1_values, accuracy_values)




def plot_training_metrics(train_losses, val_losses, precision_values, recall_values, f1_values, accuracy_values):
    """Plots training/validation loss and metrics (precision, recall, F1)."""
    epochs = range(1, len(train_losses) + 1)

    # Plot losses
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label="Train Loss", marker='o')
    plt.plot(epochs, val_losses, label="Validation Loss", marker='o')
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title("Training and Validation Loss")
    plt.legend()

    # Plot metrics
    plt.subplot(1, 2, 2)
    plt.plot(epochs, precision_values, label="Precision", marker='o')
    plt.plot(epochs, recall_values, label="Recall", marker='o')
    plt.plot(epochs, f1_values, label="F1 Score", marker='o')
    #plt.plot(epochs, accuracy_values, label="Accuracy", marker='o')
    plt.xlabel("Epoch")
    plt.ylabel("Score")
    plt.title("Precision, Recall and F1 Score")
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
def calculate_aggressive_weights(ingredient_freq_dict):
    """Calculate aggressive class weights based on frequency"""
    frequencies = torch.tensor(list(ingredient_freq_dict.values()), dtype=torch.float)
    total_samples = frequencies.sum()
    
    # Aggressive inverse frequency weighting
    weights = total_samples / (frequencies + 1)
    
    # Apply log scaling to prevent extreme values while maintaining strong weighting
    weights = torch.log1p(weights) * 2  # Multiply by 2 to make weights more aggressive
    
    # Normalize weights but preserve ratios
    weights = weights * (len(frequencies) / weights.sum()) * 3  # Multiply by 3 for stronger weighting
    
    # Clip extremely high weights but allow for more extreme ratios
    weights = torch.clamp(weights, min=1.0, max=25.0)
    
    #print("Weight Statistics:")
    #print(f"Mean weight: {weights.mean():.2f}")
    #print(f"Max weight: {weights.max():.2f}")
    #print(f"Min weight: {weights.min():.2f}")
    
    return weights

model = VITIngredientDetector(output_size=len(ingredient_dict))
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
# Calculate class weights
class_weights = calculate_aggressive_weights(ingredient_freq_dict)
class_weights = class_weights.to(device)

# Initialize criterion
criterion = nn.BCEWithLogitsLoss(pos_weight=class_weights)

# Train with the two-phase approach
train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=20, device=device, class_names=list(ingredient_dict.keys()))
# Out:
# Epoch [1/20]
# Training: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15706/15706 [50:01<00:00,  5.23batch/s, Loss=0.5513]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3357/3357 [13:44<00:00,  4.07batch/s, Val Loss=0.4122]
# Entering custom_multilabel_metrics
# {'agent': [0, 1], 'allium': [2], 'berries': [3], 'butter': [4, 5, 6, 7], 'cheese': [8], 'chocolate': [9], 'cinnamon': [10], 'condiment': [11], 'cream': [12, 13], 'dried fruit, jams, snacks, treats': [14], 'fats': [15], 'flour': [16, 17, 18, 19], 'fruit': [20], 'juice': [21, 22], 'liquids': [23], 'meat and substitutes': [24], 'milk': [25, 26, 27], 'nightshade': [28], 'nut': [29, 30], 'oil': [31, 32, 33], 'pepper': [34, 35], 'powder': [36, 37], 'root vegetable': [38], 'sauce': [39], 'seasoning': [40, 41], 'seed': [42], 'starches': [43], 'syrup': [44, 45, 46], 'vegetable': [47], 'vinegar': [48], 'water': [49, 50, 51], 'wheat product': [52]}
# Sample 1 key: af12e593e3
# Sample 2 key: af12e593e3
# Sample 3 key: af12e593e3
# Sample 4 key: af12e593e3
# Sample 5 key: af12e593e3
# Sample 6 key: af12e593e3
# Sample 7 key: af12e593e3
# Sample 8 key: af12e593e3
# Sample 9 key: af12e593e3
# Sample 10 key: af12e593e3
#
# Saving best model with F1: 0.3140
# Epoch Summary - Train Loss: 0.5769, Val Loss: 0.5253
# Precision: 0.3070, Recall: 0.3891, F1-Score: 0.3140
#
# Class-wise Performance:
#                                    precision    recall  f1-score   support
#
#                            agent1  0.29601680 0.53158753 0.38027553      9814
#                            agent2  0.28276278 0.56104129 0.37601524     10026
#                            allium  0.24620338 0.54795175 0.33975118      8373
#                           berries  0.39220682 0.62522290 0.48203170     10094
#                           butter1  0.15189594 0.09084916 0.11369637      7584
#                           butter2  0.15365938 0.11519958 0.13167868      7691
#                           butter3  0.16021250 0.15180819 0.15589716      7549
#                           butter4  0.13608563 0.01209075 0.02220836      7361
#                            cheese  0.26754003 0.38512310 0.31573975      9545
#                         chocolate  0.31418597 0.68403909 0.43059525     10131
#                          cinnamon  0.28357381 0.41831908 0.33801264     10994
#                         condiment  0.30305016 0.51982424 0.38288424      9786
#                            cream1  0.19043970 0.27409348 0.22473434      7253
#                            cream2  0.18433079 0.23708887 0.20740741      7145
# dried fruit, jams, snacks, treats  0.22901382 0.50128649 0.31439541     11271
#                              fats  0.24307657 0.50384253 0.32793998     12752
#                            flour1  0.20737058 0.45164989 0.28423669      7849
#                            flour2  0.22554905 0.39203461 0.28635160      7859
#                            flour3  0.20072609 0.50839552 0.28781592      7504
#                            flour4  0.17365035 0.46627610 0.25305723      6657
#                             fruit  0.23792165 0.49052609 0.32042594      9447
#                            juice1  0.24062535 0.25415819 0.24720670      8357
#                            juice2  0.19355792 0.31094232 0.23859393      8426
#                           liquids  0.24811569 0.34570766 0.28889229      8189
#              meat and substitutes  0.32400556 0.57520988 0.41451957     10125
#                             milk1  0.16279445 0.13081810 0.14506506      7713
#                             milk2  0.18706157 0.17513987 0.18090452      8222
#                             milk3  0.18307513 0.14116891 0.15941398      7785
#                        nightshade  0.26038647 0.30219780 0.27973843      8918
#                              nut1  0.22457112 0.43062156 0.29519612     10731
#                              nut2  0.20216294 0.31874503 0.24740813      8797
#                              oil1  0.16822978 0.12478261 0.14328507      6900
#                              oil2  0.16526060 0.19732303 0.17987421      7247
#                              oil3  0.16159371 0.14370438 0.15212492      6576
#                           pepper1  0.19939391 0.43885870 0.27420413      8096
#                           pepper2  0.19226503 0.47895993 0.27438564      7961
#                           powder1  0.23587059 0.20020510 0.21657935      8776
#                           powder2  0.19301520 0.25317636 0.21903994      8579
#                    root vegetable  0.22330709 0.27209927 0.24530043      7817
#                             sauce  0.22673606 0.53520646 0.31852955      8791
#                        seasoning1  0.20474587 0.16681907 0.18384682      7655
#                        seasoning2  0.18371106 0.30164366 0.22834959      7605
#                              seed  0.24437038 0.46489329 0.32034955     12932
#                          starches  0.21011017 0.36934766 0.26784934     10792
#                            syrup1  0.20521456 0.18377274 0.19390269     10279
#                            syrup2  0.15406715 0.28501459 0.20001463      9596
#                            syrup3  0.16939945 0.18361884 0.17622277      9340
#                         vegetable  0.32149901 0.58589489 0.41517720      8068
#                           vinegar  0.25814242 0.45913629 0.33047838      8614
#                            water1  0.19260809 0.14033127 0.16236553      9841
#                            water2  0.24255406 0.12684020 0.16657327      9374
#                            water3  0.20380030 0.17459304 0.18806945      9399
#                     wheat product  0.30091230 0.62063733 0.40531166      9885
#
#                         micro avg  0.23413763 0.35495683 0.28215764    468071
#                         macro avg  0.22193651 0.34263808 0.25913063    468071
#                      weighted avg  0.22639260 0.35495683 0.26671667    468071
#                       samples avg  0.22085297 0.35700003 0.25004206    468071
#
#
# Epoch [2/20]
# Training: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15706/15706 [28:36<00:00,  9.15batch/s, Loss=0.5998]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3357/3357 [04:04<00:00, 13.75batch/s, Val Loss=0.4269]
# Entering custom_multilabel_metrics
# {'agent': [0, 1], 'allium': [2], 'berries': [3], 'butter': [4, 5, 6, 7], 'cheese': [8], 'chocolate': [9], 'cinnamon': [10], 'condiment': [11], 'cream': [12, 13], 'dried fruit, jams, snacks, treats': [14], 'fats': [15], 'flour': [16, 17, 18, 19], 'fruit': [20], 'juice': [21, 22], 'liquids': [23], 'meat and substitutes': [24], 'milk': [25, 26, 27], 'nightshade': [28], 'nut': [29, 30], 'oil': [31, 32, 33], 'pepper': [34, 35], 'powder': [36, 37], 'root vegetable': [38], 'sauce': [39], 'seasoning': [40, 41], 'seed': [42], 'starches': [43], 'syrup': [44, 45, 46], 'vegetable': [47], 'vinegar': [48], 'water': [49, 50, 51], 'wheat product': [52]}
# Sample 1 key: af12e593e3
# Sample 2 key: af12e593e3
# Sample 3 key: af12e593e3
# Sample 4 key: af12e593e3
# Sample 5 key: af12e593e3
# Sample 6 key: af12e593e3
# Sample 7 key: af12e593e3
# Sample 8 key: af12e593e3
# Sample 9 key: af12e593e3
# Sample 10 key: af12e593e3
#
# Saving best model with F1: 0.3145
# Epoch Summary - Train Loss: 0.5705, Val Loss: 0.5249
# Precision: 0.3107, Recall: 0.3869, F1-Score: 0.3145
#
# Class-wise Performance:
#                                    precision    recall  f1-score   support
#
#                            agent1  0.27419742 0.58222947 0.37281832      9814
#                            agent2  0.29926214 0.52184321 0.38038460     10026
#                            allium  0.25272048 0.55750627 0.34778722      8373
#                           berries  0.43872695 0.58450565 0.50123184     10094
#                           butter1  0.15420970 0.11616561 0.13251109      7584
#                           butter2  0.16886748 0.14133403 0.15387882      7691
#                           butter3  0.15026527 0.23261359 0.18258383      7549
#                           butter4  0.14282832 0.09618258 0.11495373      7361
#                            cheese  0.27391504 0.37558931 0.31679406      9545
#                         chocolate  0.32151188 0.66666667 0.43381078     10131
#                          cinnamon  0.27920973 0.41777333 0.33471797     10994
#                         condiment  0.26919942 0.60750051 0.37307813      9786
#                            cream1  0.19672544 0.21535916 0.20562101      7253
#                            cream2  0.22406877 0.10944717 0.14706159      7145
# dried fruit, jams, snacks, treats  0.24584194 0.44326147 0.31627259     11271
#                              fats  0.26098228 0.42628607 0.32375450     12752
#                            flour1  0.19799021 0.48948911 0.28194027      7849
#                            flour2  0.22297735 0.43835094 0.29559398      7859
#                            flour3  0.19728884 0.50426439 0.28361565      7504
#                            flour4  0.17025347 0.48129788 0.25153085      6657
#                             fruit  0.24869125 0.44754949 0.31972172      9447
#                            juice1  0.21965268 0.30573172 0.25564060      8357
#                            juice2  0.20991720 0.26477569 0.23417655      8426
#                           liquids  0.27087093 0.34827207 0.30473341      8189
#              meat and substitutes  0.30209743 0.61738272 0.40568517     10125
#                             milk1  0.17389456 0.10605471 0.13175485      7713
#                             milk2  0.17276403 0.21308684 0.19081849      8222
#                             milk3  0.19739430 0.10314708 0.13549312      7785
#                        nightshade  0.20199126 0.48228302 0.28473073      8918
#                              nut1  0.24386232 0.37303140 0.29492375     10731
#                              nut2  0.21737560 0.27361601 0.24227479      8797
#                              oil1  0.17944664 0.03289855 0.05560318      6900
#                              oil2  0.17276227 0.09907548 0.12593177      7247
#                              oil3  0.16979866 0.11541971 0.13742531      6576
#                           pepper1  0.19192810 0.56447628 0.28645752      8096
#                           pepper2  0.19238029 0.48649667 0.27572705      7961
#                           powder1  0.22507123 0.24304923 0.23371501      8776
#                           powder2  0.19632287 0.25515794 0.22190684      8579
#                    root vegetable  0.28064624 0.21555584 0.24383185      7817
#                             sauce  0.24989555 0.47628256 0.32780083      8791
#                        seasoning1  0.15949828 0.49170477 0.24086517      7655
#                        seasoning2  0.18366064 0.30742932 0.22994836      7605
#                              seed  0.23438719 0.48785957 0.31664534     12932
#                          starches  0.27698864 0.23489622 0.25421179     10792
#                            syrup1  0.21044438 0.14466388 0.17146152     10279
#                            syrup2  0.16532508 0.19476865 0.17884312      9596
#                            syrup3  0.16420336 0.22719486 0.19063019      9340
#                         vegetable  0.37498871 0.51474963 0.43389228      8068
#                           vinegar  0.29009511 0.41072672 0.34002883      8614
#                            water1  0.19139548 0.14104258 0.16240566      9841
#                            water2  0.20861841 0.18540644 0.19632872      9374
#                            water3  0.19537063 0.15086711 0.17025875      9399
#                     wheat product  0.35035399 0.56570561 0.43271686      9885
#
#                         micro avg  0.23582510 0.35179919 0.28236777    468071
#                         macro avg  0.22760633 0.34128349 0.25993453    468071
#                      weighted avg  0.23222727 0.35179919 0.26765517    468071
#                       samples avg  0.21976592 0.35241560 0.24725774    468071
#
#
# Epoch [3/20]
# Training: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15706/15706 [28:32<00:00,  9.17batch/s, Loss=0.6034]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3357/3357 [04:07<00:00, 13.58batch/s, Val Loss=0.4478]
# Entering custom_multilabel_metrics
# {'agent': [0, 1], 'allium': [2], 'berries': [3], 'butter': [4, 5, 6, 7], 'cheese': [8], 'chocolate': [9], 'cinnamon': [10], 'condiment': [11], 'cream': [12, 13], 'dried fruit, jams, snacks, treats': [14], 'fats': [15], 'flour': [16, 17, 18, 19], 'fruit': [20], 'juice': [21, 22], 'liquids': [23], 'meat and substitutes': [24], 'milk': [25, 26, 27], 'nightshade': [28], 'nut': [29, 30], 'oil': [31, 32, 33], 'pepper': [34, 35], 'powder': [36, 37], 'root vegetable': [38], 'sauce': [39], 'seasoning': [40, 41], 'seed': [42], 'starches': [43], 'syrup': [44, 45, 46], 'vegetable': [47], 'vinegar': [48], 'water': [49, 50, 51], 'wheat product': [52]}
# Sample 1 key: af12e593e3
# Sample 2 key: af12e593e3
# Sample 3 key: af12e593e3
# Sample 4 key: af12e593e3
# Sample 5 key: af12e593e3
# Sample 6 key: af12e593e3
# Sample 7 key: af12e593e3
# Sample 8 key: af12e593e3
# Sample 9 key: af12e593e3
# Sample 10 key: af12e593e3
#
# Saving best model with F1: 0.3150
# Epoch Summary - Train Loss: 0.5675, Val Loss: 0.5244
# Precision: 0.3037, Recall: 0.3975, F1-Score: 0.3150
#
# Class-wise Performance:
#                                    precision    recall  f1-score   support
#
#                            agent1  0.29103993 0.54809456 0.38019508      9814
#                            agent2  0.27157122 0.60492719 0.37485707     10026
#                            allium  0.23118164 0.64373582 0.34019187      8373
#                           berries  0.40717577 0.61274024 0.48924221     10094
#                           butter1  0.15167591 0.08293776 0.10723723      7584
#                           butter2  0.18981818 0.03393577 0.05757776      7691
#                           butter3  0.16452188 0.11008081 0.13190476      7549
#                           butter4  0.15226406 0.12471132 0.13711725      7361
#                            cheese  0.27487070 0.37862755 0.31851232      9545
#                         chocolate  0.34472233 0.63537657 0.44695181     10131
#                          cinnamon  0.29730640 0.40158268 0.34166538     10994
#                         condiment  0.26016530 0.64009810 0.36996131      9786
#                            cream1  0.22808160 0.14490556 0.17721946      7253
#                            cream2  0.19053940 0.22099370 0.20463971      7145
# dried fruit, jams, snacks, treats  0.25048457 0.44716529 0.32110092     11271
#                              fats  0.24418089 0.51827164 0.33196042     12752
#                            flour1  0.20311383 0.47037839 0.28371628      7849
#                            flour2  0.21975323 0.46685329 0.29883934      7859
#                            flour3  0.20295865 0.48267591 0.28575937      7504
#                            flour4  0.17714517 0.39447198 0.24449514      6657
#                             fruit  0.24252676 0.46289827 0.31829100      9447
#                            juice1  0.21685653 0.31434725 0.25665576      8357
#                            juice2  0.20097661 0.27842393 0.23344445      8426
#                           liquids  0.25888665 0.32995482 0.29013207      8189
#              meat and substitutes  0.31141869 0.60444444 0.41105551     10125
#                             milk1  0.16180917 0.17347336 0.16743837      7713
#                             milk2  0.19180433 0.21746534 0.20383037      8222
#                             milk3  0.18351425 0.13898523 0.15817557      7785
#                        nightshade  0.25142373 0.36633774 0.29819277      8918
#                              nut1  0.25828819 0.33324015 0.29101562     10731
#                              nut2  0.19461673 0.36739798 0.25444812      8797
#                              oil1  0.14663489 0.18724638 0.16447075      6900
#                              oil2  0.17909883 0.13053677 0.15100966      7247
#                              oil3  0.14951989 0.18232968 0.16430284      6576
#                           pepper1  0.20032573 0.47097332 0.28109104      8096
#                           pepper2  0.19380570 0.49441025 0.27845773      7961
#                           powder1  0.21945302 0.22675479 0.22304416      8776
#                           powder2  0.20179454 0.25690640 0.22603969      8579
#                    root vegetable  0.18923318 0.40156070 0.25724237      7817
#                             sauce  0.22347157 0.55841201 0.31920151      8791
#                        seasoning1  0.18564755 0.30111039 0.22968462      7655
#                        seasoning2  0.19938479 0.28126233 0.23334970      7605
#                              seed  0.21528473 0.54871636 0.30924106     12932
#                          starches  0.23192752 0.34395849 0.27704594     10792
#                            syrup1  0.19440507 0.20011674 0.19721956     10279
#                            syrup2  0.16154891 0.24781159 0.19559138      9596
#                            syrup3  0.16055078 0.24593148 0.19427412      9340
#                         vegetable  0.31700231 0.59506693 0.41364753      8068
#                           vinegar  0.22846424 0.55850940 0.32427878      8614
#                            water1  0.19713322 0.11878874 0.14824678      9841
#                            water2  0.20606442 0.20951568 0.20777572      9374
#                            water3  0.19384507 0.17491222 0.18389262      9399
#                     wheat product  0.32002972 0.61001517 0.41981411      9885
#
#                         micro avg  0.23198268 0.36865775 0.28477009    468071
#                         macro avg  0.22149657 0.35649771 0.26273106    468071
#                      weighted avg  0.22596557 0.36865775 0.27020993    468071
#                       samples avg  0.22141352 0.36770197 0.25221903    468071
#
#
# Epoch [4/20]
# Training: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15706/15706 [28:21<00:00,  9.23batch/s, Loss=0.6870]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3357/3357 [04:03<00:00, 13.79batch/s, Val Loss=0.4582]
# Entering custom_multilabel_metrics
# {'agent': [0, 1], 'allium': [2], 'berries': [3], 'butter': [4, 5, 6, 7], 'cheese': [8], 'chocolate': [9], 'cinnamon': [10], 'condiment': [11], 'cream': [12, 13], 'dried fruit, jams, snacks, treats': [14], 'fats': [15], 'flour': [16, 17, 18, 19], 'fruit': [20], 'juice': [21, 22], 'liquids': [23], 'meat and substitutes': [24], 'milk': [25, 26, 27], 'nightshade': [28], 'nut': [29, 30], 'oil': [31, 32, 33], 'pepper': [34, 35], 'powder': [36, 37], 'root vegetable': [38], 'sauce': [39], 'seasoning': [40, 41], 'seed': [42], 'starches': [43], 'syrup': [44, 45, 46], 'vegetable': [47], 'vinegar': [48], 'water': [49, 50, 51], 'wheat product': [52]}
# Sample 1 key: af12e593e3
# Sample 2 key: af12e593e3
# Sample 3 key: af12e593e3
# Sample 4 key: af12e593e3
# Sample 5 key: af12e593e3
# Sample 6 key: af12e593e3
# Sample 7 key: af12e593e3
# Sample 8 key: af12e593e3
# Sample 9 key: af12e593e3
# Sample 10 key: af12e593e3
#
# Saving best model with F1: 0.3295
# Epoch Summary - Train Loss: 0.5610, Val Loss: 0.5221
# Precision: 0.3186, Recall: 0.4115, F1-Score: 0.3295
#
# Class-wise Performance:
#                                    precision    recall  f1-score   support
#
#                            agent1  0.30142752 0.54004483 0.38690368      9814
#                            agent2  0.29368792 0.55735089 0.38467628     10026
#                            allium  0.25454545 0.55177356 0.34837688      8373
#                           berries  0.38749009 0.62968100 0.47975242     10094
#                           butter1  0.14807535 0.11919831 0.13207685      7584
#                           butter2  0.15636579 0.13717332 0.14614212      7691
#                           butter3  0.15033167 0.26718771 0.19240675      7549
#                           butter4  0.16462546 0.07852194 0.10632818      7361
#                            cheese  0.24107805 0.47700367 0.32028420      9545
#                         chocolate  0.32413388 0.65383476 0.43340858     10131
#                          cinnamon  0.28000000 0.42150264 0.33647981     10994
#                         condiment  0.26913591 0.63560188 0.37814998      9786
#                            cream1  0.20161044 0.27271474 0.23183310      7253
#                            cream2  0.18086775 0.29055283 0.22295012      7145
# dried fruit, jams, snacks, treats  0.23848023 0.47892822 0.31840972     11271
#                              fats  0.26967370 0.44071518 0.33460348     12752
#                            flour1  0.20507316 0.46247930 0.28414873      7849
#                            flour2  0.20730455 0.53950884 0.29951964      7859
#                            flour3  0.20452074 0.47627932 0.28616037      7504
#                            flour4  0.17093059 0.50383055 0.25526085      6657
#                             fruit  0.26714092 0.41738118 0.32577354      9447
#                            juice1  0.22434410 0.30082566 0.25701580      8357
#                            juice2  0.20038942 0.29314028 0.23804934      8426
#                           liquids  0.26460117 0.33581634 0.29598536      8189
#              meat and substitutes  0.33329598 0.58755556 0.42532351     10125
#                             milk1  0.15691869 0.19966291 0.17572888      7713
#                             milk2  0.19524719 0.19885673 0.19703543      8222
#                             milk3  0.19467709 0.13436095 0.15899073      7785
#                        nightshade  0.26082023 0.36084324 0.30278510      8918
#                              nut1  0.21957491 0.47749511 0.30081897     10731
#                              nut2  0.19331328 0.37990224 0.25623922      8797
#                              oil1  0.16405562 0.13507246 0.14815992      6900
#                              oil2  0.19040554 0.10625086 0.13639182      7247
#                              oil3  0.15879525 0.17077251 0.16456624      6576
#                           pepper1  0.19849349 0.53705534 0.28985700      8096
#                           pepper2  0.19236735 0.51413139 0.27997811      7961
#                           powder1  0.23910513 0.21068824 0.22399903      8776
#                           powder2  0.21016984 0.23510899 0.22194102      8579
#                    root vegetable  0.21974412 0.32518869 0.26226464      7817
#                             sauce  0.26756404 0.44318053 0.33367592      8791
#                        seasoning1  0.17516616 0.36838668 0.23743370      7655
#                        seasoning2  0.20762565 0.23629191 0.22103321      7605
#                              seed  0.27021592 0.39483452 0.32084957     12932
#                          starches  0.26419327 0.28372869 0.27361272     10792
#                            syrup1  0.19981087 0.20556474 0.20264697     10279
#                            syrup2  0.16782542 0.18111713 0.17421812      9596
#                            syrup3  0.15370315 0.32751606 0.20921962      9340
#                         vegetable  0.33871435 0.57994546 0.42765744      8068
#                           vinegar  0.25555144 0.48096123 0.33376299      8614
#                            water1  0.17940787 0.20627985 0.19190773      9841
#                            water2  0.18023256 0.26456155 0.21440304      9374
#                            water3  0.18038028 0.22810937 0.20145642      9399
#                     wheat product  0.34491032 0.58168943 0.43304715      9885
#
#                         micro avg  0.23364877 0.37246700 0.28716117    468071
#                         macro avg  0.22487017 0.36294640 0.27006981    468071
#                      weighted avg  0.22982644 0.37246700 0.27724283    468071
#                       samples avg  0.22244309 0.37524663 0.25615195    468071
#
#
# Epoch [5/20]
# Training: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15706/15706 [28:18<00:00,  9.24batch/s, Loss=0.5717]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3357/3357 [04:06<00:00, 13.63batch/s, Val Loss=0.4516]
# Entering custom_multilabel_metrics
# {'agent': [0, 1], 'allium': [2], 'berries': [3], 'butter': [4, 5, 6, 7], 'cheese': [8], 'chocolate': [9], 'cinnamon': [10], 'condiment': [11], 'cream': [12, 13], 'dried fruit, jams, snacks, treats': [14], 'fats': [15], 'flour': [16, 17, 18, 19], 'fruit': [20], 'juice': [21, 22], 'liquids': [23], 'meat and substitutes': [24], 'milk': [25, 26, 27], 'nightshade': [28], 'nut': [29, 30], 'oil': [31, 32, 33], 'pepper': [34, 35], 'powder': [36, 37], 'root vegetable': [38], 'sauce': [39], 'seasoning': [40, 41], 'seed': [42], 'starches': [43], 'syrup': [44, 45, 46], 'vegetable': [47], 'vinegar': [48], 'water': [49, 50, 51], 'wheat product': [52]}
# Sample 1 key: af12e593e3
# Sample 2 key: af12e593e3
# Sample 3 key: af12e593e3
# Sample 4 key: af12e593e3
# Sample 5 key: af12e593e3
# Sample 6 key: af12e593e3
# Sample 7 key: af12e593e3
# Sample 8 key: af12e593e3
# Sample 9 key: af12e593e3
# Sample 10 key: af12e593e3
# Epoch Summary - Train Loss: 0.5553, Val Loss: 0.5229
# Precision: 0.3140, Recall: 0.4178, F1-Score: 0.3287
#
# Class-wise Performance:
#                                    precision    recall  f1-score   support
#
#                            agent1  0.28279943 0.56490728 0.37691209      9814
#                            agent2  0.30157511 0.54807500 0.38906787     10026
#                            allium  0.24237645 0.60563717 0.34620242      8373
#                           berries  0.40485620 0.61779275 0.48915559     10094
#                           butter1  0.16207003 0.06896097 0.09675331      7584
#                           butter2  0.15962387 0.17878039 0.16865992      7691
#                           butter3  0.16842603 0.14160816 0.15385723      7549
#                           butter4  0.14363198 0.19426708 0.16515563      7361
#                            cheese  0.27324822 0.39465689 0.32291801      9545
#                         chocolate  0.32693720 0.65926365 0.43710733     10131
#                          cinnamon  0.26714006 0.49617973 0.34729738     10994
#                         condiment  0.28797059 0.56826078 0.38223872      9786
#                            cream1  0.21212812 0.25658348 0.23224760      7253
#                            cream2  0.20935252 0.20363891 0.20645619      7145
# dried fruit, jams, snacks, treats  0.24854574 0.45869932 0.32239960     11271
#                              fats  0.25402828 0.48462986 0.33333333     12752
#                            flour1  0.20008433 0.48362849 0.28306178      7849
#                            flour2  0.21795166 0.48415829 0.30058854      7859
#                            flour3  0.20438577 0.48067697 0.28681616      7504
#                            flour4  0.17086369 0.47904461 0.25188579      6657
#                             fruit  0.25132366 0.46226315 0.32561608      9447
#                            juice1  0.19228296 0.39356228 0.25834577      8357
#                            juice2  0.19466706 0.31711370 0.24124233      8426
#                           liquids  0.23615338 0.37904506 0.29100455      8189
#              meat and substitutes  0.32827617 0.58982716 0.42179609     10125
#                             milk1  0.16911969 0.15791521 0.16332551      7713
#                             milk2  0.17793904 0.29822428 0.22288883      8222
#                             milk3  0.17627198 0.19447656 0.18492732      7785
#                        nightshade  0.25497674 0.37485983 0.30350901      8918
#                              nut1  0.23567045 0.42223465 0.30250025     10731
#                              nut2  0.18712536 0.40809367 0.25659352      8797
#                              oil1  0.16141875 0.12927536 0.14356993      6900
#                              oil2  0.17780313 0.15054505 0.16304267      7247
#                              oil3  0.16293930 0.15510949 0.15892801      6576
#                           pepper1  0.19239685 0.56385870 0.28689941      8096
#                           pepper2  0.18782501 0.57166185 0.28274984      7961
#                           powder1  0.21084287 0.28760255 0.24331229      8776
#                           powder2  0.18595607 0.30096748 0.22987892      8579
#                    root vegetable  0.24341293 0.30254573 0.26977699      7817
#                             sauce  0.26901436 0.46229098 0.34011214      8791
#                        seasoning1  0.17717406 0.33481385 0.23172551      7655
#                        seasoning2  0.17005956 0.41301775 0.24092042      7605
#                              seed  0.22936673 0.52822456 0.31984829     12932
#                          starches  0.24274424 0.33867680 0.28279624     10792
#                            syrup1  0.19025555 0.26364432 0.22101700     10279
#                            syrup2  0.16053770 0.21654856 0.18438332      9596
#                            syrup3  0.17002836 0.23104925 0.19589688      9340
#                         vegetable  0.34872261 0.57015369 0.43275789      8068
#                           vinegar  0.28403808 0.44683074 0.34730431      8614
#                            water1  0.18962669 0.17498222 0.18201036      9841
#                            water2  0.20594589 0.21356945 0.20968840      9374
#                            water3  0.18973353 0.19544632 0.19254756      9399
#                     wheat product  0.31925801 0.61112797 0.41941195      9885
#
#                         micro avg  0.23132233 0.38490101 0.28897379    468071
#                         macro avg  0.22284721 0.37413223 0.27249891    468071
#                      weighted avg  0.22737809 0.38490101 0.27964202    468071
#                       samples avg  0.22088874 0.38639320 0.25838697    468071
#
#
# Epoch [6/20]
# Training: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15706/15706 [28:28<00:00,  9.19batch/s, Loss=0.6101]
# Validation: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3357/3357 [04:05<00:00, 13.67batch/s, Val Loss=0.4707]
# Entering custom_multilabel_metrics
# {'agent': [0, 1], 'allium': [2], 'berries': [3], 'butter': [4, 5, 6, 7], 'cheese': [8], 'chocolate': [9], 'cinnamon': [10], 'condiment': [11], 'cream': [12, 13], 'dried fruit, jams, snacks, treats': [14], 'fats': [15], 'flour': [16, 17, 18, 19], 'fruit': [20], 'juice': [21, 22], 'liquids': [23], 'meat and substitutes': [24], 'milk': [25, 26, 27], 'nightshade': [28], 'nut': [29, 30], 'oil': [31, 32, 33], 'pepper': [34, 35], 'powder': [36, 37], 'root vegetable': [38], 'sauce': [39], 'seasoning': [40, 41], 'seed': [42], 'starches': [43], 'syrup': [44, 45, 46], 'vegetable': [47], 'vinegar': [48], 'water': [49, 50, 51], 'wheat product': [52]}
# Sample 1 key: af12e593e3
# Sample 2 key: af12e593e3
# Sample 3 key: af12e593e3
# Sample 4 key: af12e593e3
# Sample 5 key: af12e593e3
# Sample 6 key: af12e593e3
# Sample 7 key: af12e593e3
# Sample 8 key: af12e593e3
# Sample 9 key: af12e593e3
# Sample 10 key: af12e593e3
#
# Saving best model with F1: 0.3334
# Epoch Summary - Train Loss: 0.5501, Val Loss: 0.5240
# Precision: 0.3101, Recall: 0.4349, F1-Score: 0.3334
#
# Class-wise Performance:
#                                    precision    recall  f1-score   support
#
#                            agent1  0.26485834 0.60393316 0.36822813      9814
#                            agent2  0.27367091 0.60482745 0.37683321     10026
#                            allium  0.23524414 0.62832915 0.34232358      8373
#                           berries  0.42520073 0.59807807 0.49703606     10094
#                           butter1  0.14712987 0.16864451 0.15715427      7584
#                           butter2  0.16025374 0.20036406 0.17807823      7691
#                           butter3  0.16214700 0.22969930 0.19010031      7549
#                           butter4  0.14640884 0.13680206 0.14144252      7361
#                            cheese  0.25451053 0.45814563 0.32723463      9545
#                         chocolate  0.31565691 0.68038693 0.43124374     10131
#                          cinnamon  0.28204112 0.45297435 0.34763185     10994
#                         condiment  0.26937669 0.60944206 0.37361398      9786
#                            cream1  0.19320478 0.29008686 0.23193518      7253
#                            cream2  0.19485524 0.26186144 0.22344300      7145
# dried fruit, jams, snacks, treats  0.26095715 0.42525064 0.32343613     11271
#                              fats  0.25765697 0.47498432 0.33408715     12752
#                            flour1  0.19824053 0.50528730 0.28476037      7849
#                            flour2  0.21410537 0.48555796 0.29717312      7859
#                            flour3  0.20011441 0.51279318 0.28788389      7504
#                            flour4  0.16417910 0.50563317 0.24787363      6657
#                             fruit  0.26813305 0.42066264 0.32750948      9447
#                            juice1  0.22509714 0.30501376 0.25903155      8357
#                            juice2  0.20716496 0.26216473 0.23144219      8426
#                           liquids  0.25056661 0.36451337 0.29698537      8189
#              meat and substitutes  0.32103539 0.59041975 0.41591874     10125
#                             milk1  0.16829521 0.18980941 0.17840604      7713
#                             milk2  0.18796734 0.26599368 0.22027497      8222
#                             milk3  0.16866257 0.21528581 0.18914344      7785
#                        nightshade  0.23429711 0.44797040 0.30767454      8918
#                              nut1  0.23591849 0.43910167 0.30693069     10731
#                              nut2  0.19020300 0.39195180 0.25611885      8797
#                              oil1  0.15658062 0.16086957 0.15869612      6900
#                              oil2  0.15945403 0.20794812 0.18050066      7247
#                              oil3  0.13556959 0.25136861 0.17614151      6576
#                           pepper1  0.19051738 0.59856719 0.28903734      8096
#                           pepper2  0.17887506 0.59201105 0.27473841      7961
#                           powder1  0.18636942 0.38388788 0.25092168      8776
#                           powder2  0.18698691 0.32124956 0.23638391      8579
#                    root vegetable  0.24517848 0.29435845 0.26752703      7817
#                             sauce  0.24630656 0.48549653 0.32681190      8791
#                        seasoning1  0.15914135 0.51521881 0.24317159      7655
#                        seasoning2  0.16809310 0.42353715 0.24066948      7605
#                              seed  0.23480523 0.50247448 0.32005122     12932
#                          starches  0.24409236 0.33404374 0.28207034     10792
#                            syrup1  0.18960245 0.24730032 0.21464156     10279
#                            syrup2  0.15338093 0.35150063 0.21356887      9596
#                            syrup3  0.16359294 0.26402570 0.20201524      9340
#                         vegetable  0.33349851 0.58391175 0.42452915      8068
#                           vinegar  0.25770202 0.47387973 0.33385131      8614
#                            water1  0.18355140 0.14967991 0.16489421      9841
#                            water2  0.19946903 0.24045231 0.21805166      9374
#                            water3  0.18881409 0.19395680 0.19135090      9399
#                     wheat product  0.34512842 0.57228123 0.43058304      9885
#
#                         micro avg  0.22388876 0.40213985 0.28763731    468071
#                         macro avg  0.21856345 0.39384883 0.27530483    468071
#                      weighted avg  0.22366311 0.40213985 0.28195238    468071
#                       samples avg  0.21568035 0.40164073 0.25984386    468071
#
#
# Epoch [7/20]
# Training: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15706/15706 [28:18<00:00,  9.25batch/s, Loss=0.5729]
# Validation:  87%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                   | 2908/3357 [03:31<00:32, 13.88batch/s, Val Loss=0.4289]

# %%
# Clear GPU memory before training
import torch
import gc

# First delete model and data if they exist
try:
    del model
except:
    pass
try:
    del optimizer
except:
    pass
try:
    del train_loader
except:
    pass
try:
    del val_loader
except:
    pass

# Force CUDA to clear memory
torch.cuda.empty_cache()
gc.collect()
# To check memory usage
print(torch.cuda.memory_allocated()/1024**3, "GB allocated")
print(torch.cuda.memory_reserved()/1024**3, "GB reserved")
