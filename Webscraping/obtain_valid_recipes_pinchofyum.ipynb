# %%
import requests
from bs4 import BeautifulSoup
from typing import List
import time

def is_recipe_page(url: str) -> bool:
    """
    Check if a webpage is a recipe by looking for 'PRINT RECIPE' and 'PIN RECIPE' buttons.
    """
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
    }
    
    try:
        response = requests.get(url.strip(), headers=headers, timeout=10)
        response.raise_for_status()
        
        soup = BeautifulSoup(response.text, 'html.parser')
        
        print_recipe = soup.find(string=lambda text: 'print recipe' in text.lower() if text else False)
        pin_recipe = soup.find(string=lambda text: 'pin recipe' in text.lower() if text else False)
        
        return bool(print_recipe and pin_recipe)
        
    except Exception as e:
        print(f"Error processing {url}: {str(e)}")
        return False

def process_url_file(input_file: str, output_file: str) -> None:
    """
    Process a file of URLs and write valid recipe URLs to a new file.
    
    Args:
        input_file (str): Path to input file containing URLs
        output_file (str): Path to output file for valid recipe URLs
    """
    valid_urls = []
    total_urls = 0
    valid_count = 0
    
    print(f"Reading URLs from {input_file}...")
    
    try:
        # Read URLs from input file
        with open(input_file, 'r') as f:
            urls = f.readlines()
        
        total_urls = len(urls)
        print(f"Found {total_urls} URLs to process")
        
        # Process each URL
        for i, url in enumerate(urls, 1):
            url = url.strip()
            print(f"\nProcessing URL {i}/{total_urls}: {url}")
            
            if is_recipe_page(url):
                valid_urls.append(url)
                valid_count += 1
                print("✓ Valid recipe page")
            else:
                print("✗ Not a recipe page")
            
            # Add a small delay to be nice to the server
            time.sleep(1)
            
        # Write valid URLs to output file
        with open(output_file, 'w') as f:
            for url in valid_urls:
                f.write(f"{url}\n")
        
        print(f"\nProcessing complete!")
        print(f"Total URLs processed: {total_urls}")
        print(f"Valid recipe URLs found: {valid_count}")
        print(f"Valid URLs written to: {output_file}")
        
    except Exception as e:
        print(f"Error: {str(e)}")

def main():
    # File paths
    input_file = "recipe_urls.txt"  # Your input file with URLs
    output_file = "valid_recipe_urls.txt"  # Output file for valid URLs
    
    process_url_file(input_file, output_file)

if __name__ == "__main__":
    main()
# Out:
# Reading URLs from recipe_urls.txt...
# Found 1280 URLs to process
#
# Processing URL 1/1280: https://pinchofyum.com/bang-bang-salmon-with-avocado-cucumber-salsa
# ✓ Valid recipe page
#
# Processing URL 2/1280: https://pinchofyum.com/scallion-pancake-with-eggs
# ✓ Valid recipe page
#
# Processing URL 3/1280: https://pinchofyum.com/homemade-alfredo-sauce
# ✓ Valid recipe page
#
# Processing URL 4/1280: https://pinchofyum.com/sticky-gochujang-tofu-with-herbs-and-peanuts
# ✓ Valid recipe page
#
# Processing URL 5/1280: https://pinchofyum.com/chicken-tacos
# ✓ Valid recipe page
#
# Processing URL 6/1280: https://pinchofyum.com/garlic-and-black-pepper-beef-skewers
# ✓ Valid recipe page
#
# Processing URL 7/1280: https://pinchofyum.com/chicken-with-coconut-kale
# ✓ Valid recipe page
#
# Processing URL 8/1280: https://pinchofyum.com/ricotta-meatballs-with-the-crispy-topping
# ✓ Valid recipe page
#
# Processing URL 9/1280: https://pinchofyum.com/welcome-to-the-sos-series
# ✗ Not a recipe page
#
# Processing URL 10/1280: https://pinchofyum.com/spicy-shrimp-with-peach-salad
# ✓ Valid recipe page
#
# Processing URL 11/1280: https://pinchofyum.com/party-brownies
# ✓ Valid recipe page
#
# Processing URL 12/1280: https://pinchofyum.com/how-you-should-be-doing-oat-bran-for-breakfast
# ✓ Valid recipe page
#
# Processing URL 13/1280: https://pinchofyum.com/gorgeous-peach-salad
# ✓ Valid recipe page
#
# Processing URL 14/1280: https://pinchofyum.com/honey-chipotle-chicken-skewers
# ✓ Valid recipe page
#
# Processing URL 15/1280: https://pinchofyum.com/amazing-green-rice
# ✓ Valid recipe page
#
# Processing URL 16/1280: https://pinchofyum.com/super-yummy-chicken-salad
# ✓ Valid recipe page
#
# Processing URL 17/1280: https://pinchofyum.com/avocado-caesar-green-beans
# ✓ Valid recipe page
#
# Processing URL 18/1280: https://pinchofyum.com/two-huge-double-chocolate-cookies
# ✓ Valid recipe page
#
# Processing URL 19/1280: https://pinchofyum.com/big-yummy-italian-salad
# ✓ Valid recipe page
#
# Processing URL 20/1280: https://pinchofyum.com/crispy-rice-salad-with-cucumbers-and-herbs
# ✓ Valid recipe page
#
# Processing URL 21/1280: https://pinchofyum.com/incredible-gochujang-sauce
# ✓ Valid recipe page
#
# Processing URL 22/1280: https://pinchofyum.com/ridiculously-good-air-fryer-salmon
# ✓ Valid recipe page
#
# Processing URL 23/1280: https://pinchofyum.com/33-things-you-absolutely-need-to-be-buying-at-trader-joes
# ✗ Not a recipe page
#
# Processing URL 24/1280: https://pinchofyum.com/two-huge-chocolate-chip-cookies
# ✓ Valid recipe page
#
# Processing URL 25/1280: https://pinchofyum.com/marry-me-chicken
# ✓ Valid recipe page
#
# Processing URL 26/1280: https://pinchofyum.com/ridiculously-good-air-fryer-tofu
# ✓ Valid recipe page
#
# Processing URL 27/1280: https://pinchofyum.com/baked-tortellini-with-sausage
# ✓ Valid recipe page
#
# Processing URL 28/1280: https://pinchofyum.com/butter-cauliflower-and-chickpeas-with-mint-cilantro-sauce
# ✓ Valid recipe page
#
# Processing URL 29/1280: https://pinchofyum.com/shortcut-sesame-butter-noodles
# ✓ Valid recipe page
#
# Processing URL 30/1280: https://pinchofyum.com/banza-chicken-bowls-with-calabrian-chili-sauce
# ✓ Valid recipe page
#
# Processing URL 31/1280: https://pinchofyum.com/ridiculously-good-air-fryer-chicken-breast
# ✓ Valid recipe page
#
# Processing URL 32/1280: https://pinchofyum.com/super-creamy-white-chicken-chili-with-seasoned-tots
# ✓ Valid recipe page
#
# Processing URL 33/1280: https://pinchofyum.com/roasted-mushroom-sandwich-with-horseradish-aioli
# ✓ Valid recipe page
#
# Processing URL 34/1280: https://pinchofyum.com/gnocchi-with-creamy-mushroom-sauce
# ✓ Valid recipe page
#
# Processing URL 35/1280: https://pinchofyum.com/easy-instant-pot-applesauce
# ✓ Valid recipe page
#
# Processing URL 36/1280: https://pinchofyum.com/slow-cooker-texas-style-chili
# ✓ Valid recipe page
#
# Processing URL 37/1280: https://pinchofyum.com/5-ingredient-tomato-soup
# ✓ Valid recipe page
#
# Processing URL 38/1280: https://pinchofyum.com/house-favorite-garlic-bread
# ✓ Valid recipe page
#
# Processing URL 39/1280: https://pinchofyum.com/pumpkin-muffins-with-maple-cream-cheese-filling
# ✓ Valid recipe page
#
# Processing URL 40/1280: https://pinchofyum.com/swedish-pancakes
# ✓ Valid recipe page
#
# Processing URL 41/1280: https://pinchofyum.com/roasted-corn-and-fried-egg-tacos
# ✓ Valid recipe page
#
# Processing URL 42/1280: https://pinchofyum.com/chimichurri-shrimp-with-tomatoes
# ✓ Valid recipe page
#
# Processing URL 43/1280: https://pinchofyum.com/creamy-baked-orzo-with-meatballs
# ✓ Valid recipe page
#
# Processing URL 44/1280: https://pinchofyum.com/kale-apple-salad-crispy-shallots
# ✓ Valid recipe page
#
# Processing URL 45/1280: https://pinchofyum.com/chicken-wontons-in-spicy-chili-sauce
# ✓ Valid recipe page
#
# Processing URL 46/1280: https://pinchofyum.com/red-curry-chicken-stir-fry-with-spicy-cashew-sauce
# ✓ Valid recipe page
#
# Processing URL 47/1280: https://pinchofyum.com/feel-good-zucchini-muffins
# ✓ Valid recipe page
#
# Processing URL 48/1280: https://pinchofyum.com/pumpkin-caramel-monkey-bread
# ✓ Valid recipe page
#
# Processing URL 49/1280: https://pinchofyum.com/english-muffin-baklava
# ✓ Valid recipe page
#
# Processing URL 50/1280: https://pinchofyum.com/roasted-peanut-kale-crunch-salad
# ✓ Valid recipe page
#
# Processing URL 51/1280: https://pinchofyum.com/aji-verde
# ✓ Valid recipe page
#
# Processing URL 52/1280: https://pinchofyum.com/my-go-to-pickled-red-onions
# ✓ Valid recipe page
#
# Processing URL 53/1280: https://pinchofyum.com/gochujang-chicken-burgers-with-kimchi-bacon-jam
# ✓ Valid recipe page
#
# Processing URL 54/1280: https://pinchofyum.com/grilled-chicken-with-pepperoncini-garlic-butter
# ✓ Valid recipe page
#
# Processing URL 55/1280: https://pinchofyum.com/blueberry-matcha-latte
# ✓ Valid recipe page
#
# Processing URL 56/1280: https://pinchofyum.com/very-incredible-basil-sauce
# ✓ Valid recipe page
#
# Processing URL 57/1280: https://pinchofyum.com/trader-joes-sun-dried-tomato-focaccia-turkey-sandwich
# ✓ Valid recipe page
#
# Processing URL 58/1280: https://pinchofyum.com/garlic-shrimp-and-tomatoes-on-parmesan-orzo
# ✓ Valid recipe page
#
# Processing URL 59/1280: https://pinchofyum.com/salmon-with-basil-sauce-and-tomato-salad
# ✓ Valid recipe page
#
# Processing URL 60/1280: https://pinchofyum.com/chicken-teriyaki-burgers
# ✓ Valid recipe page
#
# Processing URL 61/1280: https://pinchofyum.com/kimchi-tuna-salad-wrap
# ✓ Valid recipe page
#
# Processing URL 62/1280: https://pinchofyum.com/chili-crunch-tofu
# ✓ Valid recipe page
#
# Processing URL 63/1280: https://pinchofyum.com/a-really-good-non-alcoholic-margarita
# ✓ Valid recipe page
#
# Processing URL 64/1280: https://pinchofyum.com/avocado-mojo-bowls-with-sweet-potato-and-chicken
# ✓ Valid recipe page
#
# Processing URL 65/1280: https://pinchofyum.com/pickled-strawberries
# ✓ Valid recipe page
#
# Processing URL 66/1280: https://pinchofyum.com/salmon-tacos
# ✓ Valid recipe page
#
# Processing URL 67/1280: https://pinchofyum.com/chili-garlic-pappardelle-with-smashed-broccoli-and-soft-eggs
# ✓ Valid recipe page
#
# Processing URL 68/1280: https://pinchofyum.com/chickpea-curry
# ✓ Valid recipe page
#
# Processing URL 69/1280: https://pinchofyum.com/miso-crunch-salad
# ✓ Valid recipe page
#
# Processing URL 70/1280: https://pinchofyum.com/red-chile-tostadas-with-eggs
# ✓ Valid recipe page
#
# Processing URL 71/1280: https://pinchofyum.com/cilantro-orange-chicken-with-rice-and-beans
# ✓ Valid recipe page
#
# Processing URL 72/1280: https://pinchofyum.com/butter-chicken-meatballs
# ✓ Valid recipe page
#
# Processing URL 73/1280: https://pinchofyum.com/carrot-cake-coffee-cake
# ✓ Valid recipe page
#
# Processing URL 74/1280: https://pinchofyum.com/browned-butter-chocolate-chip-cookies
# ✓ Valid recipe page
#
# Processing URL 75/1280: https://pinchofyum.com/yummy-salmon-burgers-slaw
# ✓ Valid recipe page
#
# Processing URL 76/1280: https://pinchofyum.com/sopa-tarasca-pinto-bean-soup-with-jalapeno-corn-fritters
# ✓ Valid recipe page
#
# Processing URL 77/1280: https://pinchofyum.com/ginger-peanut-chicken-with-coconut-rice
# ✓ Valid recipe page
#
# Processing URL 78/1280: https://pinchofyum.com/strawberry-white-chocolate-cookies
# ✓ Valid recipe page
#
# Processing URL 79/1280: https://pinchofyum.com/couscous-skillet-with-tomatoes-chickpeas-and-feta
# ✓ Valid recipe page
#
# Processing URL 80/1280: https://pinchofyum.com/bistro-salad
# ✓ Valid recipe page
#
# Processing URL 81/1280: https://pinchofyum.com/7-layer-beet-salad
# ✓ Valid recipe page
#
# Processing URL 82/1280: https://pinchofyum.com/favorite-recipes-from-2022
# ✗ Not a recipe page
#
# Processing URL 83/1280: https://pinchofyum.com/12-easy-recipes-you-can-make-in-a-slow-cooker
# ✗ Not a recipe page
#
# Processing URL 84/1280: https://pinchofyum.com/cream-cheese-danishes-with-sugared-cranberries-and-butter-glaze
# ✓ Valid recipe page
#
# Processing URL 85/1280: https://pinchofyum.com/ginger-chicken-meatball-sandos
# ✓ Valid recipe page
#
# Processing URL 86/1280: https://pinchofyum.com/instant-pot-short-rib-ragu
# ✓ Valid recipe page
#
# Processing URL 87/1280: https://pinchofyum.com/vegetarian-shepherds-pie
# ✓ Valid recipe page
#
# Processing URL 88/1280: https://pinchofyum.com/house-favorite-brussels-sprouts
# ✓ Valid recipe page
#
# Processing URL 89/1280: https://pinchofyum.com/instant-pot-mac-and-cheese
# ✓ Valid recipe page
#
# Processing URL 90/1280: https://pinchofyum.com/corn-casserole
# ✓ Valid recipe page
#
# Processing URL 91/1280: https://pinchofyum.com/salted-caramel-rice-krispie-bars
# ✓ Valid recipe page
#
# Processing URL 92/1280: https://pinchofyum.com/cashew-chicken
# ✓ Valid recipe page
#
# Processing URL 93/1280: https://pinchofyum.com/chicken-orzo-tomato-soup
# ✓ Valid recipe page
#
# Processing URL 94/1280: https://pinchofyum.com/comfort-meals-to-bring-to-a-friend-in-need
# ✗ Not a recipe page
#
# Processing URL 95/1280: https://pinchofyum.com/chipotle-orange-shrimp-with-cilantro-rice
# ✓ Valid recipe page
#
# Processing URL 96/1280: https://pinchofyum.com/harissa-meatballs-with-whipped-feta
# ✓ Valid recipe page
#
# Processing URL 97/1280: https://pinchofyum.com/sesame-apricot-tofu
# ✓ Valid recipe page
#
# Processing URL 98/1280: https://pinchofyum.com/instant-pot-wild-rice-soup
# ✓ Valid recipe page
#
# Processing URL 99/1280: https://pinchofyum.com/no-knead-bread
# ✓ Valid recipe page
#
# Processing URL 100/1280: https://pinchofyum.com/instant-pot-pasta-and-meatballs-with-lemon-herb-ricotta
# ✓ Valid recipe page
#
# Processing URL 101/1280: https://pinchofyum.com/spicy-sofritas-veggie-bowls
# ✓ Valid recipe page
#
# Processing URL 102/1280: https://pinchofyum.com/tofu-and-brown-rice-lettuce-wraps
# ✓ Valid recipe page
#
# Processing URL 103/1280: https://pinchofyum.com/simple-homemade-tomato-soup
# ✓ Valid recipe page
#
# Processing URL 104/1280: https://pinchofyum.com/crispy-black-bean-tacos-with-cilantro-lime-sauce
# ✓ Valid recipe page
#
# Processing URL 105/1280: https://pinchofyum.com/cauliflower-orange-gnocchi
# ✓ Valid recipe page
#
# Processing URL 106/1280: https://pinchofyum.com/instant-pot-beef-stew
# ✓ Valid recipe page
#
# Processing URL 107/1280: https://pinchofyum.com/pineapple-pork-with-coconut-rice
# ✓ Valid recipe page
#
# Processing URL 108/1280: https://pinchofyum.com/cauliflower-black-bean-tostadas-with-queso-and-pickled-onion
# ✓ Valid recipe page
#
# Processing URL 109/1280: https://pinchofyum.com/crunchy-roll-bowls
# ✓ Valid recipe page
#
# Processing URL 110/1280: https://pinchofyum.com/magical-black-bean-recipes
# ✗ Not a recipe page
#
# Processing URL 111/1280: https://pinchofyum.com/breakfast-sandwich
# ✓ Valid recipe page
#
# Processing URL 112/1280: https://pinchofyum.com/5-minute-honey-mustard-sauce
# ✓ Valid recipe page
#
# Processing URL 113/1280: https://pinchofyum.com/buffalo-chicken-bowls-with-cauliflower-garlic-rice
# ✓ Valid recipe page
#
# Processing URL 114/1280: https://pinchofyum.com/angs-chicken-wraps
# ✓ Valid recipe page
#
# Processing URL 115/1280: https://pinchofyum.com/muccis-bucatini
# ✓ Valid recipe page
#
# Processing URL 116/1280: https://pinchofyum.com/extra-good-puppy-chow
# ✓ Valid recipe page
#
# Processing URL 117/1280: https://pinchofyum.com/crunchwrap
# ✓ Valid recipe page
#
# Processing URL 118/1280: https://pinchofyum.com/fruit-pizza
# ✓ Valid recipe page
#
# Processing URL 119/1280: https://pinchofyum.com/pasta-salad
# ✓ Valid recipe page
#
# Processing URL 120/1280: https://pinchofyum.com/how-to-grill-corn
# ✗ Not a recipe page
#
# Processing URL 121/1280: https://pinchofyum.com/how-to-cook-salmon
# ✗ Not a recipe page
#
# Processing URL 122/1280: https://pinchofyum.com/vanilla-mint-iced-coffee
# ✓ Valid recipe page
#
# Processing URL 123/1280: https://pinchofyum.com/spicy-shrimp-tacos-with-garlic-cilantro-lime-slaw
# ✓ Valid recipe page
#
# Processing URL 124/1280: https://pinchofyum.com/juicy-lucy
# ✓ Valid recipe page
#
# Processing URL 125/1280: https://pinchofyum.com/smash-burgers-with-house-sauce
# ✓ Valid recipe page
#
# Processing URL 126/1280: https://pinchofyum.com/chicken-lettuce-wraps-with-lime-drench
# ✓ Valid recipe page
#
# Processing URL 127/1280: https://pinchofyum.com/saucy-gochujang-noodles-with-chicken
# ✓ Valid recipe page
#
# Processing URL 128/1280: https://pinchofyum.com/elote-style-quinoa-salad
# ✓ Valid recipe page
#
# Processing URL 129/1280: https://pinchofyum.com/pesto-shrimp-and-parmesan-risotto
# ✓ Valid recipe page
#
# Processing URL 130/1280: https://pinchofyum.com/italian-tomato-and-bread-soup
# ✓ Valid recipe page
#
# Processing URL 131/1280: https://pinchofyum.com/napa-chicken-salad-with-sesame-dressing
# ✓ Valid recipe page
#
# Processing URL 132/1280: https://pinchofyum.com/garlic-cream-bucatini-with-peas-and-asparagus
# ✓ Valid recipe page
#
# Processing URL 133/1280: https://pinchofyum.com/crispy-chicken-tikka-bowls-with-mint-sauce
# ✓ Valid recipe page
#
# Processing URL 134/1280: https://pinchofyum.com/baked-coconut-shrimp
# ✓ Valid recipe page
#
# Processing URL 135/1280: https://pinchofyum.com/salmon-with-leeks-potatoes-and-asparagus
# ✓ Valid recipe page
#
# Processing URL 136/1280: https://pinchofyum.com/30-minute-meals
# ✗ Not a recipe page
#
# Processing URL 137/1280: https://pinchofyum.com/sheet-pan-meatballs-with-tomato-salad-and-green-sauce
# ✓ Valid recipe page
#
# Processing URL 138/1280: https://pinchofyum.com/red-chile-chicken-tacos-with-creamy-corn
# ✓ Valid recipe page
#
# Processing URL 139/1280: https://pinchofyum.com/pistachio-loaf
# ✓ Valid recipe page
#
# Processing URL 140/1280: https://pinchofyum.com/the-olivers-salad
# ✓ Valid recipe page
#
# Processing URL 141/1280: https://pinchofyum.com/reuben-casserole
# ✓ Valid recipe page
#
# Processing URL 142/1280: https://pinchofyum.com/egg-waffles-with-romesco-and-goat-cheese
# ✓ Valid recipe page
#
# Processing URL 143/1280: https://pinchofyum.com/zaalouk-toasts-with-burrata
# ✓ Valid recipe page
#
# Processing URL 144/1280: https://pinchofyum.com/instant-pot-spicy-short-rib-noodle-soup
# ✓ Valid recipe page
#
# Processing URL 145/1280: https://pinchofyum.com/cafe-latte-turtle-cake-for-two
# ✓ Valid recipe page
#
# Processing URL 146/1280: https://pinchofyum.com/thai-yellow-chicken-curry-with-potatoes
# ✓ Valid recipe page
#
# Processing URL 147/1280: https://pinchofyum.com/better-for-you-products-from-aldi
# ✗ Not a recipe page
#
# Processing URL 148/1280: https://pinchofyum.com/best-healthy-chickpea-recipes
# ✗ Not a recipe page
#
# Processing URL 149/1280: https://pinchofyum.com/kimchi-grilled-cheese
# ✓ Valid recipe page
#
# Processing URL 150/1280: https://pinchofyum.com/sweet-honey-recipes-to-make
# ✗ Not a recipe page
#
# Processing URL 151/1280: https://pinchofyum.com/millionaire-gnocchi
# ✓ Valid recipe page
#
# Processing URL 152/1280: https://pinchofyum.com/golden-crispies
# ✓ Valid recipe page
#
# Processing URL 153/1280: https://pinchofyum.com/luscious-coconut-milk-recipes
# ✗ Not a recipe page
#
# Processing URL 154/1280: https://pinchofyum.com/simple-green-salad
# ✓ Valid recipe page
#
# Processing URL 155/1280: https://pinchofyum.com/pecan-pie-energy-bites
# ✓ Valid recipe page
#
# Processing URL 156/1280: https://pinchofyum.com/crockpot-chicken-wild-rice-soup
# ✓ Valid recipe page
#
# Processing URL 157/1280: https://pinchofyum.com/join-our-january-meal-planning-bootcamp
# ✗ Not a recipe page
#
# Processing URL 158/1280: https://pinchofyum.com/cozy-casserole-recipes
# ✗ Not a recipe page
#
# Processing URL 159/1280: https://pinchofyum.com/complete-list-of-holiday-series-recipes
# ✗ Not a recipe page
#
# Processing URL 160/1280: https://pinchofyum.com/christmas-feta
# ✓ Valid recipe page
#
# Processing URL 161/1280: https://pinchofyum.com/the-merry-mocktail
# ✓ Valid recipe page
#
# Processing URL 162/1280: https://pinchofyum.com/roasted-carrots-with-honey-and-garlic-yogurt-sauce
# ✓ Valid recipe page
#
# Processing URL 163/1280: https://pinchofyum.com/swedish-meatballs
# ✓ Valid recipe page
#
# Processing URL 164/1280: https://pinchofyum.com/soft-gingerbread-cookies-with-maple-glaze
# ✓ Valid recipe page
#
# Processing URL 165/1280: https://pinchofyum.com/holiday-products-at-aldi
# ✗ Not a recipe page
#
# Processing URL 166/1280: https://pinchofyum.com/cinnamon-rolls
# ✓ Valid recipe page
#
# Processing URL 167/1280: https://pinchofyum.com/bacon-wrapped-dates-with-goat-cheese
# ✓ Valid recipe page
#
# Processing URL 168/1280: https://pinchofyum.com/very-best-chocolate-cookies
# ✓ Valid recipe page
#
# Processing URL 169/1280: https://pinchofyum.com/onion-dip
# ✓ Valid recipe page
#
# Processing URL 170/1280: https://pinchofyum.com/pumpkin-shortcakes-with-cinnamon-apples
# ✓ Valid recipe page
#
# Processing URL 171/1280: https://pinchofyum.com/green-bean-casserole
# ✓ Valid recipe page
#
# Processing URL 172/1280: https://pinchofyum.com/chicken-pot-pie-with-biscuits
# ✓ Valid recipe page
#
# Processing URL 173/1280: https://pinchofyum.com/incredible-corn-recipes
# ✗ Not a recipe page
#
# Processing URL 174/1280: https://pinchofyum.com/sweet-potato-casserole
# ✓ Valid recipe page
#
# Processing URL 175/1280: https://pinchofyum.com/creamy-and-delicious-dairy-free-recipes
# ✗ Not a recipe page
#
# Processing URL 176/1280: https://pinchofyum.com/coming-soon-the-holiday-series
# ✗ Not a recipe page
#
# Processing URL 177/1280: https://pinchofyum.com/soup-series-wrap-up
# ✗ Not a recipe page
#
# Processing URL 178/1280: https://pinchofyum.com/chicken-tortilla-soup
# ✓ Valid recipe page
#
# Processing URL 179/1280: https://pinchofyum.com/pumpkin-soup-with-walnut-crispies
# ✓ Valid recipe page
#
# Processing URL 180/1280: https://pinchofyum.com/healing-chicken-and-rice-soup
# ✓ Valid recipe page
#
# Processing URL 181/1280: https://pinchofyum.com/peppery-torn-homemade-croutons
# ✓ Valid recipe page
#
# Processing URL 182/1280: https://pinchofyum.com/sausage-kale-and-white-bean-soup
# ✓ Valid recipe page
#
# Processing URL 183/1280: https://pinchofyum.com/homemade-cream-of-chicken-soup
# ✓ Valid recipe page
#
# Processing URL 184/1280: https://pinchofyum.com/thai-coconut-soup-with-tofu-and-rice
# ✓ Valid recipe page
#
# Processing URL 185/1280: https://pinchofyum.com/things-you-should-absolutely-be-buying-at-aldi
# ✗ Not a recipe page
#
# Processing URL 186/1280: https://pinchofyum.com/creamy-mushroom-soup
# ✓ Valid recipe page
#
# Processing URL 187/1280: https://pinchofyum.com/sunday-chili
# ✓ Valid recipe page
#
# Processing URL 188/1280: https://pinchofyum.com/smoky-red-lentil-soup-with-spinach
# ✓ Valid recipe page
#
# Processing URL 189/1280: https://pinchofyum.com/country-chicken-stew
# ✓ Valid recipe page
#
# Processing URL 190/1280: https://pinchofyum.com/coming-soon-the-soup-series
# ✗ Not a recipe page
#
# Processing URL 191/1280: https://pinchofyum.com/delicious-soup-recipes-to-cozy-up-to-this-fall
# ✗ Not a recipe page
#
# Processing URL 192/1280: https://pinchofyum.com/we-tried-10-of-the-internets-best-instant-pot-recipes
# ✗ Not a recipe page
#
# Processing URL 193/1280: https://pinchofyum.com/sos-series-2-recap
# ✗ Not a recipe page
#
# Processing URL 194/1280: https://pinchofyum.com/vegan-mac-and-cheese
# ✓ Valid recipe page
#
# Processing URL 195/1280: https://pinchofyum.com/slow-cooker-beef-ragu-with-pappardelle
# ✓ Valid recipe page
#
# Processing URL 196/1280: https://pinchofyum.com/fall-favorite-maple-mustard-tempeh-bowls
# ✓ Valid recipe page
#
# Processing URL 197/1280: https://pinchofyum.com/30-minute-vegetarian-meatballs
# ✓ Valid recipe page
#
# Processing URL 198/1280: https://pinchofyum.com/green-curry
# ✓ Valid recipe page
#
# Processing URL 199/1280: https://pinchofyum.com/freezer-meals
# ✗ Not a recipe page
#
# Processing URL 200/1280: https://pinchofyum.com/cinnamon-sugar-apple-cake
# ✓ Valid recipe page
#
# Processing URL 201/1280: https://pinchofyum.com/three-cheese-baked-gnocchi-with-spinach
# ✓ Valid recipe page
#
# Processing URL 202/1280: https://pinchofyum.com/hot-honey-salmon
# ✓ Valid recipe page
#
# Processing URL 203/1280: https://pinchofyum.com/how-to-cook-perfect-rice
# ✗ Not a recipe page
#
# Processing URL 204/1280: https://pinchofyum.com/easy-homemade-yellow-curry-paste
# ✓ Valid recipe page
#
# Processing URL 205/1280: https://pinchofyum.com/spaghetti-with-crispy-zucchini
# ✓ Valid recipe page
#
# Processing URL 206/1280: https://pinchofyum.com/garlic-butter-shrimp-boil
# ✓ Valid recipe page
#
# Processing URL 207/1280: https://pinchofyum.com/peach-cobbler
# ✓ Valid recipe page
#
# Processing URL 208/1280: https://pinchofyum.com/roasted-broccoli-salad
# ✓ Valid recipe page
#
# Processing URL 209/1280: https://pinchofyum.com/one-pan-farro-with-tomatoes-and-kale
# ✓ Valid recipe page
#
# Processing URL 210/1280: https://pinchofyum.com/the-best-easy-peanut-butter-pie
# ✓ Valid recipe page
#
# Processing URL 211/1280: https://pinchofyum.com/coming-soon-sos-series-2-0
# ✗ Not a recipe page
#
# Processing URL 212/1280: https://pinchofyum.com/5-ingredient-lemon-chicken-asparagus
# ✓ Valid recipe page
#
# Processing URL 213/1280: https://pinchofyum.com/completely-delicious-broccoli-recipes
# ✗ Not a recipe page
#
# Processing URL 214/1280: https://pinchofyum.com/rainbow-vegetarian-pad-thai-with-peanuts-and-basil
# ✓ Valid recipe page
#
# Processing URL 215/1280: https://pinchofyum.com/20-minute-healthy-chicken-parmesan
# ✓ Valid recipe page
#
# Processing URL 216/1280: https://pinchofyum.com/arepas
# ✓ Valid recipe page
#
# Processing URL 217/1280: https://pinchofyum.com/romesco-sauce
# ✓ Valid recipe page
#
# Processing URL 218/1280: https://pinchofyum.com/lemongrass-chicken-with-rice-and-zucchini
# ✓ Valid recipe page
#
# Processing URL 219/1280: https://pinchofyum.com/burst-tomato-pappardelle
# ✓ Valid recipe page
#
# Processing URL 220/1280: https://pinchofyum.com/savory-meatball-recipes
# ✗ Not a recipe page
#
# Processing URL 221/1280: https://pinchofyum.com/smores-bars
# ✓ Valid recipe page
#
# Processing URL 222/1280: https://pinchofyum.com/baked-salmon-with-amazing-lemon-sauce
# ✓ Valid recipe page
#
# Processing URL 223/1280: https://pinchofyum.com/lo-mein
# ✓ Valid recipe page
#
# Processing URL 224/1280: https://pinchofyum.com/cashew-crunch-salad-with-sesame-dressing
# ✓ Valid recipe page
#
# Processing URL 225/1280: https://pinchofyum.com/harissa-chickpeas-with-whipped-feta
# ✓ Valid recipe page
#
# Processing URL 226/1280: https://pinchofyum.com/almond-butter-chocolate-chip-zucchini-bars
# ✓ Valid recipe page
#
# Processing URL 227/1280: https://pinchofyum.com/easy-homemade-blueberry-sauce
# ✓ Valid recipe page
#
# Processing URL 228/1280: https://pinchofyum.com/smoky-beans-greens-tacos-with-aji-verde
# ✓ Valid recipe page
#
# Processing URL 229/1280: https://pinchofyum.com/how-to-cut-a-watermelon
# ✗ Not a recipe page
#
# Processing URL 230/1280: https://pinchofyum.com/sticky-ginger-rice-bowls
# ✓ Valid recipe page
#
# Processing URL 231/1280: https://pinchofyum.com/asian-chicken-salad
# ✓ Valid recipe page
#
# Processing URL 232/1280: https://pinchofyum.com/recipes-with-five-ingredients-or-less
# ✗ Not a recipe page
#
# Processing URL 233/1280: https://pinchofyum.com/thats-a-wrap-highlights-from-the-sos-series
# ✗ Not a recipe page
#
# Processing URL 234/1280: https://pinchofyum.com/loaded-bbq-baked-potatoes
# ✓ Valid recipe page
#
# Processing URL 235/1280: https://pinchofyum.com/5-minute-homemade-peanut-butter
# ✓ Valid recipe page
#
# Processing URL 236/1280: https://pinchofyum.com/creamy-garlic-sun-dried-tomato-pasta
# ✓ Valid recipe page
#
# Processing URL 237/1280: https://pinchofyum.com/chicken-enchilada-casserole
# ✓ Valid recipe page
#
# Processing URL 238/1280: https://pinchofyum.com/spicy-salmon-burgers
# ✓ Valid recipe page
#
# Processing URL 239/1280: https://pinchofyum.com/migas-day-every-day
# ✓ Valid recipe page
#
# Processing URL 240/1280: https://pinchofyum.com/basic-awesome-chicken-quinoa-salad
# ✓ Valid recipe page
#
# Processing URL 241/1280: https://pinchofyum.com/black-pepper-stir-fried-udon
# ✓ Valid recipe page
#
# Processing URL 242/1280: https://pinchofyum.com/easy-crockpot-carnitas
# ✓ Valid recipe page
#
# Processing URL 243/1280: https://pinchofyum.com/easy-veggie-enchiladas
# ✓ Valid recipe page
#
# Processing URL 244/1280: https://pinchofyum.com/spinach-and-artichoke-pizza
# ✓ Valid recipe page
#
# Processing URL 245/1280: https://pinchofyum.com/beet-and-burrata-salad-with-fried-bread
# ✓ Valid recipe page
#
# Processing URL 246/1280: https://pinchofyum.com/instant-pot-chicken-and-dumplings
# ✓ Valid recipe page
#
# Processing URL 247/1280: https://pinchofyum.com/sheet-pan-shrimp-and-cauli-rice
# ✓ Valid recipe page
#
# Processing URL 248/1280: https://pinchofyum.com/bbq-jackfruit-sandwiches
# ✓ Valid recipe page
#
# Processing URL 249/1280: https://pinchofyum.com/crockpot-chicken-gnocchi-soup
# ✓ Valid recipe page
#
# Processing URL 250/1280: https://pinchofyum.com/sos-recipes-that-will-save-dinner
# ✗ Not a recipe page
#
# Processing URL 251/1280: https://pinchofyum.com/best-carrot-cake-cupcakes-with-cream-cheese-frosting
# ✓ Valid recipe page
#
# Processing URL 252/1280: https://pinchofyum.com/delicious-rice-recipes
# ✗ Not a recipe page
#
# Processing URL 253/1280: https://pinchofyum.com/spicy-peanut-soba-noodle-salad
# ✓ Valid recipe page
#
# Processing URL 254/1280: https://pinchofyum.com/quick-homemade-ramen
# ✓ Valid recipe page
#
# Processing URL 255/1280: https://pinchofyum.com/spicy-shrimp-avocado-salad-miso-dressing
# ✓ Valid recipe page
#
# Processing URL 256/1280: https://pinchofyum.com/rainbow-chicken-salad-almond-honey-mustard-dressing
# ✓ Valid recipe page
#
# Processing URL 257/1280: https://pinchofyum.com/the-best-detox-crockpot-lentil-soup
# ✓ Valid recipe page
#
# Processing URL 258/1280: https://pinchofyum.com/best-mushroom-recipes-to-convert-mushroom-haters
# ✗ Not a recipe page
#
# Processing URL 259/1280: https://pinchofyum.com/creamy-chicken-quinoa-broccoli-casserole
# ✓ Valid recipe page
#
# Processing URL 260/1280: https://pinchofyum.com/favorite-peanut-butter-recipes
# ✗ Not a recipe page
#
# Processing URL 261/1280: https://pinchofyum.com/30-minute-spicy-ancho-turkey-chili
# ✓ Valid recipe page
#
# Processing URL 262/1280: https://pinchofyum.com/spicy-sausage-rigatoni
# ✓ Valid recipe page
#
# Processing URL 263/1280: https://pinchofyum.com/garlic-butter-white-wine-shrimp-linguine
# ✓ Valid recipe page
#
# Processing URL 264/1280: https://pinchofyum.com/vegetarian-recipes-we-eat-week-after-week
# ✗ Not a recipe page
#
# Processing URL 265/1280: https://pinchofyum.com/basic-awesome-vegetarian-lasagna
# ✓ Valid recipe page
#
# Processing URL 266/1280: https://pinchofyum.com/15-minute-cauliflower-fried-rice
# ✓ Valid recipe page
#
# Processing URL 267/1280: https://pinchofyum.com/5-minute-spicy-chickpea-salad
# ✓ Valid recipe page
#
# Processing URL 268/1280: https://pinchofyum.com/our-favorite-vegetarian-bloggers-and-books-from-veggie-loving-cooks
# ✗ Not a recipe page
#
# Processing URL 269/1280: https://pinchofyum.com/plantain-and-pinto-stew-with-aji-verde
# ✓ Valid recipe page
#
# Processing URL 270/1280: https://pinchofyum.com/maple-quinoa-granola
# ✓ Valid recipe page
#
# Processing URL 271/1280: https://pinchofyum.com/how-to-eat-more-veggies-in-your-everyday-meals
# ✗ Not a recipe page
#
# Processing URL 272/1280: https://pinchofyum.com/portobello-french-dip-with-horseradish-aioli
# ✓ Valid recipe page
#
# Processing URL 273/1280: https://pinchofyum.com/the-ultimate-guide-to-keeping-produce-fresh
# ✗ Not a recipe page
#
# Processing URL 274/1280: https://pinchofyum.com/creamy-kale-pasta-2
# ✓ Valid recipe page
#
# Processing URL 275/1280: https://pinchofyum.com/plant-powered
# ✗ Not a recipe page
#
# Processing URL 276/1280: https://pinchofyum.com/favorite-drink-recipes
# ✗ Not a recipe page
#
# Processing URL 277/1280: https://pinchofyum.com/creamy-tomato-lasagna-florentine
# ✓ Valid recipe page
#
# Processing URL 278/1280: https://pinchofyum.com/old-school-homemade-oreos
# ✓ Valid recipe page
#
# Processing URL 279/1280: https://pinchofyum.com/red-curry-lentils
# ✓ Valid recipe page
#
# Processing URL 280/1280: https://pinchofyum.com/biscuits-and-gravy-egg-bake
# ✓ Valid recipe page
#
# Processing URL 281/1280: https://pinchofyum.com/cozy-homemade-peppermint-mocha
# ✓ Valid recipe page
#
# Processing URL 282/1280: https://pinchofyum.com/cozy-veggie-korma
# ✓ Valid recipe page
#
# Processing URL 283/1280: https://pinchofyum.com/instant-pot-mashed-potatoes
# ✓ Valid recipe page
#
# Processing URL 284/1280: https://pinchofyum.com/ways-to-use-your-instant-pot
# ✗ Not a recipe page
#
# Processing URL 285/1280: https://pinchofyum.com/one-hour-sheet-pan-thanksgiving-sides
# ✓ Valid recipe page
#
# Processing URL 286/1280: https://pinchofyum.com/oatmilk-honey-latte
# ✓ Valid recipe page
#
# Processing URL 287/1280: https://pinchofyum.com/sweet-potato-gnocchi
# ✓ Valid recipe page
#
# Processing URL 288/1280: https://pinchofyum.com/sarahs-white-chicken-chili
# ✓ Valid recipe page
#
# Processing URL 289/1280: https://pinchofyum.com/how-to-cook-tofu
# ✗ Not a recipe page
#
# Processing URL 290/1280: https://pinchofyum.com/the-best-soft-chocolate-chip-cookies
# ✓ Valid recipe page
#
# Processing URL 291/1280: https://pinchofyum.com/sheet-pan-jambalaya
# ✓ Valid recipe page
#
# Processing URL 292/1280: https://pinchofyum.com/arroz-con-pollo
# ✓ Valid recipe page
#
# Processing URL 293/1280: https://pinchofyum.com/super-moist-pumpkin-bread
# ✓ Valid recipe page
#
# Processing URL 294/1280: https://pinchofyum.com/baked-shrimp-with-feta-with-grilled-sourdough
# ✓ Valid recipe page
#
# Processing URL 295/1280: https://pinchofyum.com/creamy-red-pepper-pasta-blistered-tomatoes
# ✓ Valid recipe page
#
# Processing URL 296/1280: https://pinchofyum.com/creamy-squash-fettuccine-with-caramelized-onion-and-pancetta
# ✓ Valid recipe page
#
# Processing URL 297/1280: https://pinchofyum.com/chipotle-quinoa-burgers
# ✓ Valid recipe page
#
# Processing URL 298/1280: https://pinchofyum.com/broccoli-cheese-soup
# ✓ Valid recipe page
#
# Processing URL 299/1280: https://pinchofyum.com/back-to-school-recipes
# ✗ Not a recipe page
#
# Processing URL 300/1280: https://pinchofyum.com/lemon-olive-oil-cake
# ✓ Valid recipe page
#
# Processing URL 301/1280: https://pinchofyum.com/best-healthy-fall-recipes
# ✗ Not a recipe page
#
# Processing URL 302/1280: https://pinchofyum.com/grilled-chimichurri-portobellos-with-goat-cheese-mashed-potatoes
# ✓ Valid recipe page
#
# Processing URL 303/1280: https://pinchofyum.com/delicious-sheet-pan-dinners
# ✗ Not a recipe page
#
# Processing URL 304/1280: https://pinchofyum.com/coconut-lime-grilled-chicken-and-rice
# ✓ Valid recipe page
#
# Processing URL 305/1280: https://pinchofyum.com/all-star-slow-cooker-recipes
# ✗ Not a recipe page
#
# Processing URL 306/1280: https://pinchofyum.com/socca-with-whipped-feta
# ✓ Valid recipe page
#
# Processing URL 307/1280: https://pinchofyum.com/deep-dish-smores-bowls-for-two
# ✓ Valid recipe page
#
# Processing URL 308/1280: https://pinchofyum.com/bell-pepper-recipes
# ✗ Not a recipe page
#
# Processing URL 309/1280: https://pinchofyum.com/spicy-tofu-burgers
# ✓ Valid recipe page
#
# Processing URL 310/1280: https://pinchofyum.com/sweet-berry-recipes
# ✗ Not a recipe page
#
# Processing URL 311/1280: https://pinchofyum.com/lemon-herb-pasta-salad
# ✓ Valid recipe page
#
# Processing URL 312/1280: https://pinchofyum.com/cucumber-agua-fresca
# ✓ Valid recipe page
#
# Processing URL 313/1280: https://pinchofyum.com/flavor-packed-jalapeno-recipes
# ✗ Not a recipe page
#
# Processing URL 314/1280: https://pinchofyum.com/sauces-that-make-everything-better
# ✗ Not a recipe page
#
# Processing URL 315/1280: https://pinchofyum.com/the-everything-marinade
# ✓ Valid recipe page
#
# Processing URL 316/1280: https://pinchofyum.com/green-tahini
# ✓ Valid recipe page
#
# Processing URL 317/1280: https://pinchofyum.com/chipotle-cashew-queso
# ✓ Valid recipe page
#
# Processing URL 318/1280: https://pinchofyum.com/favorite-avocado-recipes
# ✗ Not a recipe page
#
# Processing URL 319/1280: https://pinchofyum.com/two-person-banana-cream-pies
# ✓ Valid recipe page
#
# Processing URL 320/1280: https://pinchofyum.com/lemongrass-vermicelli-salad
# ✓ Valid recipe page
#
# Processing URL 321/1280: https://pinchofyum.com/must-have-lemon-recipes
# ✗ Not a recipe page
#
# Processing URL 322/1280: https://pinchofyum.com/peanut-butter-chocolate-chip-cookie-cheesecake-bars
# ✓ Valid recipe page
#
# Processing URL 323/1280: https://pinchofyum.com/corn-avocado-and-quinoa-salad-with-marinated-tomatoes
# ✓ Valid recipe page
#
# Processing URL 324/1280: https://pinchofyum.com/5-ingredient-marinated-tomatoes
# ✓ Valid recipe page
#
# Processing URL 325/1280: https://pinchofyum.com/fresh-tomato-recipes
# ✗ Not a recipe page
#
# Processing URL 326/1280: https://pinchofyum.com/recipes-to-save-you-when-you-just-dont-feel-like-cooking
# ✗ Not a recipe page
#
# Processing URL 327/1280: https://pinchofyum.com/caramelized-pork-tacos-with-pineapple-salsa
# ✓ Valid recipe page
#
# Processing URL 328/1280: https://pinchofyum.com/creamy-shrimp-pasta-with-corn-and-tomatoes
# ✓ Valid recipe page
#
# Processing URL 329/1280: https://pinchofyum.com/delicious-quinoa-recipes
# ✗ Not a recipe page
#
# Processing URL 330/1280: https://pinchofyum.com/mango-kiwi-coolers
# ✓ Valid recipe page
#
# Processing URL 331/1280: https://pinchofyum.com/easy-no-bake-desserts
# ✗ Not a recipe page
#
# Processing URL 332/1280: https://pinchofyum.com/couscous-salad-with-lime-basil-vinaigrette
# ✓ Valid recipe page
#
# Processing URL 333/1280: https://pinchofyum.com/curry-chicken-salad
# ✓ Valid recipe page
#
# Processing URL 334/1280: https://pinchofyum.com/the-la-chop
# ✓ Valid recipe page
#
# Processing URL 335/1280: https://pinchofyum.com/healthy-ish-recipes
# ✗ Not a recipe page
#
# Processing URL 336/1280: https://pinchofyum.com/roasted-tomato-puttanesca
# ✓ Valid recipe page
#
# Processing URL 337/1280: https://pinchofyum.com/best-sugar-free-recipes
# ✗ Not a recipe page
#
# Processing URL 338/1280: https://pinchofyum.com/grilled-sausage-and-peppers-with-garlic-aioli
# ✓ Valid recipe page
#
# Processing URL 339/1280: https://pinchofyum.com/garlic-parmesan-shellbows
# ✓ Valid recipe page
#
# Processing URL 340/1280: https://pinchofyum.com/beef-recipes
# ✗ Not a recipe page
#
# Processing URL 341/1280: https://pinchofyum.com/triple-berry-cheesecake-muffins
# ✓ Valid recipe page
#
# Processing URL 342/1280: https://pinchofyum.com/spring-quiche
# ✓ Valid recipe page
#
# Processing URL 343/1280: https://pinchofyum.com/best-sandwiches-burgers-and-wraps
# ✗ Not a recipe page
#
# Processing URL 344/1280: https://pinchofyum.com/homemade-cauliflower-gnocchi
# ✓ Valid recipe page
#
# Processing URL 345/1280: https://pinchofyum.com/lentil-recipes
# ✗ Not a recipe page
#
# Processing URL 346/1280: https://pinchofyum.com/caprese-chicken-with-smashed-potatoes
# ✓ Valid recipe page
#
# Processing URL 347/1280: https://pinchofyum.com/spinach-recipes
# ✗ Not a recipe page
#
# Processing URL 348/1280: https://pinchofyum.com/pantry-recipes
# ✗ Not a recipe page
#
# Processing URL 349/1280: https://pinchofyum.com/carrot-recipes
# ✗ Not a recipe page
#
# Processing URL 350/1280: https://pinchofyum.com/deep-dish-cookie-bowls
# ✓ Valid recipe page
#
# Processing URL 351/1280: https://pinchofyum.com/easy-italian-recipes
# ✗ Not a recipe page
#
# Processing URL 352/1280: https://pinchofyum.com/mushroom-bowls-with-kale-pesto
# ✓ Valid recipe page
#
# Processing URL 353/1280: https://pinchofyum.com/three-cheese-baked-ziti
# ✓ Valid recipe page
#
# Processing URL 354/1280: https://pinchofyum.com/instant-pot-buffalo-chicken-tacos
# ✓ Valid recipe page
#
# Processing URL 355/1280: https://pinchofyum.com/vegetarian-chili
# ✓ Valid recipe page
#
# Processing URL 356/1280: https://pinchofyum.com/sesame-beef-and-broccoli
# ✓ Valid recipe page
#
# Processing URL 357/1280: https://pinchofyum.com/pork-recipes
# ✗ Not a recipe page
#
# Processing URL 358/1280: https://pinchofyum.com/queso-chicken-chili
# ✓ Valid recipe page
#
# Processing URL 359/1280: https://pinchofyum.com/instant-pot-pot-roast
# ✓ Valid recipe page
#
# Processing URL 360/1280: https://pinchofyum.com/asian-noodles
# ✗ Not a recipe page
#
# Processing URL 361/1280: https://pinchofyum.com/date-night-lemon-pappardelle-with-shrimp
# ✓ Valid recipe page
#
# Processing URL 362/1280: https://pinchofyum.com/kale-recipes
# ✗ Not a recipe page
#
# Processing URL 363/1280: https://pinchofyum.com/creamy-thai-sweet-potato-curry
# ✓ Valid recipe page
#
# Processing URL 364/1280: https://pinchofyum.com/eating-in-real-life-part-3
# ✗ Not a recipe page
#
# Processing URL 365/1280: https://pinchofyum.com/date-night-recipes
# ✗ Not a recipe page
#
# Processing URL 366/1280: https://pinchofyum.com/sheet-pan-chicken-pitas
# ✓ Valid recipe page
#
# Processing URL 367/1280: https://pinchofyum.com/carrot-muffins
# ✓ Valid recipe page
#
# Processing URL 368/1280: https://pinchofyum.com/easy-mexican-recipes
# ✗ Not a recipe page
#
# Processing URL 369/1280: https://pinchofyum.com/eating-in-real-life-sugar-free-part-2
# ✗ Not a recipe page
#
# Processing URL 370/1280: https://pinchofyum.com/cauliflower-walnut-vegetarian-taco-meat
# ✓ Valid recipe page
#
# Processing URL 371/1280: https://pinchofyum.com/cashew-golden-milk-latte
# ✓ Valid recipe page
#
# Processing URL 372/1280: https://pinchofyum.com/best-easy-fish-tacos
# ✓ Valid recipe page
#
# Processing URL 373/1280: https://pinchofyum.com/chicken-tikka-masala
# ✓ Valid recipe page
#
# Processing URL 374/1280: https://pinchofyum.com/eating-in-real-life-sugar-free-part-1
# ✗ Not a recipe page
#
# Processing URL 375/1280: https://pinchofyum.com/sweet-potato-peanut-soup
# ✓ Valid recipe page
#
# Processing URL 376/1280: https://pinchofyum.com/roasted-cauliflower-hummus-bowls
# ✓ Valid recipe page
#
# Processing URL 377/1280: https://pinchofyum.com/winter-grain-bowl-with-balsamic-dressing
# ✓ Valid recipe page
#
# Processing URL 378/1280: https://pinchofyum.com/instant-pot-chicken-cacciatore
# ✓ Valid recipe page
#
# Processing URL 379/1280: https://pinchofyum.com/best-healthy-winter-recipes
# ✗ Not a recipe page
#
# Processing URL 380/1280: https://pinchofyum.com/everything-you-need-to-know-about-sugar-free-january
# ✗ Not a recipe page
#
# Processing URL 381/1280: https://pinchofyum.com/easy-zucchini-recipes
# ✗ Not a recipe page
#
# Processing URL 382/1280: https://pinchofyum.com/best-recipes-to-make-before-the-end-of-2019
# ✗ Not a recipe page
#
# Processing URL 383/1280: https://pinchofyum.com/cauliflower-recipes
# ✗ Not a recipe page
#
# Processing URL 384/1280: https://pinchofyum.com/tortellini-soup
# ✓ Valid recipe page
#
# Processing URL 385/1280: https://pinchofyum.com/coconut-curry-salmon
# ✓ Valid recipe page
#
# Processing URL 386/1280: https://pinchofyum.com/no-knead-cheese-bread
# ✓ Valid recipe page
#
# Processing URL 387/1280: https://pinchofyum.com/easy-chocolate-desserts
# ✗ Not a recipe page
#
# Processing URL 388/1280: https://pinchofyum.com/spicy-peanut-tofu-bowls
# ✓ Valid recipe page
#
# Processing URL 389/1280: https://pinchofyum.com/coziest-comfort-food-recipes
# ✗ Not a recipe page
#
# Processing URL 390/1280: https://pinchofyum.com/squash-salad-with-kale
# ✓ Valid recipe page
#
# Processing URL 391/1280: https://pinchofyum.com/thanksgiving-recipes
# ✗ Not a recipe page
#
# Processing URL 392/1280: https://pinchofyum.com/greek-baked-orzo
# ✓ Valid recipe page
#
# Processing URL 393/1280: https://pinchofyum.com/best-healthy-sweet-potato-recipes
# ✗ Not a recipe page
#
# Processing URL 394/1280: https://pinchofyum.com/feel-good-apple-muffins
# ✓ Valid recipe page
#
# Processing URL 395/1280: https://pinchofyum.com/easy-appetizers
# ✗ Not a recipe page
#
# Processing URL 396/1280: https://pinchofyum.com/ridiculous-baked-gnocchi-with-vodka-sauce
# ✓ Valid recipe page
#
# Processing URL 397/1280: https://pinchofyum.com/best-dip-recipes
# ✗ Not a recipe page
#
# Processing URL 398/1280: https://pinchofyum.com/spicy-shrimp-cauliflower-mash-roasted-kale
# ✓ Valid recipe page
#
# Processing URL 399/1280: https://pinchofyum.com/easy-pumpkin-recipes
# ✗ Not a recipe page
#
# Processing URL 400/1280: https://pinchofyum.com/best-instant-pot-recipes
# ✗ Not a recipe page
#
# Processing URL 401/1280: https://pinchofyum.com/chicken-meatballs-with-peppers-and-orzo
# ✓ Valid recipe page
#
# Processing URL 402/1280: https://pinchofyum.com/pumpkin-rigatoni
# ✓ Valid recipe page
#
# Processing URL 403/1280: https://pinchofyum.com/paprika-chicken-pasta
# ✓ Valid recipe page
#
# Processing URL 404/1280: https://pinchofyum.com/quinoa-sweet-potato-salad
# ✓ Valid recipe page
#
# Processing URL 405/1280: https://pinchofyum.com/instant-pot-cauliflower-curry
# ✓ Valid recipe page
#
# Processing URL 406/1280: https://pinchofyum.com/easy-vegan-burrito-bowls
# ✓ Valid recipe page
#
# Processing URL 407/1280: https://pinchofyum.com/pumpkin-energy-bites
# ✓ Valid recipe page
#
# Processing URL 408/1280: https://pinchofyum.com/easy-tofu-recipes
# ✗ Not a recipe page
#
# Processing URL 409/1280: https://pinchofyum.com/bbq-tofu
# ✓ Valid recipe page
#
# Processing URL 410/1280: https://pinchofyum.com/egg-recipes
# ✗ Not a recipe page
#
# Processing URL 411/1280: https://pinchofyum.com/instant-pot-italian-beef
# ✓ Valid recipe page
#
# Processing URL 412/1280: https://pinchofyum.com/easy-weeknight-dinners
# ✗ Not a recipe page
#
# Processing URL 413/1280: https://pinchofyum.com/breakfast-crunchwrap
# ✓ Valid recipe page
#
# Processing URL 414/1280: https://pinchofyum.com/easy-shrimp-recipes
# ✗ Not a recipe page
#
# Processing URL 415/1280: https://pinchofyum.com/best-taco-recipes
# ✗ Not a recipe page
#
# Processing URL 416/1280: https://pinchofyum.com/vegan-sheet-pan-fajitas-with-chipotle-queso
# ✓ Valid recipe page
#
# Processing URL 417/1280: https://pinchofyum.com/easy-baking-recipes
# ✗ Not a recipe page
#
# Processing URL 418/1280: https://pinchofyum.com/farmers-market-pasta-with-walnut-pesto
# ✓ Valid recipe page
#
# Processing URL 419/1280: https://pinchofyum.com/two-person-raspberry-crumbles
# ✓ Valid recipe page
#
# Processing URL 420/1280: https://pinchofyum.com/bbq-salmon-mango-salsa
# ✓ Valid recipe page
#
# Processing URL 421/1280: https://pinchofyum.com/easy-summer-dinners
# ✗ Not a recipe page
#
# Processing URL 422/1280: https://pinchofyum.com/easy-brunch-recipes
# ✗ Not a recipe page
#
# Processing URL 423/1280: https://pinchofyum.com/elote-queso
# ✓ Valid recipe page
#
# Processing URL 424/1280: https://pinchofyum.com/best-healthy-chicken-recipes
# ✗ Not a recipe page
#
# Processing URL 425/1280: https://pinchofyum.com/korean-bbq-style-cauliflower-lettuce-wraps
# ✓ Valid recipe page
#
# Processing URL 426/1280: https://pinchofyum.com/easy-dessert-recipes
# ✗ Not a recipe page
#
# Processing URL 427/1280: https://pinchofyum.com/instant-pot-red-curry-lentils
# ✓ Valid recipe page
#
# Processing URL 428/1280: https://pinchofyum.com/fluffiest-blueberry-pancakes
# ✓ Valid recipe page
#
# Processing URL 429/1280: https://pinchofyum.com/easy-pasta-recipes
# ✗ Not a recipe page
#
# Processing URL 430/1280: https://pinchofyum.com/chopped-thai-chicken-salad
# ✓ Valid recipe page
#
# Processing URL 431/1280: https://pinchofyum.com/best-healthy-meal-prep-recipes
# ✗ Not a recipe page
#
# Processing URL 432/1280: https://pinchofyum.com/5-ingredient-spicy-pork
# ✓ Valid recipe page
#
# Processing URL 433/1280: https://pinchofyum.com/best-healthy-vegan-recipes
# ✗ Not a recipe page
#
# Processing URL 434/1280: https://pinchofyum.com/kale-chimichurri
# ✓ Valid recipe page
#
# Processing URL 435/1280: https://pinchofyum.com/chipotle-tahini
# ✓ Valid recipe page
#
# Processing URL 436/1280: https://pinchofyum.com/jalapeno-ranch
# ✓ Valid recipe page
#
# Processing URL 437/1280: https://pinchofyum.com/roasted-red-pepper-sauce
# ✓ Valid recipe page
#
# Processing URL 438/1280: https://pinchofyum.com/the-very-best-peanut-sauce
# ✓ Valid recipe page
#
# Processing URL 439/1280: https://pinchofyum.com/best-healthy-spring-recipes
# ✗ Not a recipe page
#
# Processing URL 440/1280: https://pinchofyum.com/best-healthy-breakfast-recipes
# ✗ Not a recipe page
#
# Processing URL 441/1280: https://pinchofyum.com/blender-lemon-pie
# ✓ Valid recipe page
#
# Processing URL 442/1280: https://pinchofyum.com/coconut-curry-ramen
# ✓ Valid recipe page
#
# Processing URL 443/1280: https://pinchofyum.com/best-healthy-gluten-free-recipes
# ✗ Not a recipe page
#
# Processing URL 444/1280: https://pinchofyum.com/brussels-kale-caesar-with-cheezy-garlic-croutons
# ✓ Valid recipe page
#
# Processing URL 445/1280: https://pinchofyum.com/cheezy-garlic-croutons
# ✓ Valid recipe page
#
# Processing URL 446/1280: https://pinchofyum.com/instant-pot-hawaiian-chicken-tacos
# ✓ Valid recipe page
#
# Processing URL 447/1280: https://pinchofyum.com/best-healthy-bowl-recipes
# ✗ Not a recipe page
#
# Processing URL 448/1280: https://pinchofyum.com/egg-and-croissant-brunch-bake
# ✓ Valid recipe page
#
# Processing URL 449/1280: https://pinchofyum.com/best-healthy-snack-recipes
# ✗ Not a recipe page
#
# Processing URL 450/1280: https://pinchofyum.com/best-healthy-summer-salad-recipes
# ✗ Not a recipe page
#
# Processing URL 451/1280: https://pinchofyum.com/raw-vegan-carrot-cake-bites
# ✓ Valid recipe page
#
# Processing URL 452/1280: https://pinchofyum.com/30-minute-meal-prep-sheet-pan-chicken-tinga-bowls
# ✓ Valid recipe page
#
# Processing URL 453/1280: https://pinchofyum.com/best-healthy-vegetarian-recipes
# ✗ Not a recipe page
#
# Processing URL 454/1280: https://pinchofyum.com/chipotle-tahini-bowls
# ✓ Valid recipe page
#
# Processing URL 455/1280: https://pinchofyum.com/15-minute-meal-prep-breakfast-sandwiches
# ✓ Valid recipe page
#
# Processing URL 456/1280: https://pinchofyum.com/one-ingredient-socca
# ✓ Valid recipe page
#
# Processing URL 457/1280: https://pinchofyum.com/15-minute-meal-prep-sesame-noodle-bowls
# ✓ Valid recipe page
#
# Processing URL 458/1280: https://pinchofyum.com/oven-risotto-with-garlic-roasted-mushrooms-and-arugula
# ✓ Valid recipe page
#
# Processing URL 459/1280: https://pinchofyum.com/15-minute-meal-prep-egg-roll-in-a-bowl
# ✓ Valid recipe page
#
# Processing URL 460/1280: https://pinchofyum.com/best-healthy-soup-recipes
# ✗ Not a recipe page
#
# Processing URL 461/1280: https://pinchofyum.com/date-night-rigatoni
# ✓ Valid recipe page
#
# Processing URL 462/1280: https://pinchofyum.com/30-minute-meal-prep-roasted-vegetable-bowls-with-green-tahini
# ✓ Valid recipe page
#
# Processing URL 463/1280: https://pinchofyum.com/5-minute-vegan-yogurt
# ✓ Valid recipe page
#
# Processing URL 464/1280: https://pinchofyum.com/red-curry-noodles
# ✓ Valid recipe page
#
# Processing URL 465/1280: https://pinchofyum.com/15-minute-meal-prep-cauliflower-fried-rice-with-crispy-tofu
# ✓ Valid recipe page
#
# Processing URL 466/1280: https://pinchofyum.com/what-i-ate-wednesday-week-4
# ✗ Not a recipe page
#
# Processing URL 467/1280: https://pinchofyum.com/5-ingredient-vegan-vodka-pasta
# ✓ Valid recipe page
#
# Processing URL 468/1280: https://pinchofyum.com/lentil-greek-salads-with-dill-sauce
# ✓ Valid recipe page
#
# Processing URL 469/1280: https://pinchofyum.com/coconut-oil-granola-remix
# ✓ Valid recipe page
#
# Processing URL 470/1280: https://pinchofyum.com/what-i-ate-wednesday-week-3
# ✗ Not a recipe page
#
# Processing URL 471/1280: https://pinchofyum.com/quinoa-crunch-salad-with-peanut-dressing
# ✓ Valid recipe page
#
# Processing URL 472/1280: https://pinchofyum.com/15-minute-meal-prep-cilantro-lime-chicken-and-lentils
# ✓ Valid recipe page
#
# Processing URL 473/1280: https://pinchofyum.com/instant-pot-sweet-potato-tortilla-soup
# ✓ Valid recipe page
#
# Processing URL 474/1280: https://pinchofyum.com/what-i-ate-wednesday-week-2
# ✗ Not a recipe page
#
# Processing URL 475/1280: https://pinchofyum.com/garlic-butter-baked-penne
# ✓ Valid recipe page
#
# Processing URL 476/1280: https://pinchofyum.com/15-minute-meal-prep-creole-chicken-and-sausage
# ✓ Valid recipe page
#
# Processing URL 477/1280: https://pinchofyum.com/what-i-ate-wednesday-week-1
# ✗ Not a recipe page
#
# Processing URL 478/1280: https://pinchofyum.com/lemon-chicken-soup-with-orzo
# ✓ Valid recipe page
#
# Processing URL 479/1280: https://pinchofyum.com/brussels-sprouts-tacos
# ✓ Valid recipe page
#
# Processing URL 480/1280: https://pinchofyum.com/14-must-bake-holiday-cookie-recipes
# ✗ Not a recipe page
#
# Processing URL 481/1280: https://pinchofyum.com/how-to-cook-chicken
# ✗ Not a recipe page
#
# Processing URL 482/1280: https://pinchofyum.com/how-to-make-hummus
# ✗ Not a recipe page
#
# Processing URL 483/1280: https://pinchofyum.com/how-to-make-buttermilk
# ✗ Not a recipe page
#
# Processing URL 484/1280: https://pinchofyum.com/how-to-peel-garlic
# ✗ Not a recipe page
#
# Processing URL 485/1280: https://pinchofyum.com/healthy-mexican-sweet-potato-skins
# ✓ Valid recipe page
#
# Processing URL 486/1280: https://pinchofyum.com/12-favorite-instant-pot-soup-recipes
# ✗ Not a recipe page
#
# ...
# ✓ Valid recipe page
#
# Processing URL 1119/1280: https://pinchofyum.com/creamy-baked-corn
# ✓ Valid recipe page
#
# Processing URL 1120/1280: https://pinchofyum.com/fluffy-sugar-cookies-vanilla-frosting
# ✓ Valid recipe page
#
# Processing URL 1121/1280: https://pinchofyum.com/butternut-squash-pecan-pancakes
# ✓ Valid recipe page
#
# Processing URL 1122/1280: https://pinchofyum.com/holiday-pretzel-bites
# ✓ Valid recipe page
#
# Processing URL 1123/1280: https://pinchofyum.com/spicy-sweet-squash-bowl
# ✓ Valid recipe page
#
# Processing URL 1124/1280: https://pinchofyum.com/bacon-pear-and-raspberry-grilled-cheese
# ✓ Valid recipe page
#
# Processing URL 1125/1280: https://pinchofyum.com/brown-sugar-cookies
# ✓ Valid recipe page
#
# Processing URL 1126/1280: https://pinchofyum.com/vanilla-glazed-apple-cinnamon-muffins
# ✓ Valid recipe page
#
# Processing URL 1127/1280: https://pinchofyum.com/skinny-veggie-lasagna
# ✓ Valid recipe page
#
# Processing URL 1128/1280: https://pinchofyum.com/hot-fudge-cake-with-peanut-butter-sauce
# ✓ Valid recipe page
#
# Processing URL 1129/1280: https://pinchofyum.com/powered-up-pumpkin-oats
# ✓ Valid recipe page
#
# Processing URL 1130/1280: https://pinchofyum.com/healthy-bacon-pumpkin-pasta
# ✓ Valid recipe page
#
# Processing URL 1131/1280: https://pinchofyum.com/peanut-butter-cheesecake-brownies
# ✓ Valid recipe page
#
# Processing URL 1132/1280: https://pinchofyum.com/spicy-sausage-posole
# ✓ Valid recipe page
#
# Processing URL 1133/1280: https://pinchofyum.com/baked-gingerbread-mini-donuts
# ✓ Valid recipe page
#
# Processing URL 1134/1280: https://pinchofyum.com/cheesy-baked-eggplant-pizza
# ✓ Valid recipe page
#
# Processing URL 1135/1280: https://pinchofyum.com/pumpkin-bars-with-old-fashioned-caramel-frosting
# ✓ Valid recipe page
#
# Processing URL 1136/1280: https://pinchofyum.com/baked-apple-pancake-with-apple-cider-syrup
# ✓ Valid recipe page
#
# Processing URL 1137/1280: https://pinchofyum.com/japanese-halloween
# ✗ Not a recipe page
#
# Processing URL 1138/1280: https://pinchofyum.com/curry-roasted-red-pepper-and-eggplant-soup
# ✓ Valid recipe page
#
# Processing URL 1139/1280: https://pinchofyum.com/harvest-salad-with-creamy-maple-sauce
# ✓ Valid recipe page
#
# Processing URL 1140/1280: https://pinchofyum.com/pumpkin-dip-for-gingersnaps
# ✓ Valid recipe page
#
# Processing URL 1141/1280: https://pinchofyum.com/classic-homemade-applesauce
# ✓ Valid recipe page
#
# Processing URL 1142/1280: https://pinchofyum.com/chicken-zucchini-pasta
# ✓ Valid recipe page
#
# Processing URL 1143/1280: https://pinchofyum.com/maple-banana-bread
# ✓ Valid recipe page
#
# Processing URL 1144/1280: https://pinchofyum.com/marisas-spicy-chicken-tostadas
# ✓ Valid recipe page
#
# Processing URL 1145/1280: https://pinchofyum.com/pumpkin-bundt-cake-with-cinnamon-glaze
# ✓ Valid recipe page
#
# Processing URL 1146/1280: https://pinchofyum.com/cheesy-meatless-meatballs-with-marinara
# ✓ Valid recipe page
#
# Processing URL 1147/1280: https://pinchofyum.com/apple-bran-oats
# ✓ Valid recipe page
#
# Processing URL 1148/1280: https://pinchofyum.com/butternut-squash-mac-n-cheese-with-caramelized-onions-apples-and-bacon
# ✓ Valid recipe page
#
# Processing URL 1149/1280: https://pinchofyum.com/mozzarella-basil-and-corn-quesadilla
# ✓ Valid recipe page
#
# Processing URL 1150/1280: https://pinchofyum.com/maple-vanilla-almond-clusters
# ✓ Valid recipe page
#
# Processing URL 1151/1280: https://pinchofyum.com/classic-apple-crisp
# ✓ Valid recipe page
#
# Processing URL 1152/1280: https://pinchofyum.com/southwest-black-bean-casserole
# ✓ Valid recipe page
#
# Processing URL 1153/1280: https://pinchofyum.com/raisin-bran-muffins
# ✓ Valid recipe page
#
# Processing URL 1154/1280: https://pinchofyum.com/smoky-white-bean-chili-with-pork
# ✓ Valid recipe page
#
# Processing URL 1155/1280: https://pinchofyum.com/caramel-corn-bars
# ✓ Valid recipe page
#
# Processing URL 1156/1280: https://pinchofyum.com/chipotle-turkey-burger
# ✓ Valid recipe page
#
# Processing URL 1157/1280: https://pinchofyum.com/nectarine-basil-salsa
# ✓ Valid recipe page
#
# Processing URL 1158/1280: https://pinchofyum.com/fluffy-peanut-butter-cookies
# ✗ Not a recipe page
#
# Processing URL 1159/1280: https://pinchofyum.com/spicy-peanut-chicken-salad
# ✓ Valid recipe page
#
# Processing URL 1160/1280: https://pinchofyum.com/hot-dog-bar
# ✗ Not a recipe page
#
# Processing URL 1161/1280: https://pinchofyum.com/fresh-blueberry-tarts
# ✓ Valid recipe page
#
# Processing URL 1162/1280: https://pinchofyum.com/farmers-market-flatbread-pizza
# ✓ Valid recipe page
#
# Processing URL 1163/1280: https://pinchofyum.com/mango-chicken-salad
# ✓ Valid recipe page
#
# Processing URL 1164/1280: https://pinchofyum.com/fudgy-oreo-brownies
# ✓ Valid recipe page
#
# Processing URL 1165/1280: https://pinchofyum.com/red-pepper-goat-cheese-panini
# ✓ Valid recipe page
#
# Processing URL 1166/1280: https://pinchofyum.com/ginger-melon-chillers
# ✓ Valid recipe page
#
# Processing URL 1167/1280: https://pinchofyum.com/creamy-cilantro-dressing
# ✓ Valid recipe page
#
# Processing URL 1168/1280: https://pinchofyum.com/pb-cookie-dough-bites
# ✓ Valid recipe page
#
# Processing URL 1169/1280: https://pinchofyum.com/chocolate-scotcheroos
# ✓ Valid recipe page
#
# Processing URL 1170/1280: https://pinchofyum.com/crunchy-pecan-granola
# ✓ Valid recipe page
#
# Processing URL 1171/1280: https://pinchofyum.com/5-minute-green-curry-salad
# ✓ Valid recipe page
#
# Processing URL 1172/1280: https://pinchofyum.com/real-strawberry-lemonade
# ✓ Valid recipe page
#
# Processing URL 1173/1280: https://pinchofyum.com/mapleglazedpumpkinmuffins
# ✓ Valid recipe page
#
# Processing URL 1174/1280: https://pinchofyum.com/creamy-basil-dip
# ✓ Valid recipe page
#
# Processing URL 1175/1280: https://pinchofyum.com/farmers-market-pasta
# ✓ Valid recipe page
#
# Processing URL 1176/1280: https://pinchofyum.com/garlic-edamame
# ✓ Valid recipe page
#
# Processing URL 1177/1280: https://pinchofyum.com/classic-bean-burgers
# ✓ Valid recipe page
#
# Processing URL 1178/1280: https://pinchofyum.com/peanut-butter-pretzel-cookies
# ✓ Valid recipe page
#
# Processing URL 1179/1280: https://pinchofyum.com/mango-black-bean-coconut-tacos
# ✓ Valid recipe page
#
# Processing URL 1180/1280: https://pinchofyum.com/honey-butter-spread-on-lemon-cake
# ✓ Valid recipe page
#
# Processing URL 1181/1280: https://pinchofyum.com/garlic-shrimp-and-zucchini-wrap
# ✓ Valid recipe page
#
# Processing URL 1182/1280: https://pinchofyum.com/sweet-zucchini-pancakes
# ✗ Not a recipe page
#
# Processing URL 1183/1280: https://pinchofyum.com/creamy-garlic-scape-dip
# ✓ Valid recipe page
#
# Processing URL 1184/1280: https://pinchofyum.com/wild-rice-flatbread
# ✓ Valid recipe page
#
# Processing URL 1185/1280: https://pinchofyum.com/roasted-cherry-brownies
# ✓ Valid recipe page
#
# Processing URL 1186/1280: https://pinchofyum.com/greek-salad-with-paprika-croutons
# ✓ Valid recipe page
#
# Processing URL 1187/1280: https://pinchofyum.com/portobello-red-pepper-pesto-pizza
# ✓ Valid recipe page
#
# Processing URL 1188/1280: https://pinchofyum.com/milk-chocolate-cupcakes-with-avocado-buttercream
# ✓ Valid recipe page
#
# Processing URL 1189/1280: https://pinchofyum.com/avocado-blue-cheese-dressing
# ✓ Valid recipe page
#
# Processing URL 1190/1280: https://pinchofyum.com/cinnamon-sugar-radish-chips
# ✓ Valid recipe page
#
# Processing URL 1191/1280: https://pinchofyum.com/spicy-hummus
# ✓ Valid recipe page
#
# Processing URL 1192/1280: https://pinchofyum.com/pb-banana-power-oats
# ✓ Valid recipe page
#
# Processing URL 1193/1280: https://pinchofyum.com/nutella-and-peanut-butter-clusters
# ✓ Valid recipe page
#
# Processing URL 1194/1280: https://pinchofyum.com/grilled-barbeque-onion-and-smoked-gouda-quesadillas
# ✓ Valid recipe page
#
# Processing URL 1195/1280: https://pinchofyum.com/parmesan-pesto-veggie-sandwich
# ✓ Valid recipe page
#
# Processing URL 1196/1280: https://pinchofyum.com/chocolate-marshmallow-graham-bars
# ✓ Valid recipe page
#
# Processing URL 1197/1280: https://pinchofyum.com/cornmeal-blueberry-muffins
# ✓ Valid recipe page
#
# Processing URL 1198/1280: https://pinchofyum.com/coconut-caramel-malt
# ✓ Valid recipe page
#
# Processing URL 1199/1280: https://pinchofyum.com/brownie-fudge-trifle
# ✓ Valid recipe page
#
# Processing URL 1200/1280: https://pinchofyum.com/roasted-sweet-potato-salad
# ✓ Valid recipe page
#
# Processing URL 1201/1280: https://pinchofyum.com/waffle-berry-stacks
# ✓ Valid recipe page
#
# Processing URL 1202/1280: https://pinchofyum.com/lemon-pancakes-and-blackberry-syrup
# ✓ Valid recipe page
#
# Processing URL 1203/1280: https://pinchofyum.com/garlic-parmesan-burgers-creamed-spinach-sauce
# ✓ Valid recipe page
#
# Processing URL 1204/1280: https://pinchofyum.com/lemon-berry-smoothie
# ✓ Valid recipe page
#
# Processing URL 1205/1280: https://pinchofyum.com/spicy-corn-salad
# ✓ Valid recipe page
#
# Processing URL 1206/1280: https://pinchofyum.com/cinnamon-sugar-mini-donuts
# ✓ Valid recipe page
#
# Processing URL 1207/1280: https://pinchofyum.com/baked-zucchini-fries
# ✓ Valid recipe page
#
# Processing URL 1208/1280: https://pinchofyum.com/new-york-times-chocolate-chip-cookies
# ✓ Valid recipe page
#
# Processing URL 1209/1280: https://pinchofyum.com/sausage-and-mozzarella-calzone
# ✓ Valid recipe page
#
# Processing URL 1210/1280: https://pinchofyum.com/indian-street-food-aloo-tikki
# ✓ Valid recipe page
#
# Processing URL 1211/1280: https://pinchofyum.com/smoky-paprika-croutons
# ✓ Valid recipe page
#
# Processing URL 1212/1280: https://pinchofyum.com/roasted-potatoes-with-maple-fig-sauce
# ✓ Valid recipe page
#
# Processing URL 1213/1280: https://pinchofyum.com/peanut-butter-banana-flax-muffins
# ✓ Valid recipe page
#
# Processing URL 1214/1280: https://pinchofyum.com/caprese-penne
# ✓ Valid recipe page
#
# Processing URL 1215/1280: https://pinchofyum.com/triple-berry-pie-bars
# ✓ Valid recipe page
#
# Processing URL 1216/1280: https://pinchofyum.com/roasted-sweet-potatoes-hummus
# ✓ Valid recipe page
#
# Processing URL 1217/1280: https://pinchofyum.com/asparagus-pea-goat-cheese-pizza
# ✓ Valid recipe page
#
# Processing URL 1218/1280: https://pinchofyum.com/asparagus-and-pea-saute
# ✓ Valid recipe page
#
# Processing URL 1219/1280: https://pinchofyum.com/tortilla-chicken-with-salsa-verde
# ✓ Valid recipe page
#
# Processing URL 1220/1280: https://pinchofyum.com/grandmas-butterhorns
# ✓ Valid recipe page
#
# Processing URL 1221/1280: https://pinchofyum.com/artichoke-and-red-pepper-melt
# ✓ Valid recipe page
#
# Processing URL 1222/1280: https://pinchofyum.com/pb-dark-chocolate-hummus
# ✓ Valid recipe page
#
# Processing URL 1223/1280: https://pinchofyum.com/rosemary-goat-cheese-and-wild-rice
# ✓ Valid recipe page
#
# Processing URL 1224/1280: https://pinchofyum.com/double-chocolate-cake-with-buttercream-frosting
# ✓ Valid recipe page
#
# Processing URL 1225/1280: https://pinchofyum.com/stuffed-french-toast
# ✓ Valid recipe page
#
# Processing URL 1226/1280: https://pinchofyum.com/smoked-almond-and-goat-cheese-salad
# ✓ Valid recipe page
#
# Processing URL 1227/1280: https://pinchofyum.com/sausage-and-red-pepper-quiche
# ✓ Valid recipe page
#
# Processing URL 1228/1280: https://pinchofyum.com/avocado-bacon-orzo
# ✓ Valid recipe page
#
# Processing URL 1229/1280: https://pinchofyum.com/avocado-tomatillo-dip
# ✓ Valid recipe page
#
# Processing URL 1230/1280: https://pinchofyum.com/coconut-peanut-butter-oatmeal
# ✓ Valid recipe page
#
# Processing URL 1231/1280: https://pinchofyum.com/orangeberry-shortcake-cookies
# ✓ Valid recipe page
#
# Processing URL 1232/1280: https://pinchofyum.com/grandmas-creamy-lemon-pie
# ✓ Valid recipe page
#
# Processing URL 1233/1280: https://pinchofyum.com/strawberry-breakfast-cakes
# ✓ Valid recipe page
#
# Processing URL 1234/1280: https://pinchofyum.com/spiced-tea-punch
# ✓ Valid recipe page
#
# Processing URL 1235/1280: https://pinchofyum.com/spinach-artichoke-pasta
# ✓ Valid recipe page
#
# Processing URL 1236/1280: https://pinchofyum.com/shrimp-and-feta-orzo
# ✓ Valid recipe page
#
# Processing URL 1237/1280: https://pinchofyum.com/spicy-corn-cake-breakfast-stack
# ✓ Valid recipe page
#
# Processing URL 1238/1280: https://pinchofyum.com/candy-fudge-bars
# ✓ Valid recipe page
#
# Processing URL 1239/1280: https://pinchofyum.com/sweet-potato-doughnuts
# ✓ Valid recipe page
#
# Processing URL 1240/1280: https://pinchofyum.com/green-monster
# ✓ Valid recipe page
#
# Processing URL 1241/1280: https://pinchofyum.com/nuevo-cubano-sandwiches
# ✓ Valid recipe page
#
# Processing URL 1242/1280: https://pinchofyum.com/basil-chicken-lettuce-wraps
# ✓ Valid recipe page
#
# Processing URL 1243/1280: https://pinchofyum.com/asparagus-quesadilla-lasagna
# ✓ Valid recipe page
#
# Processing URL 1244/1280: https://pinchofyum.com/cinnamon-apple-carrot-pancakes
# ✓ Valid recipe page
#
# Processing URL 1245/1280: https://pinchofyum.com/molten-chocolate-cakes
# ✓ Valid recipe page
#
# Processing URL 1246/1280: https://pinchofyum.com/sun-dried-tomato-dill-linguine
# ✓ Valid recipe page
#
# Processing URL 1247/1280: https://pinchofyum.com/marshmallow-monster-cookies
# ✓ Valid recipe page
#
# Processing URL 1248/1280: https://pinchofyum.com/grandmas-apple-crisp
# ✓ Valid recipe page
#
# Processing URL 1249/1280: https://pinchofyum.com/coconut-pineapple-orange-smoothie
# ✓ Valid recipe page
#
# Processing URL 1250/1280: https://pinchofyum.com/sweet-potato-muffins
# ✓ Valid recipe page
#
# Processing URL 1251/1280: https://pinchofyum.com/butternut-squash-lasagna
# ✓ Valid recipe page
#
# Processing URL 1252/1280: https://pinchofyum.com/caramelized-banana-and-fig-oatmeal
# ✓ Valid recipe page
#
# Processing URL 1253/1280: https://pinchofyum.com/roasted-bell-pepper-tostadas
# ✓ Valid recipe page
#
# Processing URL 1254/1280: https://pinchofyum.com/rocky-road-brownies
# ✓ Valid recipe page
#
# Processing URL 1255/1280: https://pinchofyum.com/butternut-squash-black-bean-wrap
# ✓ Valid recipe page
#
# Processing URL 1256/1280: https://pinchofyum.com/strawberry-blinchke-crepes
# ✓ Valid recipe page
#
# Processing URL 1257/1280: https://pinchofyum.com/banana-monkey-bread
# ✓ Valid recipe page
#
# Processing URL 1258/1280: https://pinchofyum.com/gorgonzola-and-bacon-panini
# ✓ Valid recipe page
#
# Processing URL 1259/1280: https://pinchofyum.com/coffee-streusel-bundt-cake
# ✓ Valid recipe page
#
# Processing URL 1260/1280: https://pinchofyum.com/shrimp-and-quinoa-salad
# ✓ Valid recipe page
#
# Processing URL 1261/1280: https://pinchofyum.com/red-pepper-and-artichoke-panini
# ✓ Valid recipe page
#
# Processing URL 1262/1280: https://pinchofyum.com/snickerdoodle-blondies
# ✓ Valid recipe page
#
# Processing URL 1263/1280: https://pinchofyum.com/chocolate-checkered-banana-bread
# ✓ Valid recipe page
#
# Processing URL 1264/1280: https://pinchofyum.com/cheesy-roasted-potato-nachos
# ✓ Valid recipe page
#
# Processing URL 1265/1280: https://pinchofyum.com/deep-dish-chocolate-chip-cookies
# ✓ Valid recipe page
#
# Processing URL 1266/1280: https://pinchofyum.com/creamy-tomato-balsamic-soup
# ✓ Valid recipe page
#
# Processing URL 1267/1280: https://pinchofyum.com/salted-toffee
# ✓ Valid recipe page
#
# Processing URL 1268/1280: https://pinchofyum.com/thai-chicken-salad
# ✓ Valid recipe page
#
# Processing URL 1269/1280: https://pinchofyum.com/minty-chocolate-oreo-truffles
# ✓ Valid recipe page
#
# Processing URL 1270/1280: https://pinchofyum.com/pomegranate-orange-muffins
# ✓ Valid recipe page
#
# Processing URL 1271/1280: https://pinchofyum.com/cheesy-black-bean-risotto
# ✓ Valid recipe page
#
# Processing URL 1272/1280: https://pinchofyum.com/edamame-hummus-wrap
# ✓ Valid recipe page
#
# Processing URL 1273/1280: https://pinchofyum.com/creamy-root-vegetable-stew
# ✓ Valid recipe page
#
# Processing URL 1274/1280: https://pinchofyum.com/roasted-butternut-squash-risotto-with-sugared-walnuts
# ✓ Valid recipe page
#
# Processing URL 1275/1280: https://pinchofyum.com/pumpkin-pecan-cheesecake-parfaits
# ✓ Valid recipe page
#
# Processing URL 1276/1280: https://pinchofyum.com/chili-corn-casserole-with-polenta
# ✓ Valid recipe page
#
# Processing URL 1277/1280: https://pinchofyum.com/tomato-ricotta-pasta-with-broccoli
# ✓ Valid recipe page
#
# Processing URL 1278/1280: https://pinchofyum.com/scotchabrownies
# ✓ Valid recipe page
#
# Processing URL 1279/1280: https://pinchofyum.com/zucchini-fritters-goat-cheese-sauce
# ✓ Valid recipe page
#
# Processing URL 1280/1280: https://pinchofyum.com/morning-grains
# ✗ Not a recipe page
#
# Processing complete!
# Total URLs processed: 1280
# Valid recipe URLs found: 1118
# Valid URLs written to: valid_recipe_urls.txt
