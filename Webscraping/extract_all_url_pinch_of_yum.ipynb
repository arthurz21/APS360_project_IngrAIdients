# %%
import requests
from bs4 import BeautifulSoup
import time

# %%
def get_recipe_urls(base_url, total_pages):
    """
    Scrape recipe URLs from all pages of Pinch of Yum's recipe section
    
    Args:
        base_url (str): The base URL pattern for pagination
        total_pages (int): Total number of pages to scrape
    
    Returns:
        list: List of recipe URLs
    """
    all_recipe_urls = []
    
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }

    # Loop through each page
    for page in range(1, total_pages + 1):
        # Construct the URL for current page
        if page == 1:
            url = "https://pinchofyum.com/recipes/all"
        else:
            url = f"https://pinchofyum.com/recipes/all/page/{page}"
        
        try:
            # Make request to the page
            response = requests.get(url, headers=headers)
            response.raise_for_status()
            
            # Parse HTML
            soup = BeautifulSoup(response.text, 'html.parser')
            
            # Find all recipe article elements
            recipe_articles = soup.find_all('article')
            
            # Extract URLs from articles
            for article in recipe_articles:
                link = article.find('a')
                if link and 'href' in link.attrs:
                    recipe_url = link['href']
                    all_recipe_urls.append(recipe_url)
            
            print(f"Scraped page {page} successfully - Found {len(recipe_articles)} recipes")
            
            # Add delay to be respectful to the server
            time.sleep(2)
            
        except Exception as e:
            print(f"Error scraping page {page}: {str(e)}")
            continue
    
    return all_recipe_urls

def save_urls_to_txt(urls, filename='recipe_urls.txt'):
    """
    Save the scraped URLs to a text file, one URL per line
    
    Args:
        urls (list): List of recipe URLs
        filename (str): Name of output text file
    """
    with open(filename, 'w') as f:
        for url in urls:
            f.write(url + '\n')
    print(f"Saved {len(urls)} URLs to {filename}")

# %%
BASE_URL = "https://pinchofyum.com/recipes/all"
TOTAL_PAGES = 107
    
# Scrape the URLs
recipe_urls = get_recipe_urls(BASE_URL, TOTAL_PAGES)
    
# Save to text file
save_urls_to_txt(recipe_urls)
# Out:
# Scraped page 1 successfully - Found 12 recipes
# Scraped page 2 successfully - Found 12 recipes
# Scraped page 3 successfully - Found 12 recipes
# Scraped page 4 successfully - Found 12 recipes
# Scraped page 5 successfully - Found 12 recipes
# Scraped page 6 successfully - Found 12 recipes
# Scraped page 7 successfully - Found 12 recipes
# Scraped page 8 successfully - Found 12 recipes
# Scraped page 9 successfully - Found 12 recipes
# Scraped page 10 successfully - Found 12 recipes
# Scraped page 11 successfully - Found 12 recipes
# Scraped page 12 successfully - Found 12 recipes
# Scraped page 13 successfully - Found 12 recipes
# Scraped page 14 successfully - Found 12 recipes
# Scraped page 15 successfully - Found 12 recipes
# Scraped page 16 successfully - Found 12 recipes
# Scraped page 17 successfully - Found 12 recipes
# Scraped page 18 successfully - Found 12 recipes
# Scraped page 19 successfully - Found 12 recipes
# Scraped page 20 successfully - Found 12 recipes
# Scraped page 21 successfully - Found 12 recipes
# Scraped page 22 successfully - Found 12 recipes
# Scraped page 23 successfully - Found 12 recipes
# Scraped page 24 successfully - Found 12 recipes
# Scraped page 25 successfully - Found 12 recipes
# Scraped page 26 successfully - Found 12 recipes
# Scraped page 27 successfully - Found 12 recipes
# Scraped page 28 successfully - Found 12 recipes
# Scraped page 29 successfully - Found 12 recipes
# Scraped page 30 successfully - Found 12 recipes
# Scraped page 31 successfully - Found 12 recipes
# Scraped page 32 successfully - Found 12 recipes
# Scraped page 33 successfully - Found 12 recipes
# Scraped page 34 successfully - Found 12 recipes
# Scraped page 35 successfully - Found 12 recipes
# Scraped page 36 successfully - Found 12 recipes
# Scraped page 37 successfully - Found 12 recipes
# Scraped page 38 successfully - Found 12 recipes
# Scraped page 39 successfully - Found 12 recipes
# Scraped page 40 successfully - Found 12 recipes
# Scraped page 41 successfully - Found 12 recipes
# Scraped page 42 successfully - Found 12 recipes
# Scraped page 43 successfully - Found 12 recipes
# Scraped page 44 successfully - Found 12 recipes
# Scraped page 45 successfully - Found 12 recipes
# Scraped page 46 successfully - Found 12 recipes
# Scraped page 47 successfully - Found 12 recipes
# Scraped page 48 successfully - Found 12 recipes
# Scraped page 49 successfully - Found 12 recipes
# Scraped page 50 successfully - Found 12 recipes
# Scraped page 51 successfully - Found 12 recipes
# Scraped page 52 successfully - Found 12 recipes
# Scraped page 53 successfully - Found 12 recipes
# Scraped page 54 successfully - Found 12 recipes
# Scraped page 55 successfully - Found 12 recipes
# Scraped page 56 successfully - Found 12 recipes
# Scraped page 57 successfully - Found 12 recipes
# Scraped page 58 successfully - Found 12 recipes
# Scraped page 59 successfully - Found 12 recipes
# Scraped page 60 successfully - Found 12 recipes
# Scraped page 61 successfully - Found 12 recipes
# Scraped page 62 successfully - Found 12 recipes
# Scraped page 63 successfully - Found 12 recipes
# Scraped page 64 successfully - Found 12 recipes
# Scraped page 65 successfully - Found 12 recipes
# Scraped page 66 successfully - Found 12 recipes
# Scraped page 67 successfully - Found 12 recipes
# Scraped page 68 successfully - Found 12 recipes
# Scraped page 69 successfully - Found 12 recipes
# Scraped page 70 successfully - Found 12 recipes
# Scraped page 71 successfully - Found 12 recipes
# Scraped page 72 successfully - Found 12 recipes
# Scraped page 73 successfully - Found 12 recipes
# Scraped page 74 successfully - Found 12 recipes
# Scraped page 75 successfully - Found 12 recipes
# Scraped page 76 successfully - Found 12 recipes
# Scraped page 77 successfully - Found 12 recipes
# Scraped page 78 successfully - Found 12 recipes
# Scraped page 79 successfully - Found 12 recipes
# Scraped page 80 successfully - Found 12 recipes
# Scraped page 81 successfully - Found 12 recipes
# Scraped page 82 successfully - Found 12 recipes
# Scraped page 83 successfully - Found 12 recipes
# Scraped page 84 successfully - Found 12 recipes
# Scraped page 85 successfully - Found 12 recipes
# Scraped page 86 successfully - Found 12 recipes
# Scraped page 87 successfully - Found 12 recipes
# Scraped page 88 successfully - Found 12 recipes
# Scraped page 89 successfully - Found 12 recipes
# Scraped page 90 successfully - Found 12 recipes
# Scraped page 91 successfully - Found 12 recipes
# Scraped page 92 successfully - Found 12 recipes
# Scraped page 93 successfully - Found 12 recipes
# Scraped page 94 successfully - Found 12 recipes
# Scraped page 95 successfully - Found 12 recipes
# Scraped page 96 successfully - Found 12 recipes
# Scraped page 97 successfully - Found 12 recipes
# Scraped page 98 successfully - Found 12 recipes
# Scraped page 99 successfully - Found 12 recipes
# Scraped page 100 successfully - Found 12 recipes
# Scraped page 101 successfully - Found 12 recipes
# Scraped page 102 successfully - Found 12 recipes
# Scraped page 103 successfully - Found 12 recipes
# Scraped page 104 successfully - Found 12 recipes
# Scraped page 105 successfully - Found 12 recipes
# Scraped page 106 successfully - Found 12 recipes
# Scraped page 107 successfully - Found 8 recipes
# Saved 1280 URLs to recipe_urls.txt
